# %% [markdown]
# # Modeing Rating and Reviews data

# %% [markdown]
# **PACKAGES**

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import datetime

import os
import pickle
import time
from tqdm.notebook import tqdm

from fuzzywuzzy import fuzz
import textdistance

import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# Out:
# C:\Users\asaid\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
tqdm.pandas()
code_start = time.time()
# Out:
# C:\Users\asaid\Anaconda3\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# **CODE PARAMETERS**

# %%
# PANDAS DISPLAY PARAMETERS
# Setting the number of maximum columns and rows to display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', 1)

# %%
# PATHS FOR RATINGS AND REVIEWS
input_reviews_dir_path = r'../data/raw_data/Rating and Reviews/'
output_reviews_dir_path = r'../data/clean_data/'

# PATHS FOR PRODUCT CATALOGUE
input_product_dir_path = r'../data/raw_data/Product Catalogue/'
output_product_dir_path = r'../data/clean_data/'

# PATHS FOR DEMAND
input_demand_dir_path = r'../data/raw_data/Demand Data/'
output_demand_dir_path = r'../data/clean_data/'

# PATHS FOR MAPPINGS
input_mappings_dir_path = r'../data/clean_data/'
output_mappings_dir_path = r'../data/clean_data/'

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# **Quick explanation:**
#
# The data is broken into *Product Catalogues* and *Ratings and Reviews*. *Product Catalogues* contain data about the products. Ratings and Reviews contain data about reviews (EZ). Each of the two are broken into *skincare* and *cosmetics*. The granularity of the data is *Brand* and *Sub Category* also called *ELC Solution Type* (lipstick, gloss etc.). The *Rating and Reviews* data contains the *ELC Solution Type* column but does not contain the *Brand* column. The *Brand* can be retrived from the *Product Catalogue*.
#
# Therefore, we need to join the *Rating and Reviews* data with the *Product Catalogue* then join that to the demand data and finally apply our models.
#
# NB: The *Product Catalogues* and *Ratings and Reviews* files get uploaded to a shared folder once in a while. The *demand* data is downloaded from a certain server.

# %% [markdown]
# ### Wrangling Demand Data

# %% [markdown]
# Before this code, I manually deleted the first row of the xlsx file and saved it as a .csv file. A lot of formating needs to be done to transform the data into a Pandas friendly DataFrame.

# %% [markdown]
# #### Read data

# %%
# Read data
demand = pd.read_csv(os.path.join(input_demand_dir_path,'full_demand.csv'), encoding="ISO-8859-1")

# %% [markdown]
# #### Data description

# %% [markdown]
# The demand data is a bit messy, all the number are in text format. The brands are represented using abbreviations but we have a mapping between brands and there abbreviation.

# %%
print("DATA SAMPLE:")
display(demand.sample(3))
print("DATA DESCRIPTION:")
display(demand.describe(include='all'))
# Out:
# DATA SAMPLE:
#       Brand    ItemID 9             Item Description Affiliate  \
# 22694    OR  0J9J400000  YOUTHTOPIA CREAM REFORM 5ML        US
# 28677    BB  ECT0050990     FACE TOUCH UP PALETTE-WN        US
# 1960     CL  7JGK020000   PORE INSTANT PERFECTING MU        US
#
#        Major Category ID Major Category Application ID Application  \
# 22694                520       Skincare             25        Face
# 28677                510         Makeup             25        Face
# 1960                 510         Makeup             25        Face
#
#       Category ID              Category Sub Category ID       Sub Category  \
# 22694          31          Moisturizers              80       Moisturizers
# 28677          25  Concealers & Correct              M0            Palette
# 1960           28            Foundation              26  Liquid Foundation
#
#       Product Line ID          Product Line Sub Product Line ID  \
# 22694             349        (D) Anti Aging                 152
# 28677              53           Bobbi Brown                 775
# 1960              286  Pore Refining Soluti                 231
#
#                            Sub Product Line Major Inventory  \
# 22694                        (D) Youthtopia     Promotional
# 28677                           Bobbi Brown     Promotional
# 1960   All Pore Refining Solutions Products        Saleable
#
#               Inventory  7/1/2013 8/1/2013 9/1/2013 10/1/2013 11/1/2013  \
# 22694            Samples        -        -        -         -         -
# 28677            Samples        -        -        -         -         -
# 1960   Standard Saleable      942    2,979    2,262     1,467     1,443
#
#       12/1/2013 1/1/2014 2/1/2014 3/1/2014 4/1/2014 5/1/2014 6/1/2014  \
# 22694         1        1        -        5        -        -        -
# 28677         -        -        -        -        -        -        -
# 1960      1,800    1,521    3,009    1,899    1,560    2,413    1,503
#
#       7/1/2014 8/1/2014 9/1/2014 10/1/2014 11/1/2014 12/1/2014 1/1/2015  \
# 22694        -        -        3         -         -         1        -
# 28677        -        -        -         -         -        84        -
# 1960       426    2,098    1,581     1,163     1,913     1,102    1,787
#
#       2/1/2015 3/1/2015 4/1/2015 5/1/2015 6/1/2015 7/1/2015 8/1/2015 9/1/2015  \
# 22694        -        1        2        1      771        2        -        -
# 28677        -        -        -        -        -        -        -        -
# 1960     1,915    2,160    1,181    1,579    1,293    1,291    1,494    1,011
#
#       10/1/2015 11/1/2015 12/1/2015 1/1/2016 2/1/2016 3/1/2016 4/1/2016  \
# 22694         1         -         -      245        1        3        1
# 28677         -         -         -        -        -        -        -
# 1960        867       913       550      153      159        -        -
#
#       5/1/2016 6/1/2016 7/1/2016 8/1/2016 9/1/2016 10/1/2016 11/1/2016  \
# 22694        -        -        -        -        -         -         -
# 28677        -        -        -        -        -         -         -
# 1960         -        -        -        -        -         -         -
#
#       12/1/2016 1/1/2017 2/1/2017 3/1/2017 4/1/2017 5/1/2017 6/1/2017  \
# 22694         -        -        -        -        -        -        -
# 28677         -        -        -        -        -        -        -
# 1960          -        -        -        -        -        -        -
#
#       7/1/2017 8/1/2017 9/1/2017 10/1/2017 11/1/2017 12/1/2017 1/1/2018  \
# 22694        -        -        -         -         -         -        -
# 28677        -        -        -         -         -         -        -
# 1960         -        -        -         -         -         -        -
#
#       2/1/2018 3/1/2018 4/1/2018 5/1/2018 6/1/2018 7/1/2018 8/1/2018 9/1/2018  \
# 22694        -        -        -        -        -        -        -        -
# 28677        -        -        -        -        -        -        -        -
# 1960         -        -        -        -        -        -        -        -
#
#       10/1/2018 11/1/2018 12/1/2018 1/1/2019 2/1/2019 3/1/2019 4/1/2019  \
# 22694         -         -         -        -        -        -        -
# 28677         -         -         -        -        -        -        -
# 1960          -         -         -        -        -        -        -
#
#       5/1/2019 6/1/2019 7/1/2019 8/1/2019 9/1/2019 10/1/2019 11/1/2019  \
# 22694        -        -        -        -        -         -         -
# 28677        -        -        -        -        -         -         -
# 1960         -        -        -        -        -         -         -
#
#       12/1/2019 1/1/2020 2/1/2020 3/1/2020 4/1/2020 5/1/2020 6/1/2020
# 22694         -        -        -        -        -        -        -
# 28677         -        -        -        -        -        -        -
# 1960          -        -        -        -        -        -        -
# DATA DESCRIPTION:
#         Brand    ItemID 9 Item Description Affiliate  Major Category ID  \
# count   37119       37119            37119     37119       37119.000000
# unique     21       37119            17712         1                NaN
# top        MC  AM0L010000        LIP COLOR        US                NaN
# freq     7083           1              330     37119                NaN
# mean      NaN         NaN              NaN       NaN         518.567041
# std       NaN         NaN              NaN       NaN          14.394473
# min       NaN         NaN              NaN       NaN         510.000000
# 25%       NaN         NaN              NaN       NaN         510.000000
# 50%       NaN         NaN              NaN       NaN         510.000000
# 75%       NaN         NaN              NaN       NaN         520.000000
# max       NaN         NaN              NaN       NaN         590.000000
#
#        Major Category Application ID Application Category ID   Category  \
# count           37119          37119       37119       37119      37119
# unique              5             23          23          94         93
# top            Makeup             25        Face          11  Lipsticks
# freq            21117          11253       11253        4112       4112
# mean              NaN            NaN         NaN         NaN        NaN
# std               NaN            NaN         NaN         NaN        NaN
# min               NaN            NaN         NaN         NaN        NaN
# 25%               NaN            NaN         NaN         NaN        NaN
# 50%               NaN            NaN         NaN         NaN        NaN
# 75%               NaN            NaN         NaN         NaN        NaN
# max               NaN            NaN         NaN         NaN        NaN
#
#        Sub Category ID   Sub Category Product Line ID Product Line  \
# count            37119          37119           37119        37119
# unique             212            208             418          418
# top                 17  All Lipsticks              57          MAC
# freq              4080           4080            3445         3445
# mean               NaN            NaN             NaN          NaN
# std                NaN            NaN             NaN          NaN
# min                NaN            NaN             NaN          NaN
# 25%                NaN            NaN             NaN          NaN
# 50%                NaN            NaN             NaN          NaN
# 75%                NaN            NaN             NaN          NaN
# max                NaN            NaN             NaN          NaN
#
#        Sub Product Line ID Sub Product Line Major Inventory  \
# count                37119            37119           37119
# unique                1120             1118               2
# top                    700              MAC        Saleable
# freq                  3161             3161           29244
# mean                   NaN              NaN             NaN
# std                    NaN              NaN             NaN
# min                    NaN              NaN             NaN
# 25%                    NaN              NaN             NaN
# 50%                    NaN              NaN             NaN
# 75%                    NaN              NaN             NaN
# max                    NaN              NaN             NaN
#
#                Inventory  7/1/2013 8/1/2013 9/1/2013 10/1/2013 11/1/2013  \
# count               37119    37119    37119    37119     37119     37119
# unique                  6     3534     3816     3981      3804      3971
# top     Standard Saleable        -        -        -         -         -
# freq                28755    28085    28019    27776     27664     27747
# mean                  NaN      NaN      NaN      NaN       NaN       NaN
# std                   NaN      NaN      NaN      NaN       NaN       NaN
# min                   NaN      NaN      NaN      NaN       NaN       NaN
# 25%                   NaN      NaN      NaN      NaN       NaN       NaN
# 50%                   NaN      NaN      NaN      NaN       NaN       NaN
# 75%                   NaN      NaN      NaN      NaN       NaN       NaN
# max                   NaN      NaN      NaN      NaN       NaN       NaN
#
#        12/1/2013 1/1/2014 2/1/2014 3/1/2014 4/1/2014 5/1/2014 6/1/2014  \
# count      37119    37119    37119    37119    37119    37119    37119
# unique      3913     3336     3783     3940     3459     3941     4017
# top            -        -        -        -        -        -        -
# freq       27758    27977    27913    27849    28118    27931    28408
# mean         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# std          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# min          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25%          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 50%          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 75%          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# max          NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#
aN      NaN      NaN      NaN       NaN       NaN       NaN
# 75%         NaN      NaN      NaN      NaN       NaN       NaN       NaN
# max         NaN      NaN      NaN      NaN       NaN       NaN       NaN
#
#        1/1/2018 2/1/2018 3/1/2018 4/1/2018 5/1/2018 6/1/2018 7/1/2018  \
# count     37119    37119    37119    37119    37119    37119    37119
# unique     2754     3277     3693     2970     3098     3464     2503
# top           -        -        -        -        -        -        -
# freq      28273    28144    27952    28376    28422    28046    28904
# mean        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# std         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# min         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 50%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 75%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# max         NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        8/1/2018 9/1/2018 10/1/2018 11/1/2018 12/1/2018 1/1/2019 2/1/2019  \
# count     37119    37119     37119     37119     37119    37119    37119
# unique     3412     3669      3352      3374      3180     2777     3112
# top           -        -         -         -         -        -        -
# freq      28246    28189     28246     28166     28478    28778    28721
# mean        NaN      NaN       NaN       NaN       NaN      NaN      NaN
# std         NaN      NaN       NaN       NaN       NaN      NaN      NaN
# min         NaN      NaN       NaN       NaN       NaN      NaN      NaN
# 25%         NaN      NaN       NaN       NaN       NaN      NaN      NaN
# 50%         NaN      NaN       NaN       NaN       NaN      NaN      NaN
# 75%         NaN      NaN       NaN       NaN       NaN      NaN      NaN
# max         NaN      NaN       NaN       NaN       NaN      NaN      NaN
#
#        3/1/2019 4/1/2019 5/1/2019 6/1/2019 7/1/2019 8/1/2019 9/1/2019  \
# count     37119    37119    37119    37119    37119    37119    37119
# unique     3612     3178     3349     3621     2956     3484     3391
# top           -        -        -        -        -        -        -
# freq      27878    28096    28107    27735    28378    27945    28101
# mean        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# std         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# min         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 50%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 75%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# max         NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        10/1/2019 11/1/2019 12/1/2019 1/1/2020 2/1/2020 3/1/2020 4/1/2020  \
# count      37119     37119     37119    37119    37119    37119    37119
# unique      3504      3475      3308     3090     3195     2819     1854
# top            -         -         -        -        -        -        -
# freq       27595     27913     28108    28195    28190    28214    29947
# mean         NaN       NaN       NaN      NaN      NaN      NaN      NaN
# std          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# min          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 25%          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 50%          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 75%          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# max          NaN       NaN       NaN      NaN      NaN      NaN      NaN
#
#        5/1/2020 6/1/2020
# count     37119    37119
# unique     2184     2327
# top           -        -
# freq      29652    28838
# mean        NaN      NaN
# std         NaN      NaN
# min         NaN      NaN
# 25%         NaN      NaN
# 50%         NaN      NaN
# 75%         NaN      NaN
# max         NaN      NaN

# %% [markdown]
# #### Data wrangling

# %%
# Pandas friendly column names
demand.columns = [col.lower().strip().replace(' ','_') for col in demand.columns]

# %%
# We extract the columns that contain demand data. They have the format (dd/mm/yyy)
# TODO: use regex. Bleh
dates_columns = demand.columns[demand.columns.str.contains('/')].tolist()

# %%
# In xlsx 0 is marked as '-' which cause the demand columns to be read as of type object (str).
# We need to replace the '-' by 0 and transform the type to int so that we can aggregate using sum().
temp = demand[dates_columns]
temp[temp == '-'] = 0
demand[dates_columns] = temp
del temp
# Out:
# C:\Users\asaid\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\asaid\Anaconda3\lib\site-packages\pandas\core\frame.py:2986: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)

# %%
demand[demand=='-'] = np.nan
# Out:
# C:\Users\asaid\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
groupbycols = [col for col in demand.columns if not col in dates_columns]

# %%
# We aggregate the data
demand = demand.set_index(groupbycols)

# %%
# Finally we use stack to create a columns date, and have a row for each seperate month
demand.columns.name = 'date'
demand = demand.stack().to_frame('demand').reset_index()
demand['date'] = pd.to_datetime(demand['date'], errors='coerce').dt.to_period('m')
#.values.astype('datetime64[M]')

# %%
demand['demand'] = demand['demand'].str.replace(',','').fillna(0).astype(int)

# %%
demand['itemid_4'] = demand['itemid_9'].str[0:4]

# %%
demand = demand.groupby([
    'brand', 
    'itemid_4', 
    'item_description',
    'date',])['demand'].sum().reset_index()

# %%
demand = demand.sort_values(['brand', 
    'itemid_4', 
    'item_description',
    'date'])

# %%
demand
# Out:
#         brand itemid_4    item_description     date  demand
# 0          AR     2008  AR EAU DE TOILETTE  2013-07     219
# 1          AR     2008  AR EAU DE TOILETTE  2013-08     924
# 2          AR     2008  AR EAU DE TOILETTE  2013-09     690
# 3          AR     2008  AR EAU DE TOILETTE  2013-10     843
# 4          AR     2008  AR EAU DE TOILETTE  2013-11    1728
# ...       ...      ...                 ...      ...     ...
# 1738879    TF     T9A4  CCS SCOREMORE TF4A  2020-02       0
# 1738880    TF     T9A4  CCS SCOREMORE TF4A  2020-03       0
# 1738881    TF     T9A4  CCS SCOREMORE TF4A  2020-04       0
# 1738882    TF     T9A4  CCS SCOREMORE TF4A  2020-05       0
# 1738883    TF     T9A4  CCS SCOREMORE TF4A  2020-06       0
#
# [1738884 rows x 5 columns]

# %%
demand.to_csv(os.path.join(output_demand_dir_path,'demand.csv'), index=False)

# %%
# If the wrangled files already exist
demand = pd.read_csv(os.path.join(output_demand_dir_path,'demand.csv'))
demand.sample(10)
# Out:
#         brand itemid_4                 item_description     date  demand
# 1059931    GG     G03T   POWERMUD DUALCLEANSE TREATMENT  2015-02       0
# 950780     EL     RXE5  PURE COLOR ENVY SINGLE LONG NAV  2019-03       0
# 1244861    LL     J0T3                       N36 EDP CP  2018-12       0
# 133        AR     2014                   AR AFTER SHAVE  2017-08       0
# 1537961    OR     0N15          MAD HAND CREAM KEY CLIP  2013-12       0
# 1214535    KL     N38Y  STRAIGHT TO HEAVEN BY KL WH CRI  2018-10       0
# 246555     AV     AMJP        BEAUTIFYING PUREFUME MIST  2014-10       0
# 1163964    JM     L8TE                TRAVEL COLLECTION  2018-07       0
# 624674     CL     ZCTM   TA REVITALIZING INSTANT FACIAL  2017-09    2331
# 542278     CL     KAJ2  MS HYDRATING SUPERCHARGED CNCNT  2018-05       0

# %% [markdown]
# ### Wrangling Rating and Reviews

# %% [markdown]
# #### Read and concatenate data

# %% [markdown]
# First we need to read all the files and concatenate them.

# %%
# List of available files
os.listdir(input_reviews_dir_path)
# Out:
# ['cosmetics_reviews_20191130_final.csv',
#  'cosmetics_reviews_20200101-20200131.csv',
#  'cosmetics_reviews_20200229.csv',
#  'cosmetics_reviews_20200331.csv',
#  'old_files',
#  'pwds',
#  'skincare_reviews_20150201-20200131.csv',
#  'skincare_reviews_20200229.csv',
#  'skincare_reviews_20200331.csv',
#  'template']

# %%
start = time.time()
reviews_skincare = pd.DataFrame()
reviews_cosmetics = pd.DataFrame()
for file in os.listdir(input_reviews_dir_path):
    if '.csv' in file.lower():
        if 'skincare' in file.lower():
            interm = time.time()
            print('\nReading', file)
            temp = pd.read_csv(os.path.join(input_reviews_dir_path,file), low_memory=False)
            temp = temp.loc[:, ~temp.columns.str.contains('^Unnamed')]
            temp.columns = [colname.lower().replace(' ','_') for colname in temp.columns]
            print('Concatenating', file)
            reviews_skincare=pd.concat([reviews_skincare, temp], ignore_index=True)
            print('Time for this dataset: %.0f seconds' % (time.time()-interm))
            print('Total time: %.0f seconds' % (time.time()-start))
        elif 'cosmetics' in file.lower():
            interm = time.time()
            print('\nReading', file)
            temp = pd.read_csv(os.path.join(input_reviews_dir_path,file), low_memory=False)
            temp = temp.loc[:, ~temp.columns.str.contains('^Unnamed')]
            temp.columns = [colname.lower().replace(' ','_') for colname in temp.columns]
            print('Concatenating', file)
            reviews_cosmetics=pd.concat([reviews_cosmetics, temp], ignore_index=True)
            print('Time for this dataset: %.0f seconds' % (time.time()-interm))
            print('Total time: %.0f seconds' % (time.time()-start))
del temp

# %%
reviews_cosmetics = reviews_cosmetics.drop_duplicates()
reviews_skincare = reviews_skincare.drop_duplicates()

# %%
reviews_cosmetics.to_csv(os.path.join(output_reviews_dir_path,'reviews_cosmetics.csv'), index=False)
reviews_skincare.to_csv(os.path.join(output_reviews_dir_path,'reviews_skincare.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-773e5facc4d7> in <module>
# ----> 1 reviews_cosmetics.to_csv(os.path.join(output_reviews_dir_path,'reviews_cosmetics.csv'), index=False)
#       2 reviews_skincare.to_csv(os.path.join(output_reviews_dir_path,'reviews_skincare.csv'), index=False)
#
# NameError: name 'reviews_cosmetics' is not defined

# %%
# If concatenated files already exist
reviews_cosmetics = pd.read_csv(os.path.join(output_reviews_dir_path,'reviews_cosmetics.csv'), low_memory=False)
reviews_skincare = pd.read_csv(os.path.join(output_reviews_dir_path,'reviews_skincare.csv'), low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-97a0719e9f5c> in <module>
#       1 # If concatenated files already exist
# ----> 2 reviews_cosmetics = pd.read_csv(os.path.join(output_reviews_dir_path,'reviews_cosmetics.csv'), low_memory=False)
#       3 reviews_skincare = pd.read_csv(os.path.join(output_reviews_dir_path,'reviews_skincare.csv'), low_memory=False)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\common.py in is_categorical_dtype(arr_or_dtype)
#     540
#     541
# --> 542 def is_categorical_dtype(arr_or_dtype) -> bool:
#     543     """
#     544     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %% [markdown]
# #### Data description

# %% [markdown]
# Each review/post has a unique *OnlinePost_ID*. Each *OnlinePost_ID* is broken into different *Statements*. Each statement has a unique *OnlineStatement_ID* which is the concatenation of the *OnlineStatement_ID* and the rank of the statement. A statement is usually a sentence or a comment. The actual text is contained in the *Description* column.
#
# The Reviews data and the Products data must be joined using *Source Product Identifier* and *Channel* as a compounded key.

# %% [markdown]
# **COSMETICS**

# %%
print("DATA SAMPLE:")
display(reviews_cosmetics.sample(3))
print("DATA DESCRIPTION:")
display(reviews_cosmetics.describe(include='all'))
print("% OF MISSING DATA:")
display((reviews_cosmetics.isna().sum()/len(reviews_cosmetics))*100)

# %% [markdown]
# **REVIEWS**

# %%
print("DATA SAMPLE:")
display(reviews_skincare.sample(3))
print("DATA DESCRIPTION:")
display(reviews_skincare.describe(include='all'))
print("% OF MISSING DATA:")
display((reviews_skincare.isna().sum()/len(reviews_skincare))*100)

# %% [markdown]
# #### Data wrangling

# %% [markdown]
# Here are some ideas about the aggregationg of R&R data :
# 1. Filter on Geography to only keep USA data
# 2. create date columns (year, month)
# 3. change sentiment to numerical data : negative:-1, neurtal:0, positive:1
# 4. create sentiment one hot encodings
# 5. groupby OnlineStatement_ID and aggregate by {sentiment:mean, sentiments_hot_one:average_count)
# 5. create rating one hot encodings
# 5. Groupby year, month, Channel, Source Product Identifier
# 6. Aggregate by {num_sentiment:mean, num_rating:mean, sentiments_hot_one:count, rating_hot_one:count}
# 7. Count the number of reviews

# %% [markdown]
# Then we concatenate cosmetic and skincare, and add a columns *type* to keep track of the source of the data.
#
# **NB**: The columns are not exactly the same between the two types. By concatenting, we will have the union of the features of the two datasets and missing values will be filled with NaNs.

# %%
reviews_cosmetics['type'] = 'Cosmetics'
reviews_skincare['type'] = 'Skincare'
reviews = pd.concat([reviews_cosmetics, reviews_skincare], axis=0)

# %%
del reviews_cosmetics
del reviews_skincare

# %%
reviews.head(2)

# %%
# Filtering geographies on US
reviews = reviews[reviews['geography']=='USA']

# %%
# Creating date columns in the right dtype and dropping the day of the month: 2019-02-24 => 2019-02-01
reviews.loc[:,'clean_date'] = pd.to_datetime(reviews['date'], errors='coerce')
if reviews['clean_date'].isna().sum() > 0:
    print('{} rows have been dropped because the date format is wrong.'.format(reviews['clean_date'].isna().sum()))
    display(reviews.loc[reviews['clean_date'].isna(), 'date'])
    reviews = reviews.dropna(subset='date')
reviews['date'] = reviews['clean_date']  
reviews = reviews.drop('clean_date', axis=1)
reviews['date'] = reviews['date'].dt.to_period('m')

# %%
# Checking for missing data (NA => -1)
if reviews['rating'].isna().sum()>0:
    print('{} rows are missing ratings'.format(reviews['rating'].isna().sum()))
    reviews.loc[:,'rating'] = reviews['rating'].fillna(-1).astype(int)

if reviews['sentiment'].isna().sum()>0:
    print('{} rows are missing sentiments'.format(reviews['sentiment'].isna().sum()))
    reviews.loc[:,'sentiment'] = reviews['sentiment'].fillna(-1).astype(int)

# %%
# Transforming rating and sentiment to dummy variables (one-hot encoding)
reviews.loc[:,'sentiment'] = reviews['sentiment'].str.lower()
reviews.loc[:,'rating'] = reviews['rating'].astype(int)
reviews = pd.concat([reviews, pd.get_dummies(data=reviews[['rating','sentiment']], columns=['rating','sentiment'], dtype=int)], axis=1)

# %%
# Readding NAs data to ratings
reviews.loc[reviews['rating']==-1,'rating'] = np.nan
reviews.loc[reviews['sentiment']==-1,'sentiment'] = np.nan

# %%
# Transforming sentiment to integer data (positive:1; netural:0, negative:-1)
reviews.loc[:,'sentiment'] = reviews['sentiment_positive'] - reviews['sentiment_negative']

# %%
# Aggregating RR data by OnlinePost_ID

# Creating a column to count the number of statements by review once aggreagtion happens
reviews['nb_statements'] = reviews['sentiment']

reviews = reviews.groupby(['type',
                             'channel',
                             'source_product_identifier',  
                             'date',
                             'onlinepost_id']).agg({
    'nb_statements':'count',
    'rating':'first',
    'rating_1':'first',
    'rating_2':'first',
    'rating_3':'first',
    'rating_4':'first',
    'rating_5':'first',
    'sentiment_negative':'sum',
    'sentiment_neutral':'sum',
    'sentiment_positive':'sum',
    'sentiment':'mean'
}).reset_index()

# Normalize the one hot sentiment encoding counts (sentiment_negative, sentiment_neutral, sentiment_positive) by the nb_statement.
reviews[['sentiment_negative', 'sentiment_neutral', 'sentiment_positive']] = reviews[['sentiment_negative', 'sentiment_neutral', 'sentiment_positive']].div(reviews['nb_statements'], axis=0)

# %%
reviews.head(4)

# %%
# Aggregating RR data by channel + source_product_identifier

# Creating a column to count the number of reviews once aggreagtion happens
reviews['nb_reviews'] = reviews['rating']
reviews['avg_nb_statements'] = reviews['nb_statements']

reviews = reviews.groupby(['type',
                           'channel',
                           'source_product_identifier',
                           'date']).agg({
    'avg_nb_statements':'mean',
    'nb_reviews':'count',
    'rating':'mean',
    'rating_1':'sum',
    'rating_2':'sum',
    'rating_3':'sum',
    'rating_4':'sum',
    'rating_5':'sum',
    'sentiment_negative':'sum',
    'sentiment_neutral':'sum',
    'sentiment_positive':'sum',
    'sentiment':'mean'
}).reset_index()

# %%
reviews.head(4)

# %%
# Saving dataset
reviews.to_csv(os.path.join(output_reviews_dir_path,'reviews_wrangled.csv'), index=False)

# %%
# If the wrangled files already exist
reviews = pd.read_csv(os.path.join(output_reviews_dir_path,'reviews_wrangled.csv'), low_memory=False)
reviews
# Out:
#              type     channel source_product_identifier     date  \
# 0       Cosmetics  Amazon USA                0001842420  2015-03
# 1       Cosmetics  Amazon USA                0001842420  2015-04
# 2       Cosmetics  Amazon USA                0001842420  2015-05
# 3       Cosmetics  Amazon USA                0001842420  2015-06
# 4       Cosmetics  Amazon USA                0001842420  2015-09
# ...           ...         ...                       ...      ...
# 696311   Skincare        Ulta         xlsImpprod6400280  2020-03
# 696312   Skincare        Ulta         xlsImpprod6430317  2020-03
# 696313   Skincare        Ulta         xlsImpprod6430359  2020-01
# 696314   Skincare        Ulta         xlsImpprod6470101  2020-03
# 696315   Skincare        Ulta         xlsImpprod6480077  2020-03
#
#         avg_nb_statements  nb_reviews  rating  rating_1  rating_2  rating_3  \
# 0                     2.0           1     5.0         0         0         0
# 1                     1.0           1     5.0         0         0         0
# 2                     2.0           1     5.0         0         0         0
# 3                     3.5           2     5.0         0         0         0
# 4                     3.0           2     4.0         0         0         0
# ...                   ...         ...     ...       ...       ...       ...
# 696311                4.0           3     5.0         0         0         0
# 696312                5.0           1     2.0         0         1         0
# 696313                4.0           2     5.0         0         0         0
# 696314                2.0           2     5.0         0         0         0
# 696315                2.0           2     3.0         1         0         0
#
#         rating_4  rating_5  sentiment_negative  sentiment_neutral  \
# 0              0         1            0.000000           0.000000
# 1              0         1            0.000000           0.000000
# 2              0         1            0.000000           0.000000
# 3              0         2            0.166667           0.166667
# 4              2         0            0.000000           0.500000
# ...          ...       ...                 ...                ...
# 696311         0         3            0.000000           0.285714
# 696312         0         0            0.000000           0.000000
# 696313         0         2            0.000000           0.200000
# 696314         0         2            0.000000           0.000000
# 696315         0         1            0.000000           0.500000
#
#         sentiment_positive  sentiment
# 0                 1.000000   1.000000
# 1                 1.000000   1.000000
# 2                 1.000000   1.000000
# 3                 1.666667   0.750000
# 4                 1.500000   0.750000
# ...                    ...        ...
# 696311            2.714286   0.904762
# 696312            1.000000   1.000000
# 696313            1.800000   0.900000
# 696314            2.000000   1.000000
# 696315            1.500000   0.750000
#
# [696316 rows x 16 columns]

# %% [markdown]
# The Rating and Reviews data is now wrangled. We now need to wrangle the Product Catalogue data before merging the two datasets.

# %% [markdown]
# ### Wrangling Product Catalogue

# %% [markdown]
# #### Read and concatenate data

# %% [markdown]
# First we need to read all the files and concatenate them.

# %%
# List of available files
os.listdir(input_product_dir_path)
# Out:
# ['cosmetics_products_20200331.csv',
#  'Cosmetics_Product_20190831.csv',
#  'Cosmetics_Product_20190930.csv',
#  'Cosmetics_Product_20191031.csv',
#  'cosmetics_product_2019Q4.csv',
#  'Cosmetics_Product_20200116.csv',
#  'ELC_historic_catalog_cosmetics.b.csv',
#  'ELC_historic_catalog_cosmetics.csv',
#  'ELC_historic_catalog_skincare.b.csv',
#  'ELC_historic_catalog_skincare.csv',
#  'Hair Care.zip',
#  'old_files',
#  'skincare_products_20200331.csv',
#  'skincare_productupc_20200331.csv',
#  'SkinCare_Product_20190630_ST MV2SV.csv',
#  'SkinCare_Product_20190930.csv',
#  'SkinCare_Product_20190930_Update.csv',
#  'SkinCare_Product_20191031.csv',
#  'skincare_product_20191231.csv',
#  'skincare_product_2019Q3.csv',
#  'skincare_product_2019Q3_final.csv',
#  'SkinCare_Product_20200116.csv']

# %%
start = time.time()
products_skincare = pd.DataFrame()
products_cosmetics = pd.DataFrame()
for file in os.listdir(input_product_dir_path):
    if '.csv' in file.lower():
        if 'skincare' in file.lower():
            interm = time.time()
            print('\nReading', file)
            temp = pd.read_csv(os.path.join(input_product_dir_path,file), low_memory=False)
            temp = temp.loc[:, ~temp.columns.str.contains('^Unnamed')]
            temp.columns = [colname.lower().replace(' ','_') for colname in temp.columns]
            print('Concatenating', file)
            products_skincare = pd.concat([products_skincare, temp], ignore_index=True)
            print('Time for this dataset: %.0f seconds' % (time.time()-interm))
            print('Total time: %.0f seconds' % (time.time()-start))
        elif 'cosmetics' in file.lower():
            interm = time.time()
            print('\nReading', file)
            temp = pd.read_csv(os.path.join(input_product_dir_path,file), low_memory=False)
            temp = temp.loc[:, ~temp.columns.str.contains('^Unnamed')]
            temp.columns = [colname.lower().replace(' ','_') for colname in temp.columns]
            print('Concatenating', file)
            products_cosmetics = pd.concat([products_cosmetics, temp], ignore_index=True)
            print('Time for this dataset: %.0f seconds' % (time.time()-interm))
            print('Total time: %.0f seconds' % (time.time()-start))
del temp

# %% [markdown]
# Then we drop duplicated rows (if any exist).

# %%
products_cosmetics = products_cosmetics.drop_duplicates()
products_skincare = products_skincare.drop_duplicates()

# %% [markdown]
# Finally we save the two files so that we don't have to run everything from scract everytime.

# %%
products_cosmetics.to_csv(os.path.join(output_product_dir_path,'products_cosmetics.csv'), index=False)
products_skincare.to_csv(os.path.join(output_product_dir_path,'products_skincare.csv'), index=False)

# %%
# If concatenated files already exist
products_cosmetics = pd.read_csv(os.path.join(output_product_dir_path,'products_cosmetics.csv'), low_memory=False)
products_skincare = pd.read_csv(os.path.join(output_product_dir_path,'products_skincare.csv'), low_memory=False)

# %% [markdown]
# #### Data description

# %% [markdown]
# **COSMETICS**

# %%
print("DATA SAMPLE:")
display(products_cosmetics.sample(3))
print("DATA DESCRIPTION:")
display(products_cosmetics.describe(include='all'))
print("% OF MISSING DATA:")
display((products_cosmetics.isna().sum()/len(products_cosmetics))*100)
# Out:
# DATA SAMPLE:
#                       product_id source_product_identifier  \
# 23004   Product_20200413_7009230                B079SXSQ9Z
# 435577  Product_20190722_4826377                B00CL5ZB1U
# 182042  Product_20191016_4975804                B01FEXGCLI
#
#                                                   product  \
# 23004   Physicians Formula - Healthy Lip Velvet Liquid...
# 435577  freshMinerals Mineral Loose Powder Foundation,...
# 182042  TONYMOLY Panda's Dream Smudge out mascara # 01...
#
#                                               description     channel  \
# 23004   What It Is: Long-wearing, decadent mousse-like...   Amazon UK
# 435577  Color: Natural Mineral powder foundation by fr...  Amazon USA
# 182042  Colour: #01 Volume About the Product No more s...   Amazon UK
#
#                      brand                     feature  \
# 23004   PHYSICIANS FORMULA  Gentle;Lightweight Formula
# 435577       freshMinerals      Natural;SPF Protection
# 182042            TONYMOLY               Not Mentioned
#
#                                                benefit  \
# 23004                          Anti Aging;Moisturizing
# 435577         Contains Natural Ingredients;Refreshing
# 182042  Long Lasting;Refreshing;Smudgeproof;Volumizing
#
#                                           ingredient  \
# 23004   Hyaluronic Acid;Peptides;Vitamin A;Vitamin E
# 435577                                 Not Mentioned
# 182042                                 Not Mentioned
#
#        additional_ingredients_(no_rulebase)        product_form  \
# 23004                           Avocado Oil  Cream;Liquid;Stick
# 435577                        Not Mentioned              Powder
# 182042                        Not Mentioned       Not Mentioned
#
#        elc_solution_type  rating  number_of_reviews geography collection_date  \
# 23004    Liquid Lipcolor     4.1               42.0        UK      2019-12-16
# 435577        Foundation     3.4               23.0       USA       7/11/2019
# 182042           Mascara     3.8                7.0        UK      2019-09-15
#
#                                  normalized_product_title  \
# 23004   PHYSICIANS FORMULA LIQUID LIPCOLOR THE HEALTHY...
# 435577                                                NaN
# 182042                                                NaN
#
#                            productcluster_id         finish          looks  \
# 23004   PHYSICIANS FORMULA_Liquid Lipcolor_1  Not Mentioned  Not Mentioned
# 435577                                   NaN  Not Mentioned  Not Mentioned
# 182042                                   NaN  Not Mentioned  Not Mentioned
#
#                 other         trends  cluster_size title solution_type
# 23004   Not Mentioned  Not Mentioned           NaN   NaN           NaN
# 435577  Not Mentioned  Not Mentioned           NaN   NaN           NaN
# 182042  Not Mentioned  Not Mentioned           NaN   NaN           NaN
# DATA DESCRIPTION:
#                       product_id source_product_identifier    product  \
# count                     525535                    525535     525535
# unique                    294817                    120512     127291
# top     Product_20190722_4026451               1.23443E+11  Lip Gloss
# freq                           5                       143        154
# mean                         NaN                       NaN        NaN
# std                          NaN                       NaN        NaN
# min                          NaN                       NaN        NaN
# 25%                          NaN                       NaN        NaN
# 50%                          NaN                       NaN        NaN
# 75%                          NaN                       NaN        NaN
# max                          NaN                       NaN        NaN
#
#                                               description     channel   brand  \
# count                                              509455      525535  525535
# unique                                             143785          14    2417
# top     Size: Pack of 2 For the most up to date inform...  Amazon USA     MAC
# freq                                                 1451      188105   18483
# mean                                                  NaN         NaN     NaN
# std                                                   NaN         NaN     NaN
# min                                                   NaN         NaN     NaN
# 25%                                                   NaN         NaN     NaN
# 50%                                                   NaN         NaN     NaN
# 75%                                                   NaN         NaN     NaN
# max                                                   NaN         NaN     NaN
#
#               feature        benefit     ingredient  \
# count          525535         525533         525535
# unique           9389          38781            755
# top     Not Mentioned  Not Mentioned  Not Mentioned
# freq           237381          85740         412074
# mean              NaN            NaN            NaN
# std               NaN            NaN            NaN
# min               NaN            NaN            NaN
# 25%               NaN            NaN            NaN
# 50%               NaN            NaN            NaN
# 75%               NaN            NaN            NaN
# max               NaN            NaN            NaN
#
#        additional_ingredients_(no_rulebase)   product_form elc_solution_type  \
# count                                503592         525535            514033
# unique                                 2837            597               785
# top                           Not Mentioned  Not Mentioned          Lipstick
# freq                                 392078         171609             58979
# mean                                    NaN            NaN               NaN
# std                                     NaN            NaN               NaN
# min                                     NaN            NaN               NaN
# 25%                                     NaN            NaN               NaN
# 50%                                     NaN            NaN               NaN
# 75%                                     NaN            NaN               NaN
# max                                     NaN            NaN               NaN
#
#                rating  number_of_reviews geography collection_date  \
# count   463326.000000      507847.000000    525535          525395
# unique            NaN                NaN         2             293
# top               NaN                NaN       USA      2019-07-02
# freq              NaN                NaN    310564           38457
# mean         4.032949         137.810955       NaN             NaN
# std          0.834271         858.804310       NaN             NaN
# min          0.000000           0.000000       NaN             NaN
# 25%          3.700000           3.000000       NaN             NaN
# 50%          4.200000           9.000000       NaN             NaN
# 75%          4.600000          51.000000       NaN             NaN
# max          5.000000       59066.000000       NaN             NaN
#
#        normalized_product_title productcluster_id         finish  \
# count                    195076            195076         515389
# unique                    52066             33289            557
# top      MAC amplified lipstick  NARS_Eyeshadow_1  Not Mentioned
# freq                        156               164         199233
# mean                        NaN               NaN            NaN
# std                         NaN               NaN            NaN
# min                         NaN               NaN            NaN
# 25%                         NaN               NaN            NaN
# 50%                         NaN               NaN            NaN
# 75%                         NaN               NaN            NaN
# max                         NaN               NaN            NaN
#
#                 looks          other         trends  cluster_size      title  \
# count          515389         515389         515389  31405.000000      54829
# unique            123             36            144           NaN      51417
# top     Not Mentioned  Not Mentioned  Not Mentioned           NaN  Lip Gloss
# freq           500571         468231         438648           NaN         19
# mean              NaN            NaN            NaN      4.243401        NaN
# std               NaN            NaN            NaN      7.510366        NaN
# min               NaN            NaN            NaN      1.000000        NaN
# 25%               NaN            NaN            NaN      1.000000        NaN
# 50%               NaN            NaN            NaN      3.000000        NaN
# 75%               NaN            NaN            NaN      4.000000        NaN
# max               NaN            NaN            NaN     78.000000        NaN
#
#        solution_type
# count          72230
# unique           661
# top         Lipstick
# freq            8302
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
# % OF MISSING DATA:
# product_id                               0.000000
# source_product_identifier                0.000000
# product                                  0.000000
# description                              3.059739
# channel                                  0.000000
# brand                                    0.000000
# feature                                  0.000000
# benefit                                  0.000381
# ingredient                               0.000000
# additional_ingredients_(no_rulebase)     4.175364
# product_form                             0.000000
# elc_solution_type                        2.188627
# rating                                  11.837271
# number_of_reviews                        3.365713
# geography                                0.000000
# collection_date                          0.026640
# normalized_product_title                62.880493
# productcluster_id                       62.880493
# finish                                   1.930604
# looks                                    1.930604
# other                                    1.930604
# trends                                   1.930604
# cluster_size                            94.024185
# title                                   89.567013
# solution_type                           86.255911
# dtype: float64

# %% [markdown]
# **SKINCARE**

# %%
print("DATA SAMPLE:")
display(products_skincare.sample(3))
print("DATA DESCRIPTION:")
display(products_skincare.describe(include='all'))
print("% OF MISSING DATA:")
display((products_skincare.isna().sum()/len(products_cosmetics))*100)
# Out:
# DATA SAMPLE:
#                      additional_ingredients_(no_rulebase)  \
# 590578                                      Not Mentioned
# 868721  Essential Oil;Ferment/Fermentation;Parabens;Ph...
# 17320                                                 NaN
#
#                                                   benefit           brand  \
# 590578  Brightening & Whitening;Firming;Lifting;Nouris...           Murad
# 868721  Brightening & Whitening;Effective;Firming;Glow...  DRUNK ELEPHANT
# 17320         Cleansing & Cleaning;Moisturizing;Smoothing        Shiseido
#
#           channel collection_date  \
# 590578   Birchbox      2019-07-18
# 868721    Sephora      2019-09-26
# 17320   Amazon UK       11/5/2018
#
#                                                   product  \
# 590578                                                NaN
# 868721                      C-FirmaTM Vitamin C Day Serum
# 17320   Shiseido Ibuki Refining Moisturiser Enriched 5...
#
#                                               description elc_solution_type  \
# 590578  Skincare Step 2: Treat\nThis eye serum is clin...     Eye Treatment
# 868721  Which skin type is it good for? ✔ Normal ✔ Oil...             Serum
# 17320   A multi-functional moisturiser that improves v...  Face Moisturizer
#
#                                                   feature geography  \
# 590578                                      Not Mentioned       USA
# 868721  Cruelty Free;Healing;Natural;Scented;Synthetic...       USA
# 17320                                       Not Mentioned        UK
#
#                                               ingredient  \
# 590578                                  Retinoid;Retinol
# 868721  Antioxidants;Beta Hydroxy Acid;Mineral;Vitamin C
# 17320                                      Not Mentioned
#
#                               normalized_product_title number_of_reviews  \
# 590578                                             NaN               0.0
# 868721  DRUNK ELEPHANT C-FIRMA VITAMIN DAY SERUM SERUM            1831.0
# 17320                                              NaN               0.0
#
#             packaging   product_form       productcluster_id  \
# 590578  Not Mentioned  Not Mentioned                     NaN
# 868721  Not Mentioned            Oil  DRUNK ELEPHANT_Serum_1
# 17320   Not Mentioned  Not Mentioned                     NaN
#
#                        product_id  rating  \
# 590578  Product_20190807_10915047     NaN
# 868721  Product_20191007_12521045  3.9005
# 17320     Product_20181119_294354     NaN
#
#                                       skin_condition           skin_type  \
# 590578              Dark Circle;Wrinkles and Sagging       Not Mentioned
# 868721  Dark Spots;Pigmentation;Wrinkles and Sagging       Not Mentioned
# 17320                                   Acne;Dryness  All Skin Types;Dry
#
#        solution_type source_product_identifier treatment_area       use_case  \
# 590578           NaN                     39870      Eyes;Feet  Not Mentioned
# 868721           NaN                   P400259  Not Mentioned  Not Mentioned
# 17320      Eye Cream                B017M5DDOA      Face Area  Not Mentioned
#
#        cluster_title  caf1a03ebf00d4078bbb0a590ec19a089  upc  \
# 590578           NaN                                NaN  NaN
# 868721           NaN                                NaN  NaN
# 17320            NaN                                NaN  NaN
#
#         c8285216327864eb388e64216dead18b1  c5bdcdac51d9e41dca007d69f7cd66c58  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c886f108693fa44d3b90e50714f925352  c247b9901626441798fd9f5b0e1da5b6b  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c592ee2bea9194edfa01db5a04de3e8ed  c39ee8c98ff6e4d2394de70aba44d3b53  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         ce9ff836616d54454a16e6e453cd8c3a0  c60e432d687a14313af9a796a9d1aa662  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         cdb3deb1d22ff4b3b95f7cf93a716e37f  c221108b649a940bfb30f51761418e985  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         cf1972cff60c14e5c9a0360d29728f326  c0f3a87d761e14a9a9355fd6cbf5e6a23  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c12155d43bdc349f09c79baafbd50920c  cdcbef08d2dab47dd848b0b95f0fedbe2  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c0fcd4ae2146440218fabd77b2fd0b9d2  cc7c0e57649784f21b4b637f729d6caf9  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c0881be2cfa9840f4a01414ab5ecf5ff3  cf6a2c815ba954cb39cc42b31b4fee2f0  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         cff79bc48a3904424abc514711b240877  c9a2e8d1d2d564ee89ef2dc6bb2c613d4  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c4587ff7e968142b69f6e308c49df39d3  cd96842a0c3c04ec385214879a168dfaa  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c2771dfbcbc0d4e778de96df220c34b06  c73106569fb4d4913b88ae2b231d39064  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c0b87f5c8b4c449bbbefa78e44454686a  c9a2fcedcc6564367861ae58adf7f62d1  \
# 590578                                NaN                                NaN
# 868721                                NaN                                NaN
# 17320                                 NaN                                NaN
#
#         c085c055e8cd4447aad82a1b1c15a5750  \
# 590578                                NaN
# 868721                                NaN
# 17320                                 NaN
#
#                                          title cluster_size
# 590578  Murad® Retinol Youth Renewal Eye Serum          NaN
# 868721                                     NaN          1.0
# 17320                                      NaN          NaN
# DATA DESCRIPTION:
#        additional_ingredients_(no_rulebase)        benefit          brand  \
# count                               1074346        1107894        1107894
# unique                                 6416          93006           6332
# top                           Not Mentioned  Not Mentioned  Not Mentioned
# freq                                 779063         155222          24869
# mean                                    NaN            NaN            NaN
# std                                     NaN            NaN            NaN
# min                                     NaN            NaN            NaN
# 25%                                     NaN            NaN            NaN
# 50%                                     NaN            NaN            NaN
# 75%                                     NaN            NaN            NaN
# max                                     NaN            NaN            NaN
#
#            channel collection_date product               description  \
# count      1107894         1101412  998200                    995236
# unique          17             330  219736                    205600
# top     Amazon USA      2020-04-02       -  Description coming soon.
# freq        552025           91892     222                       920
# mean           NaN             NaN     NaN                       NaN
# std            NaN             NaN     NaN                       NaN
# min            NaN             NaN     NaN                       NaN
# 25%            NaN             NaN     NaN                       NaN
# 50%            NaN             NaN     NaN                       NaN
# 75%            NaN             NaN     NaN                       NaN
# max            NaN             NaN     NaN                       NaN
#
#        elc_solution_type        feature geography     ingredient  \
# count            1029818        1107894   1107165        1107894
# unique               806          27304         4          23233
# top             Cleanser  Not Mentioned       USA  Not Mentioned
# freq              168112         406345    741960         513491
# mean                 NaN            NaN       NaN            NaN
# std                  NaN            NaN       NaN            NaN
# min                  NaN            NaN       NaN            NaN
# 25%                  NaN            NaN       NaN            NaN
# 50%                  NaN            NaN       NaN            NaN
# 75%                  NaN            NaN       NaN            NaN
# max                  NaN            NaN       NaN            NaN
#
#        normalized_product_title number_of_reviews      packaging  \
# count                    362820           1081537        1107894
# unique                   149476              4555             20
# top                    lip balm               0.0  Not Mentioned
# freq                        202            449466        1032150
# mean                        NaN               NaN            NaN
# std                         NaN               NaN            NaN
# min                         NaN               NaN            NaN
# 25%                         NaN               NaN            NaN
# 50%                         NaN               NaN            NaN
# 75%                         NaN               NaN            NaN
# max                         NaN               NaN            NaN
#
#          product_form productcluster_id                 product_id  rating  \
# count         1107894            362820                    1107895  646731
# unique           2214             52510                     483921    6329
# top     Not Mentioned  SUN BUM_In Sun_1  Product_20191007_12526454     5.0
# freq           348388               145                          5  120994
# mean              NaN               NaN                        NaN     NaN
# std               NaN               NaN                        NaN     NaN
# min               NaN               NaN                        NaN     NaN
# 25%               NaN               NaN                        NaN     NaN
# 50%               NaN               NaN                        NaN     NaN
# 75%               NaN               NaN                        NaN     NaN
# max               NaN               NaN                        NaN     NaN
#
#        skin_condition      skin_type    solution_type  \
# count         1107894        1107894           149891
# unique           3054            196             1380
# top     Not Mentioned  Not Mentioned  Wash & Cleanser
# freq           585385         681566            29236
# mean              NaN            NaN              NaN
# std               NaN            NaN              NaN
# min               NaN            NaN              NaN
# 25%               NaN            NaN              NaN
# 50%               NaN            NaN              NaN
# 75%               NaN            NaN              NaN
# max               NaN            NaN              NaN
#
#        source_product_identifier treatment_area       use_case  \
# count                    1107895        1107894        1107894
# unique                    202808            613              5
# top                     1.23E+11  Not Mentioned  Not Mentioned
# freq                         568         437942        1073394
# mean                         NaN            NaN            NaN
# std                          NaN            NaN            NaN
# min                          NaN            NaN            NaN
# 25%                          NaN            NaN            NaN
# 50%                          NaN            NaN            NaN
# 75%                          NaN            NaN            NaN
# max                          NaN            NaN            NaN
#
#                                         cluster_title  \
# count                                           99534
# unique                                          27300
# top     DR. HAUSCHKA FACE MOISTURIZER DAY CREAM LIGHT
# freq                                               56
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#         caf1a03ebf00d4078bbb0a590ec19a089           upc  \
# count                                 0.0         24874
# unique                                NaN         22414
# top                                   NaN  075486091859
# freq                                  NaN            13
# mean                                  NaN           NaN
# std                                   NaN           NaN
# min                                   NaN           NaN
# 25%                                   NaN           NaN
# 50%                                   NaN           NaN
# 75%                                   NaN           NaN
# max                                   NaN           NaN
#
#         c8285216327864eb388e64216dead18b1  c5bdcdac51d9e41dca007d69f7cd66c58  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c886f108693fa44d3b90e50714f925352  c247b9901626441798fd9f5b0e1da5b6b  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c592ee2bea9194edfa01db5a04de3e8ed  c39ee8c98ff6e4d2394de70aba44d3b53  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         ce9ff836616d54454a16e6e453cd8c3a0  c60e432d687a14313af9a796a9d1aa662  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         cdb3deb1d22ff4b3b95f7cf93a716e37f  c221108b649a940bfb30f51761418e985  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         cf1972cff60c14e5c9a0360d29728f326  c0f3a87d761e14a9a9355fd6cbf5e6a23  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c12155d43bdc349f09c79baafbd50920c  cdcbef08d2dab47dd848b0b95f0fedbe2  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c0fcd4ae2146440218fabd77b2fd0b9d2  cc7c0e57649784f21b4b637f729d6caf9  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c0881be2cfa9840f4a01414ab5ecf5ff3  cf6a2c815ba954cb39cc42b31b4fee2f0  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         cff79bc48a3904424abc514711b240877  c9a2e8d1d2d564ee89ef2dc6bb2c613d4  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c4587ff7e968142b69f6e308c49df39d3  cd96842a0c3c04ec385214879a168dfaa  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c2771dfbcbc0d4e778de96df220c34b06  c73106569fb4d4913b88ae2b231d39064  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c0b87f5c8b4c449bbbefa78e44454686a  c9a2fcedcc6564367861ae58adf7f62d1  \
# count                                 0.0                                0.0
# unique                                NaN                                NaN
# top                                   NaN                                NaN
# freq                                  NaN                                NaN
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#         c085c055e8cd4447aad82a1b1c15a5750   title cluster_size
# count                                 0.0  109695        37415
# unique                                NaN  102762           24
# top                                   NaN      Â®          1.0
# freq                                  NaN      44        10352
# mean                                  NaN     NaN          NaN
# std                                   NaN     NaN          NaN
# min                                   NaN     NaN          NaN
# 25%                                   NaN     NaN          NaN
# 50%                                   NaN     NaN          NaN
# 75%                                   NaN     NaN          NaN
# max                                   NaN     NaN          NaN
# % OF MISSING DATA:
# additional_ingredients_(no_rulebase)      6.383971
# benefit                                   0.000381
# brand                                     0.000381
# channel                                   0.000381
# collection_date                           1.233790
# product                                  20.873205
# description                              21.437202
# elc_solution_type                        14.856860
# feature                                   0.000381
# geography                                 0.139096
# ingredient                                0.000381
# normalized_product_title                141.774763
# number_of_reviews                         5.015651
# packaging                                 0.000381
# product_form                              0.000381
# productcluster_id                       141.774763
# product_id                                0.000190
# rating                                   87.751529
# skin_condition                            0.000381
# skin_type                                 0.000381
# solution_type                           182.291379
# source_product_identifier                 0.000190
# treatment_area                            0.000381
# use_case                                  0.000381
# cluster_title                           191.873424
# caf1a03ebf00d4078bbb0a590ec19a089       210.812981
# upc                                     206.079900
# c8285216327864eb388e64216dead18b1       210.812981
# c5bdcdac51d9e41dca007d69f7cd66c58       210.812981
# c886f108693fa44d3b90e50714f925352       210.812981
# c247b9901626441798fd9f5b0e1da5b6b       210.812981
# c592ee2bea9194edfa01db5a04de3e8ed       210.812981
# c39ee8c98ff6e4d2394de70aba44d3b53       210.812981
# ce9ff836616d54454a16e6e453cd8c3a0       210.812981
# c60e432d687a14313af9a796a9d1aa662       210.812981
# cdb3deb1d22ff4b3b95f7cf93a716e37f       210.812981
# c221108b649a940bfb30f51761418e985       210.812981
# cf1972cff60c14e5c9a0360d29728f326       210.812981
# c0f3a87d761e14a9a9355fd6cbf5e6a23       210.812981
# c12155d43bdc349f09c79baafbd50920c       210.812981
# cdcbef08d2dab47dd848b0b95f0fedbe2       210.812981
# c0fcd4ae2146440218fabd77b2fd0b9d2       210.812981
# cc7c0e57649784f21b4b637f729d6caf9       210.812981
# c0881be2cfa9840f4a01414ab5ecf5ff3       210.812981
# cf6a2c815ba954cb39cc42b31b4fee2f0       210.812981
# cff79bc48a3904424abc514711b240877       210.812981
# c9a2e8d1d2d564ee89ef2dc6bb2c613d4       210.812981
# c4587ff7e968142b69f6e308c49df39d3       210.812981
# cd96842a0c3c04ec385214879a168dfaa       210.812981
# c2771dfbcbc0d4e778de96df220c34b06       210.812981
# c73106569fb4d4913b88ae2b231d39064       210.812981
# c0b87f5c8b4c449bbbefa78e44454686a       210.812981
# c9a2fcedcc6564367861ae58adf7f62d1       210.812981
# c085c055e8cd4447aad82a1b1c15a5750       210.812981
# title                                   189.939966
# cluster_size                            203.693569
# dtype: float64

# %% [markdown]
# #### Data wrangling

# %% [markdown]
# Then we concatenate cosmetic and skincare, and add a columns *type* to keep track of the source of the data.
#
# **NB**: The columns are not exactly the same between the two types. By concatenting, we will have the union of the features of the two datasets and missing values will be filled with NaNs.

# %%
products_cosmetics['type'] = 'Cosmetics'
products_skincare['type'] = 'Skincare'
products = pd.concat([products_cosmetics, products_skincare], axis=0)

# %%
products.sample(4)
# Out:
#                        product_id source_product_identifier  \
# 98325   Product_20190807_10224389                B01D6VEGP4
# 556857  Product_20200416_17687678                B00HKMVFRI
# 401669  Product_20200416_18549208                B07RTJZ37J
# 688849  Product_20191007_12526247                   2902414
#
#                                                   product  \
# 98325                 Hera Signia Ampoule Set 10.2g x 4ea
# 556857      Dermalogica Precleanse Wipes PreCleanse Wipes
# 401669  Topgee Soap Scented Flower Decorative Soaps fo...
# 688849                     Pro-Collagen Eye Renewal Cream
#
#                                               description     channel  \
# 98325                 Hera Signia Ampoule Set 10.2g x 4ea  Amazon USA
# 556857  -A pack of gentle deep cleansing face wipes -H...   Amazon UK
# 401669  ☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺☺...  Amazon USA
# 688849  Free shipping and returns on Elemis Pro-Collag...   Nordstrom
#
#               brand                                    feature  \
# 98325          HERA                              Not Mentioned
# 556857  DERMALOGICA                            Water Resistant
# 401669      LANCOME                           Balances;Scented
# 688849       ELEMIS  Cruelty Free;Natural;Organic;Sulfate Free
#
#                                                   benefit  \
# 98325                                       Not Mentioned
# 556857                        Cleansing & Cleaning;Gentle
# 401669                              Easy to Use;Smoothing
# 688849  Anti Aging;Effective;Firming;Nourishing;Pore M...
#
#                                               ingredient  \
# 98325                                      Not Mentioned
# 556857                                     Not Mentioned
# 401669                                      Rose Extract
# 688849  Collagen;Antioxidants;Seaweed;Silicone;Vitamin A
#
#                      additional_ingredients_(no_rulebase)   product_form  \
# 98325                                       Not Mentioned  Not Mentioned
# 556857                                      Not Mentioned     Wipe/Cloth
# 401669                                      Essential Oil            Oil
# 688849  DEA;Mineral Oil;Parabens;Petrochemicals;Phthal...          Cream
#
#        elc_solution_type rating number_of_reviews geography collection_date  \
# 98325              Serum    NaN               0.0       USA        6/4/2019
# 556857          Cleanser    4.1               5.0        UK      2019-12-14
# 401669          Cleanser    NaN               0.0       USA      2020-02-27
# 688849         Eye Cream    4.4                 7       USA       10/2/2019
#
#                                  normalized_product_title  \
# 98325                                                 NaN
# 556857                  precleanse wipes precleanse wipes
# 401669  LANCOME CLEANSER TOPGEE SOAP SCENTED DECORATIV...
# 688849      ELEMIS  PEPTIDE4 EYE RECOVERY CREAM EYE CREAM
#
#               productcluster_id finish looks other trends cluster_size title  \
# 98325                       NaN    NaN   NaN   NaN    NaN          NaN   NaN
# 556857  DERMALOGICA_Cleanser_10    NaN   NaN   NaN    NaN          NaN   NaN
# 401669      LANCOME_Cleanser_12    NaN   NaN   NaN    NaN          NaN   NaN
# 688849       ELEMIS_Eye Cream_0    NaN   NaN   NaN    NaN            3   NaN
#
#        solution_type      type      packaging              skin_condition  \
# 98325            NaN  Skincare        Ampoule               Not Mentioned
# 556857           NaN  Skincare  Not Mentioned               Not Mentioned
# 401669           NaN  Skincare  Not Mentioned               Not Mentioned
# 688849           NaN  Skincare           Pump  Aging;Wrinkles and Sagging
#
#                               skin_type  treatment_area       use_case  \
# 98325                     Not Mentioned   Not Mentioned  Not Mentioned
# 556857                    Not Mentioned  Eyes;Face Area  Not Mentioned
# 401669                    Not Mentioned       Body Area  Not Mentioned
# 688849  All Skin Types;Mature;Sensitive            Eyes        Day Use
#
#                                             cluster_title  \
# 98325                                                 NaN
# 556857  DERMALOGICA CLEANSER PRECLEANSE WIPES PRECLEAN...
# 401669                                                NaN
# 688849                                                NaN
#
#         caf1a03ebf00d4078bbb0a590ec19a089  upc  \
# 98325                                 NaN  NaN
# 556857                                NaN  NaN
# 401669                                NaN  NaN
# 688849                                NaN  NaN
#
#         c8285216327864eb388e64216dead18b1  c5bdcdac51d9e41dca007d69f7cd66c58  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c886f108693fa44d3b90e50714f925352  c247b9901626441798fd9f5b0e1da5b6b  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c592ee2bea9194edfa01db5a04de3e8ed  c39ee8c98ff6e4d2394de70aba44d3b53  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         ce9ff836616d54454a16e6e453cd8c3a0  c60e432d687a14313af9a796a9d1aa662  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         cdb3deb1d22ff4b3b95f7cf93a716e37f  c221108b649a940bfb30f51761418e985  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         cf1972cff60c14e5c9a0360d29728f326  c0f3a87d761e14a9a9355fd6cbf5e6a23  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c12155d43bdc349f09c79baafbd50920c  cdcbef08d2dab47dd848b0b95f0fedbe2  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c0fcd4ae2146440218fabd77b2fd0b9d2  cc7c0e57649784f21b4b637f729d6caf9  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c0881be2cfa9840f4a01414ab5ecf5ff3  cf6a2c815ba954cb39cc42b31b4fee2f0  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         cff79bc48a3904424abc514711b240877  c9a2e8d1d2d564ee89ef2dc6bb2c613d4  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c4587ff7e968142b69f6e308c49df39d3  cd96842a0c3c04ec385214879a168dfaa  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c2771dfbcbc0d4e778de96df220c34b06  c73106569fb4d4913b88ae2b231d39064  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c0b87f5c8b4c449bbbefa78e44454686a  c9a2fcedcc6564367861ae58adf7f62d1  \
# 98325                                 NaN                                NaN
# 556857                                NaN                                NaN
# 401669                                NaN                                NaN
# 688849                                NaN                                NaN
#
#         c085c055e8cd4447aad82a1b1c15a5750
# 98325                                 NaN
# 556857                                NaN
# 401669                                NaN
# 688849                                NaN

# %%
product_columns = ['product_id', 'source_product_identifier', 'product', 'description',
       'channel', 'brand', 'feature', 'benefit', 'ingredient',
       'additional_ingredients_(no_rulebase)', 'product_form',
       'elc_solution_type', 'rating', 'number_of_reviews', 'geography',
       'collection_date', 'normalized_product_title', 'productcluster_id',
       'finish', 'looks', 'other', 'trends', 'cluster_size', 'title',
       'solution_type', 'type', 'packaging', 'skin_condition', 'skin_type',
       'treatment_area', 'use_case', 'cluster_title',]
products = products[product_columns]

# %% [markdown]
# We create Clean Collection Date (proper pandas date format) and fill the missing rows/bad format (if any exist) with the oldest date available.

# %%
products['clean_collection_date'] = pd.to_datetime(products['collection_date'], errors='coerce')
if products['clean_collection_date'].isna().sum()>0:
    print('{} rows where not processed properly. They will be assigned the oldest date available.'.format(products['clean_collection_date'].isna().sum()))
products.loc[products['clean_collection_date'].isna(), 'collection_date']=min(products['clean_collection_date'])
products['clean_collection_date'] = pd.to_datetime(products['collection_date'], errors='coerce')
# Out:
# 6625 rows where not processed properly. They will be assigned the oldest date available.

# %% [markdown]
# We drop the duplicates while only keeping the row with the most recent Collection Date.

# %%
products = products.sort_values(by=['clean_collection_date'], ascending=False).drop_duplicates(keep='first')

# %%
products.sample(2)
# Out:
#                        product_id source_product_identifier  \
# 413330  Product_20200416_18097195                B06Y23W4F5
# 210933   Product_20190305_3314113              121860000199
#
#                                                   product  \
# 413330  Clean and Clear Deep Acting 60 Second Shower M...
# 210933     'Mineral sunscreen' SPF 30 fluid for face 30ml
#
#                                               description     channel  \
# 413330  Clean and Clear Deep Acting 60 Second Shower M...  Amazon USA
# 210933  Ultra lightweight, 100% 'Mineral Sunscreen' is...   Debenhams
#
#                 brand                                           feature  \
# 413330  CLEAN & CLEAR                                     Not Mentioned
# 210933       Clinique  Lightweight Formula;SPF/UV Protection;Scent Free
#
#               benefit     ingredient additional_ingredients_(no_rulebase)  \
# 413330  Not Mentioned  Not Mentioned                        Not Mentioned
# 210933         Gentle  Not Mentioned                        Not Mentioned
#
#          product_form elc_solution_type rating number_of_reviews geography  \
# 413330  Not Mentioned         Face Mask    NaN               0.0       USA
# 210933  Not Mentioned            In Sun    NaN               0.0        UK
#
#        collection_date                           normalized_product_title  \
# 413330      2020-04-02  CLEAN & CLEAR FACE MASK BLACKHEAD ING 2 IN 1 W...
# 210933      2019-02-01                                                NaN
#
#                 productcluster_id finish looks other trends cluster_size  \
# 413330  CLEAN & CLEAR_Face Mask_0    NaN   NaN   NaN    NaN          NaN
# 210933                        NaN    NaN   NaN   NaN    NaN          NaN
#
#        title solution_type      type      packaging skin_condition  \
# 413330   NaN           NaN  Skincare  Not Mentioned  Not Mentioned
# 210933   NaN     Sunscreen  Skincare  Not Mentioned  Not Mentioned
#
#             skin_type  treatment_area       use_case cluster_title  \
# 413330  Not Mentioned   Not Mentioned  Not Mentioned           NaN
# 210933      Sensitive  Eyes;Face Area  Not Mentioned           NaN
#
#        clean_collection_date
# 413330            2020-04-02
# 210933            2019-02-01

# %%
products[['type', 'channel', 'source_product_identifier', 'brand', 'product', 'elc_solution_type']].isna().sum()
# Out:
# type                              0
# channel                           2
# source_product_identifier         1
# brand                             2
# product                      109696
# elc_solution_type             89580
# dtype: int64

# %%
nb_products = len(products[['type', 'channel', 'source_product_identifier']].drop_duplicates().dropna())
nb_products_with_brand = len(products[['type', 'channel', 'source_product_identifier', 'brand']].dropna().drop_duplicates(subset=['type', 'channel', 'source_product_identifier',]))
nb_products_with_product = len(products[['type', 'channel', 'source_product_identifier', 'product']].dropna().drop_duplicates(subset=['type', 'channel', 'source_product_identifier',]))
nb_products_with_elc_solution_type = len(products[['type', 'channel', 'source_product_identifier', 'elc_solution_type']].dropna().drop_duplicates(subset=['type', 'channel', 'source_product_identifier',]))

print("Number of products IDs: {}".format(nb_products))
print("Number of products IDs with brand: {}".format(nb_products_with_brand))
print("Number of products IDs with product_name: {}".format(nb_products_with_product))
print("Number of products IDs with elc_solution_type: {}".format(nb_products_with_elc_solution_type))
# Out:
# Number of products IDs: 377209
# Number of products IDs with brand: 377209
# Number of products IDs with product_name: 377209
# Number of products IDs with elc_solution_type: 353442

# %%
# Saving dataset
products.to_csv(os.path.join(output_product_dir_path,'products_wrangled.csv'), index=False)

# %%
# If the wrangled files already exist
products = pd.read_csv(os.path.join(output_product_dir_path,'products_wrangled.csv'), low_memory=False)
products.sample(10)
# Out:
#                         product_id source_product_identifier  \
# 1604969    Product_20181119_197311                B07FLJ5W5D
# 1541925   Product_20190211_3205586                B00EOP1CU4
# 1391058  Product_20190807_10571826                B075V1LS6J
# 385320   Product_20200416_18729657                B00547F7KM
# 1346876  Product_20190807_11572161                B07D811M8D
# 314460    Product_20200413_6817375                B0017K9WZQ
# 1219791  Product_20190807_11832196                B017RMIX3Y
# 1583305    Product_20181119_308915                B01M6D9IG6
# 1574920   Product_20190211_3164399                B06XD579MJ
# 97945    Product_20200416_18805917                   9208505
#
#                                                    product  \
# 1604969  Bath and Body Works 3 Pack Nourishing Shea But...
# 1541925     [HERA] White Program Radiance Emulsion / 120ml
# 1391058  AVON Anew Clinical Defend & Repair Advanced Hy...
# 385320   Suki Transformative Purifying Masque 7.5 ML (P...
# 1346876  MD Complete by Dr. Brian Zelickson 2% Hydroqui...
# 314460   Revlon Make A Sheen Lustrous Shadow, Espresso'...
# 1219791       Biotherm Wet Or Dry Solar with SPF 15 200 ml
# 1583305  EsteÌe Lauder Re-Nutriv Ultimate Lift Rejuven...
#         elc_solution_type  rating number_of_reviews geography collection_date  \
# 1604969         Face Mask     NaN               0.0       USA       11/5/2018
# 1541925               NaN     NaN               0.0        UK        2/8/2019
# 1391058         Face Mask     NaN               0.0       USA      2019-06-04
# 385320          Face Mask     2.8              24.0       USA      2019-12-06
# 1346876             Serum     3.4              27.0       USA        6/4/2019
# 314460          Eyeshadow     4.0               7.0       USA      2019-12-13
# 1219791            In Sun     5.0               1.0        UK      2019-06-30
# 1583305  Face Moisturizer     NaN               0.0        UK       11/5/2018
# 1574920          Cleanser     NaN               0.0        UK      12/26/2018
# 97945               Toner  4.9259              27.0       USA      2020-04-02
#
#                                   normalized_product_title  \
# 1604969                                                NaN
# 1541925                                                NaN
# 1391058                                                NaN
# 385320    transformative purifying masque (purse friendly)
# 1346876                                                NaN
# 314460   REVLON EYESHADOW COLORSTAY LOOKS BOOK EYESHADO...
# 1219791                                                NaN
# 1583305                                                NaN
# 1574920                                                NaN
# 97945            collagenr8 restorative coq10 facial toner
#
#                       productcluster_id         finish          looks  \
# 1604969                             NaN            NaN            NaN
# 1541925                             NaN            NaN            NaN
# 1391058                             NaN            NaN            NaN
# 385320                 SUKI_Face Mask_1            NaN            NaN
# 1346876                             NaN            NaN            NaN
# 314460              REVLON_Eyeshadow_15  Not Mentioned  Not Mentioned
# 1219791                             NaN            NaN            NaN
# 1583305                             NaN            NaN            NaN
# 1574920                             NaN            NaN            NaN
# 97945    HERBAL DYNAMICS BEAUTY_Toner_0            NaN            NaN
#
#                  other         trends cluster_size title    solution_type  \
# 1604969            NaN            NaN          NaN   NaN  Mask;Sheet Mask
# 1541925            NaN            NaN          NaN   NaN      Night Cream
# 1391058            NaN            NaN          NaN   NaN              NaN
# 385320             NaN            NaN          NaN   NaN              NaN
# 1346876            NaN            NaN          NaN   NaN              NaN
# 314460   Not Mentioned  Not Mentioned          NaN   NaN              NaN
# 1219791            NaN            NaN          NaN   NaN              NaN
# 1583305            NaN            NaN          NaN   NaN  Wash & Cleanser
# 1574920            NaN            NaN          NaN   NaN  Wash & Cleanser
# 97945              NaN            NaN          NaN   NaN              NaN
#
#               type      packaging                      skin_condition  \
# 1604969   Skincare  Not Mentioned                       Not Mentioned
# 1541925   Skincare  Not Mentioned                             Dryness
# 1391058   Skincare  Not Mentioned                       Not Mentioned
# 385320    Skincare  Not Mentioned  Blackheads;Blemish;Dryness;Redness
# 1346876   Skincare      Pump;Tube               Dark Spots;Irritation
# 314460   Cosmetics            NaN                                 NaN
# 1219791   Skincare  Not Mentioned                       Not Mentioned
# 1583305   Skincare  Not Mentioned                       Not Mentioned
# 1574920   Skincare  Not Mentioned                       Not Mentioned
# 97945     Skincare  Not Mentioned                       Aging;Redness
#
#               skin_type       treatment_area       use_case  \
# 1604969   Not Mentioned  Body Area;Face Area  Not Mentioned
# 1541925             Dry        Not Mentioned  Not Mentioned
# 1391058   Not Mentioned        Not Mentioned  Not Mentioned
# 385320    Dry;Sensitive        Not Mentioned  Not Mentioned
# 1346876   Not Mentioned        Not Mentioned  Not Mentioned
# 314460              NaN                  NaN            NaN
# 1219791   Not Mentioned                Hands  Not Mentioned
# 1583305          Mature        Not Mentioned  Not Mentioned
# 1574920  All Skin Types        Not Mentioned  Not Mentioned
# 97945     Not Mentioned            Face Area  Not Mentioned
#
#                                              cluster_title  \
# 1604969                                                NaN
# 1541925                                                NaN
# 1391058                                                NaN
# 385320                 SUKI FACE MASK MOISTURE RICH MASQUE
# 1346876                                                NaN
# 314460                                                 NaN
# 1219791                                                NaN
# 1583305                                                NaN
# 1574920                                                NaN
# 97945    HERBAL DYNAMICS BEAUTY TONER COLLAGENR8 RESTOR...
#
#         clean_collection_date
# 1604969            2018-11-05
# 1541925            2019-02-08
# 1391058            2019-06-04
# 385320             2019-12-06
# 1346876            2019-06-04
# 314460             2019-12-13
# 1219791            2019-06-30
# 1583305            2018-11-05
# 1574920            2018-12-26
# 97945              2020-04-02

# %% [markdown]
# ### Mapping Brands

# %% [markdown]
# The brands displayed in the Product Catalogue data are not the official Estée Lauder format. We have a mapping of Estée Lauder brands and brands abbreviation, which we will map to the Product Catalogue brands. To do so, we will calculate a similarity score between each possible pair (Product Catalogue brand, official brand), and select the most similar ELC Brand. The Product Calatogue contains brands that are not part of ELC. We don't care about that data for now, so we will just change the brand to a missing value (NaN).

# %%
elc_brands = pd.read_csv(os.path.join(input_mappings_dir_path,'elc_brands.csv'), encoding = "ISO-8859-1")

# %%
# Estée Lauder brands
# A better way to get these, is from the Demand data (get brand_abbrev then manually add elc_brand).
# OR ask Anurag to update the full list (I feel like some brands are missing...)
elc_brands
# Out:
#    brand_abbrev          elc_brand
# 0            AR             Aramis
# 1            AV              Aveda
# 2            BA              BECCA
# 3            BB        Bobbi Brown
# 4            BU  Bumble and bumble
# 5            CL           Clinique
# 6            CM             La Mer
# 7            DA            Darphin
# 8            EL       Estée Lauder
# 9            FM     Frédéric Malle
# 10           GG           GlamGlow
# 11           IM          Non-brand
# 12           JM   Jo Malone London
# 13           KL          By Kilian
# 14           LL            Le Labo
# 15           MC              M.A.C
# 16           OR            Origins
# 17           PR      Prescriptives
# 18           SX           Smashbox
# 19           TF    Tom Ford Beauty

# %%
# Brands from Product Catalogue
brands_to_map = pd.DataFrame({'brand' : products['brand'].unique()})
brands_to_map
# Out:
#                                   brand
# 0                                 CIATE
# 1                            L'OCCITANE
# 2                                  DIOR
# 3                               KIEHL'S
# 4                               LANCOME
# ...                                 ...
# 7223                          Babe;Lano
# 7224                  Aveeno;Botanicals
# 7225  Phyto;Tarte Cosmetics;Ulta Beauty
# 7226             Anese;Artisan;Skinfood
# 7227                  VINTNERS DAUGHTER
#
# [7228 rows x 1 columns]

# %% [markdown]
# We create all possible combinations between PC Brands and EL Brands.

# %%
brand_matching = brands_to_map.assign(key=0).merge(elc_brands.assign(key=0), on='key', how='left').drop('key', axis=1)
brand_matching
# Out:
#                     brand brand_abbrev          elc_brand
# 0                   CIATE           AR             Aramis
# 1                   CIATE           AV              Aveda
# 2                   CIATE           BA              BECCA
# 3                   CIATE           BB        Bobbi Brown
# 4                   CIATE           BU  Bumble and bumble
# ...                   ...          ...                ...
# 144555  VINTNERS DAUGHTER           MC              M.A.C
# 144556  VINTNERS DAUGHTER           OR            Origins
# 144557  VINTNERS DAUGHTER           PR      Prescriptives
# 144558  VINTNERS DAUGHTER           SX           Smashbox
# 144559  VINTNERS DAUGHTER           TF    Tom Ford Beauty
#
# [144560 rows x 3 columns]

# %% [markdown]
# Then we define a function that will calculate the similarity of the pair.

# %%
def brands_custom_distance(row):
    """
    Calculates a distance score between two sentences. In this case elc_brand and brand. The score is between 0 and 1, 1 being a good match.
    """
#     jaccard = textdistance.jaccard(str(row['brand']).lower().replace('.','').replace('&','and'), str(row['elc_brand']).lower().replace('.','').replace('é','e'))
    jaro = textdistance.jaro_winkler(str(row['brand']).lower().replace('.','').replace('&','and'), str(row['elc_brand']).lower().replace('.','').replace('é','e'))
    fuzzi = fuzz.partial_ratio(str(row['brand']).lower().replace('.','').replace('&','and'), str(row['elc_brand']).lower().replace('.','').replace('é','e'))/100
    return np.average([fuzzi,jaro], weights=[0.4,0.6])

# %% [markdown]
# and we apply it to our dataset:

# %%
# Calculate the matching score between brand and elc_brand
brand_matching['brand_score'] = brand_matching.progress_apply(lambda row : brands_custom_distance(row), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=144560.0), HTML(value='')))

# %%
# Sorting values
brand_matching = brand_matching.sort_values('brand_score', ascending=False)

# %%
brand_matching
# Out:
#                     brand brand_abbrev          elc_brand  brand_score
# 54463         Bobbi Brown           BB        Bobbi Brown          1.0
# 2607              DARPHIN           DA            Darphin          1.0
# 7484    BUMBLE AND BUMBLE           BU  Bumble and bumble          1.0
# 53927             Darphin           DA            Darphin          1.0
# 58444     Bumble & Bumble           BU  Bumble and bumble          1.0
# ...                   ...          ...                ...          ...
# 53742             Origins           BA              BECCA          0.0
# 141487               STMT           DA            Darphin          0.0
# 1495             BY TERRY           MC              M.A.C          0.0
# 141491               STMT           IM          Non-brand          0.0
# 32053            RETROUVÉ           KL          By Kilian          0.0
#
# [144560 rows x 4 columns]

# %%
# OPTIONAL SAVE
brand_matching.to_csv('../data/clean_data/brand_mapping_scores.csv', index=False)

# %% [markdown]
# Finally, we keep the most simialr ELC Brand.

# %%
# Keep the elc_brand that has the highest score
brand_matching = brand_matching.groupby('brand').apply(lambda x: x.nlargest(1,'brand_score')).reset_index(drop=True).sort_values('brand_score', ascending=False)
brand_matching
# Out:
#                  brand brand_abbrev          elc_brand  brand_score
# 3682  JO MALONE LONDON           JM   Jo Malone London     1.000000
# 1555          Clinique           CL           Clinique     1.000000
# 994              Becca           BA              BECCA     1.000000
# 5228           Origins           OR            Origins     1.000000
# 3268          Glamglow           GG           GlamGlow     1.000000
# ...                ...          ...                ...          ...
# 3392            HOKKUU           BU  Bumble and bumble     0.358196
# 1796             Ddfâ®           DA            Darphin     0.348571
# 13              0 100%           CM             La Mer     0.338667
# 1701            DL1961           EL       Estée Lauder     0.338000
# 44                  17           PR      Prescriptives     0.000000
#
# [7227 rows x 4 columns]

# %% [markdown]
# All brands, including the non-ELC brands have been mapped to an ELC brand. If our similarity function did a great job, all non-ELC brands will have a low score compared to ELC brands. Therefore, we can set a score threshhold, and all brands below that threshhold will be mapped to NaN.
#
# The way I do it is to start with a small threshhold, then select the threshhold for which all non-elc brand get filtered-out.

# %% [markdown]
# Some brands have a huge resemblance with ELC brands (PARAMISS/ARAMIS, BIORIGINS/ORIGINS). Because of that, we will keep a list of these non-ELC brands and they will get filtered out even if their threshhold is high.

# %%
brands_to_filter_out = [
    "MACY'S",
    'Original Mineral',
    'Original Source',
    'Original Sprout',
    'ORIGINAL SOURCE',
    'Bobbi Boss',
    'Bobbi',
    'PARAMISS',
    'REBECCA',
    'BIORIGINS',
    'LA PERLA',
    'LES LABORATOIRES DE BIARRITZ',
    'NATORIGIN',
    'ORVEDA',
    'YILIAN',
    'LAVERA',
    'PuraVeda Organics',
    'Rebecca Taylor',
    'MACRENE ACTIVES',
    "Macy's Beauty Collection Company",
    "Macy'S Beauty Collection",
    'Rebecca Minkoff',
    'REBECCA DANIELL',
    'No_Brand',
    'B.',
]
brands_to_filter_out = [brand.lower() for brand in brands_to_filter_out]

# %%
# Run this cell with different threshhold until satisfied with the result.
pd.set_option('display.max_rows', 306)
brand_thresh = 0.815
display(brand_matching.loc[(brand_matching['brand_score']>brand_thresh) & (~brand_matching['brand'].str.lower().isin(brands_to_filter_out))])
pd.set_option('display.max_rows', 100)
# Out:
#                                                   brand brand_abbrev  \
# 3682                                   JO MALONE LONDON           JM
# 1555                                           Clinique           CL
# 994                                               Becca           BA
# 5228                                            Origins           OR
# 3268                                           Glamglow           GG
# 2708                                       ESTEE LAUDER           EL
# 5997                                           SMASHBOX           SX
# 4441                                                MAC           MC
# 1631                                            DARPHIN           DA
# 5369                                      PRESCRIPTIVES           PR
# 1788                                            Darphin           DA
# 1113                                        Bobbi Brown           BB
# 3186                                           GLAMGLOW           GG
# 1219                                    Bumble & Bumble           BU
# 2829                                       Estee Lauder           EL
# 1368                                           CLINIQUE           CL
# 3065                                     Frederic Malle           FM
# 4330                                            Le Labo           LL
# 879                                   BUMBLE AND BUMBLE           BU
# 878                                     BUMBLE & BUMBLE           BU
# 529                                               Aveda           AV
# 5155                                            ORIGINS           OR
# 298                                               AVEDA           AV
# 244                                              ARAMIS           AR
# 6688                                    Tom Ford Beauty           TF
# 4115                                            LE LABO           LL
# 4017                                             LA MER           CM
# 6553                                    TOM FORD BEAUTY           TF
# 3734                                   Jo Malone London           JM
# 4233                                             La Mer           CM
# 708                                               BECCA           BA
# 2926                                     FREDERIC MALLE           FM
# 6348                                           Smashbox           SX
# 811                                         BOBBI BROWN           BB
# 5526                                      Prescriptives           PR
# 3683                                  JO MALONE LONDON™           JM
# 3273                                          Glamgloww           GG
# 5246                                           Originss           OR
# 4238                                            La Merr           CM
# 3735                                Jo Malone Londonâ„¢           JM
# 48                                            1clinique           CL
# 5158                                          ORIGINSTM           OR
# 3188                                        GLAMGLOW(R)           GG
# 1563                                        Clinique co           CL
# 2355    Tom Ford Beauty     0.850115
# 2361    Tom Ford Beauty     0.850115
# 2372    Tom Ford Beauty     0.850115
# 2371    Tom Ford Beauty     0.850115
# 2369    Tom Ford Beauty     0.850115
# 2370    Tom Ford Beauty     0.850115
# 2374    Tom Ford Beauty     0.850115
# 2350    Tom Ford Beauty     0.850115
# 2360    Tom Ford Beauty     0.850115
# 2351    Tom Ford Beauty     0.850115
# 2364    Tom Ford Beauty     0.850115
# 2357    Tom Ford Beauty     0.850115
# 2375    Tom Ford Beauty     0.850115
# 2362    Tom Ford Beauty     0.850115
# 4443              M.A.C     0.840000
# 414            Clinique     0.839286
# 4657              M.A.C     0.837500
# 4442              M.A.C     0.837500
# 4656              M.A.C     0.837500
# 4437              M.A.C     0.815789

# %%
# All matching that have a score below the threshhold will be unmatched
brand_matching.loc[(brand_matching['brand_score']<brand_thresh) | (brand_matching['brand'].str.lower().isin(brands_to_filter_out)), 'brand_abbrev'] = np.nan
brand_matching.loc[(brand_matching['brand_score']<brand_thresh) | (brand_matching['brand'].str.lower().isin(brands_to_filter_out)), 'elc_brand'] = np.nan
brand_matching.loc[(brand_matching['brand_score']<brand_thresh) | (brand_matching['brand'].str.lower().isin(brands_to_filter_out)), 'brand_score'] = 0

# %% [markdown]
# Finally, we need to manually check that we didn't miss anything. This can also be done on Excel.

# %%
# SAVING TO CSV
brand_matching.to_csv(os.path.join(output_mappings_dir_path,'brand_mapping_to_check.csv'), index=False)

# %%
# We manually check that we didn't miss anything
pd.set_option('display.max_rows', len(brand_matching)+1)
display(brand_matching)
pd.set_option('display.max_rows', 100)
# Out:
#                                                   brand brand_abbrev  \
# 3682                                   JO MALONE LONDON           JM
# 1555                                           Clinique           CL
# 994                                               Becca           BA
# 5228                                            Origins           OR
# 3268                                           Glamglow           GG
# 2708                                       ESTEE LAUDER           EL
# 5997                                           SMASHBOX           SX
# 4441                                                MAC           MC
# 1631                                            DARPHIN           DA
# 5369                                      PRESCRIPTIVES           PR
# 1788                                            Darphin           DA
# 1113                                        Bobbi Brown           BB
# 3186                                           GLAMGLOW           GG
# 1219                                    Bumble & Bumble           BU
# 2829                                       Estee Lauder           EL
# 1368                                           CLINIQUE           CL
# 3065                                     Frederic Malle           FM
# 4330                                            Le Labo           LL
# 879                                   BUMBLE AND BUMBLE           BU
# 878                                     BUMBLE & BUMBLE           BU
# 529                                               Aveda           AV
# 5155                                            ORIGINS           OR
# 298                                               AVEDA           AV
# 244                                              ARAMIS           AR
# 6688                                    Tom Ford Beauty           TF
# 4115                                            LE LABO           LL
# 4017                                             LA MER           CM
# 6553                                    TOM FORD BEAUTY           TF
# 3734                                   Jo Malone London           JM
# 4233                                             La Mer           CM
# 708                                               BECCA           BA
# 2926                                     FREDERIC MALLE           FM
# 6348                                           Smashbox           SX
# 811                                         BOBBI BROWN           BB
# 5526                                      Prescriptives           PR
# 3683                                  JO MALONE LONDON™           JM
# 3273                                          Glamgloww           GG
# 5246                                           Originss           OR
# 4238                                            La Merr           CM
# 3735                                Jo Malone Londonâ„¢           JM
# 4443                                    MAC;Ulta Beauty           MC
# 603                                                  B.          NaN
# 414                                      Anese;Clinique           CL
# 4657                                   Mac Strobe Cream           MC
# 4442                                   MAC PREP + PRIME           MC
# 4656                                   Mac Professional           MC
# 5716                                     Rebecca Taylor          NaN
# 5715                                    Rebecca Minkoff          NaN
# 5610                                    REBECCA DANIELL          NaN
# 4660                           Macy's Beauty Collection          NaN
# 4659                           Macy'S Beauty Collection          NaN
# 4353                       Les Laboratoires de Biarritz          NaN
# 4132                       LES LABORATOIRES DE BIARRITZ          NaN
# 4661                   Macy's Beauty Collection Company          NaN
# 4437           M.A.C Palette Eyeshadow X15 Warm Neutral           MC
# 5666                                         RMS Beauty          NaN
# 5772                                         Rms Beauty          NaN
# 5665                                         RMS BEAUTY          NaN
# 5159                                             ORVEDA          NaN
# 4106                                             LAVERA          NaN
# 4324                                             Lavera          NaN
# 592                                       Ayurveda Pura          NaN
# 316                                       AYURVEDA PURA          NaN
# 6717                                     Triple Lanolin          NaN
# 6578                                     TRIPLE LANOLIN          NaN
# 4118                                         LE PARADIS          NaN
# 4446                                         MAD BEAUTY          NaN
# 7168                                         mad beauty          NaN
# 6757                                    URBANVEDA.CO.UK          NaN
# 6780                                    Urbanveda.co.uk          NaN
# 4135                                   LETI LABORATORIO          NaN
# 4316                                      Laura Mercier          NaN
# 4102                                      LAURA MERCIER          NaN
# 7145                                           freederm          NaN
# 3067                                           Freederm          NaN
# 6150                                        Sara Miller          NaN
# 5834                                        SARA MILLER          NaN
# 1176                     Botanicals;Origins;Ulta Beauty          NaN
# 2527                                        Dove Beauty          NaN
# 1708                                        DOLL BEAUTY          NaN
# 4231                                             La Mav          NaN
# 4015                                             LA MAV          NaN
# 5118                                         OGX BEAUTY          NaN
# 5357                                         POP BEAUTY          NaN
# 5260                                         Own Beauty          NaN
# 5519                                         Pop Beauty          NaN
# 6554                                  TOM FORD SKINCARE          NaN
# 477                                              Armani          NaN
# 959                                    Bave de Escargot          NaN
# 669                                    BAVE DE ESCARGOT          NaN
# 5674                                        ROEN BEAUTY          NaN
# 4227                                        La Cremerie          NaN
# 4012                                        LA CREMERIE          NaN
# 3651                                              J.ONE          NaN
# 4326                                           Laverana          NaN
# 4108                                           LAVERANA          NaN
# 1020  Benefit Cosmetics;Bumble & Bumble;Kiehl's;W3ll...          NaN
# 6714                                        Tria Beauty          NaN
# 3042                                      Flower Beauty          NaN
# 2909                                      FLOWER BEAUTY          NaN
# 2910                                      FLOWER Beauty          NaN
# 5883                             SHEAORIGINS BLACK SOAP          NaN
# 6209                             SheaOrigins Black Soap          NaN
# 1374                                               CLIO          NaN
# 1389                                       CODEX BEAUTY          NaN
# 6749                                        UOMA Beauty          NaN
# 1709                                        DOME BEAUTY          NaN
# 6748                                        UOMA BEAUTY          NaN
# 2515                                        Dome Beauty          NaN
# 4720                                        Marula Glow          NaN
# 3007                                    Farmacy Coconut          NaN
# 4343                                   Leaders Labotica          NaN
# 368                                    Ali Mac Skincare          NaN
# 156                                    ALI MAC SKINCARE          NaN
# 4244                               La Sapomeria Firenze          NaN
# 2836                                    Estelle & Thild          NaN
# 2709                                    ESTELLE & THILD          NaN
# 6568                                    TOWER 28 BEAUTY          NaN
# 2984                                          FREZYDERM          NaN
# 2872                                 FARMACY DEW IT ALL          NaN
# 516                                                Aura          NaN
# 287                                                AURA          NaN
# 4013                                           LA FEMME          NaN
# 4228                                           La Fresh          NaN
# 4003                                         L.A. Fresh          NaN
# 4014                                           LA FRESH          NaN
# 1116                                       Bobbi Jean'S          NaN
# 4261                                             Lancer          NaN
# 4247                                         Lab Series          NaN
# 4028                                         LAB SERIES          NaN
# 4004                                          L.A. GIRL          NaN
# 4043                                             LANCER          NaN
# 4066                                             LANDER          NaN
# 4037                                LAFACE LABORATORIES          NaN
# 4256                                Laface Laboratories          NaN
# 4844                                    Montana Farmacy          NaN
# 3117                                       Fresh beauty          NaN
# 2908                                       FLOSS BEAUTY          NaN
# 5146                                   ORGANIC PHARMACY          NaN
# 472                           Argan Macadamia cosmetics          NaN
# 250                           ARGAN MACADAMIA COSMETICS          NaN
# 222                                   ANTICA FARMACISTA          NaN
# 446                                   Antica Farmacista          NaN
# 1169                         Botanicals;MAC;Ulta Beauty          NaN
# 4029                        LAB. FARMACOLOGICO MILANESE          NaN
# 543                                              Aviela          NaN
# 488                                               Artis          NaN
# 265                                               ARTIS          NaN
# 306                                              AVIELA          NaN
# 4525                                            MAYCOOP          NaN
# 4694                                            Mancave          NaN
# 4479                                            MANCAVE          NaN
# 7151                                        goop Beauty          NaN
# 6527                               THE ORGANIC PHARMACY          NaN
# 6666                               The Organic Pharmacy          NaN
# 4054                    LANCOME;MYCHELLE DERMACEUTICALS          NaN
# 5682                                       ROSEA BEAUTY          NaN
# 2873                 FARMACY DEW IT ALL TOTAL EYE CREAM          NaN
# 4651                            MYCHELLE DERMACEUTICALS          NaN
# 4867                            Mychelle Dermaceuticals          NaN
# 106                                                ACME          NaN
# 324                                                Acme          NaN
# 4486                                               MARA          NaN
# 4704                                               Mara          NaN
# 864              BRAZILIAN MIRACLE GALVANIC SPA MACHINE          NaN
# 4405                                 Lou Lei Botanicals          NaN
# 4193                                 LOU LEI BOTANICALS          NaN
# 6167                                       Savor Beauty          NaN
# 5843                                       SAVOR BEAUTY          NaN
# 4458                            MAGIS LENE LABORATORIES          NaN
# 4668                            Magis Lene Laboratories          NaN
# 1251                                   By Holika Holika          NaN
# 5429                                         PYT Beauty          NaN
# 5428                                         PYT BEAUTY          NaN
# 4301                                            Lao Wei          NaN
# 266                                             ARTISAN          NaN
# 490                                             Artisan          NaN
# 6660                                The Laboratoire ACM          NaN
# 3326                                        H2O+ BEAUTY          NaN
# 3327                                        H2O+ Beauty          NaN
# 6242                                        Show Beauty          NaN
# 574                                         Avon beauty          NaN
# 4182                                        LOLI BEAUTY          NaN
# 5890                                        SHOW BEAUTY          NaN
# 4560                                             MELLOW          NaN
# 891                                              BY YSL          NaN
# 4492                                           MARCELLE          NaN
# 4752                                           May Coop          NaN
# 4711                                           Marcelle          NaN
# 4521                                           MAY COOP          NaN
# 290                                         AURA ME SUN          NaN
# 3315                                       Grown Beauty          NaN
# 1516                                            Clarins          NaN
# 1527                                          Clarins..          NaN
# 1350                                            CLARINS          NaN
# 5677                                            ROLL ME          NaN
# 289                                             AURA ME          NaN
# 2896                                   FIRST AID BEAUTY          NaN
# 3026                                   First Aid Beauty          NaN
# 4323                              Lavanila Laboratories          NaN
# 5558                                          Pure Lano          NaN
# 6898                                          WAR PAINT          NaN
# 6668                                          The Sabon          NaN
# 6518                                          THE LANO           NaN
# 6531                                          THE SABON          NaN
# 3010                                            Farsali          NaN
# 2875                                            FARSALI          NaN
# 2994                                      FUSION BEAUTY          NaN
# 3151                                      Fusion Beauty          NaN
# 3175                                               GIGI          NaN
# 80                                                 3Lab          NaN
# 6890                                              W.Lab          NaN
# 6889                                              W.LAB          NaN
# 79                                                 3LAB          NaN
# 1642                                         DEARKLAIRS          NaN
# 483                                            Arquiste          NaN
# 1800                                         DearKlairs          NaN
# 2567                            Dr PAWPAW Original Balm          NaN
# 2601                           Dr. PAWPAW ORIGINAL BALM          NaN
# 2837                  Estã©E Lauder;Est&Eacute;E Lauder          NaN
# 355                                        Alambika Usa          NaN
# 4216                                      LUXE BOTANICS          NaN
# 4217                                      LUXE Botanics          NaN
# 3411                                        HUDA BEAUTY          NaN
# 3497                                        Huda Beauty          NaN
# 4336                                            Leaders          NaN
# 4122                                            LEADERS          NaN
# 4325                                   Lavera Skin Care          NaN
# 4107                                   LAVERA SKIN CARE          NaN
# 6136                Sally Hansen/Del Laboratories, Inc.          NaN
# 540                                               Avene          NaN
# 4763                                         Me Factory          NaN
# 4751                                         Max Factor          NaN
# 302                                               AVENE          NaN
# 4519                                         MAX FACTOR          NaN
# 4539                                         ME FACTORY          NaN
# 2885                                       FENTY BEAUTY          NaN
# 3019                                       Fenty Beauty          NaN
# 4793                                Michael Todd Beauty          NaN
# 396                                               Amika          NaN
# 3680                                           JO LOVES          NaN
# 3733                                           Jo Loves          NaN
# 4320                               Laura Mercier beauty          NaN
# 6346                              Slip For Beauty Sleep          NaN
# 5995                              SLIP FOR BEAUTY SLEEP          NaN
# 3921                              Kiehl"s Original Musk          NaN
# 537                                         Aveeno Baby          NaN
# 4490                                        MARC JACOBS          NaN
# 375                                      Alora Ambiance          NaN
# 6061                                            STELLAR          NaN
# 6404                                            Stellar          NaN
# 619                                          BABY BLING          NaN
# 6062                                       STEVE MADDEN          NaN
# 4522                                         MAY ISLAND          NaN
# 4753                                         May Island          NaN
# 5276                                         PANCHAVEDA          NaN
# 5441                                         Panchaveda          NaN
# 7144                                           farsalii          NaN
# 3011                                           Farsalii          NaN
# 5273                                           PALMER'S          NaN
# 1353                                           CLARISMA          NaN
# 5437                                           Palmer's          NaN
# 963                               Be Care Love Naturals          NaN
# 4602                                       MIRACLE SKIN          NaN
# 4707                                       Marc Anthony          NaN
# 1667                                       DERMADOCTOR®          NaN
# 4457                                       MAGICSTRIPES          NaN
# 4667                                       Magicstripes          NaN
# 4995                                       Natura Bisse          NaN
# 4815                                       Miracle Skin          NaN
# 4650                                       MY PROACTIVE          NaN
# 4997                                       Natura Bissé          NaN
# 5375                                          PRIMAGLOW          NaN
# 4888                                       NATURA BISSE          NaN
# 7175                                       my proactive          NaN
# 4489                                       MARC ANTHONY          NaN
# 3542                                        INDEED LABS          NaN
# 7156                                        indeed labs          NaN
# 3605                                        Indeed Labs          NaN
# 3604                 Indeed Laboratories Retinol Reface          NaN
# 6999                                          YIZHILIAN          NaN
# 6289                                               Skii          NaN
# 5377                                      PRIMAL BEAUTY          NaN
# 6968                                       Woosh Beauty          NaN
# 3646                                      J. CAT BEAUTY          NaN
# 1464                                             Catrin          NaN
# 1303                                             CATRIN          NaN
# 3772                                             KAHINA          NaN
# 2671                                            ELTA MD          NaN
# 2795                                            Elta MD          NaN
# 3882                                             Kahina          NaN
# 6916                                            WHAMISA          NaN
# 6955                                            Whamisa          NaN
# 5281                                            PARFAIT          NaN
# 906                                  Babé Laboratorios          NaN
# 121                                               AERIN          NaN
# 337                                               Aerin          NaN
# 4710                                      Marc New York          NaN
# 1832                                      Dermadoctorâ®          NaN
# 6120                                              Sabon          NaN
# 301                                              AVEENO          NaN
# 536                                              Aveeno          NaN
# 3843                                         KNC Beauty          NaN
# 7008                                         YSL BEAUTY          NaN
# 231                                          APA BEAUTY          NaN
# 1450                                         Cap Beauty          NaN
# 6944                                         Wei Beauty          NaN
# 7009                                         YSL Beauty          NaN
# 3842                                         KNC BEAUTY          NaN
# 456                                          Apa Beauty          NaN
# 3522                                         IBY Beauty          NaN
# 3835                                         KKW BEAUTY          NaN
# 3521                                         IBY BEAUTY          NaN
# 2516                                Dominique Cosmetics          NaN
# 1710                                DOMINIQUE COSMETICS          NaN
# 3965                                      Kopari Beauty          NaN
# 3855                                      KOPARI BEAUTY          NaN
# 6662                                      The Laundress          NaN
# 6520                                      THE LAUNDRESS          NaN
# 291                                          AURA;SK-II          NaN
# 519                                          Aura;SK-II          NaN
# 4008                                         L:A Bruket          NaN
# 4007                                         L:A BRUKET          NaN
# 4009                                         L:a Bruket          NaN
# 732                                               BERTA          NaN
# 560                                        Avon K Brand          NaN
# 3194                                      GLOSS MODERNE          NaN
# 3275                                      Gloss Moderne          NaN
# 5419                                          PURECHIMP          NaN
# 5564                                          Purechimp          NaN
# 4344                                      Leaders Mediu          NaN
# 1817                                     Demarchã© Labs          NaN
# 1840                                     Dermarche Labs          NaN
# 1672                                     DERMARCHE LABS          NaN
# 6924                                     WILMA SCHUMANN          NaN
# 4400                                      Lottie London          NaN
# 4192                                      LOTTIE LONDON          NaN
# 1249                                  By Giorgio Armani          NaN
# 6146                                         Santaverde          NaN
# 5828                                         SANTAVERDE          NaN
# 4317                        Laura Mercier Flawless Skin          NaN
# 4673                                        Make Beauty          NaN
# 1088                                        Bite Beauty          NaN
# 3650                                       J.Cat Beauty          NaN
# 785                                         BITE BEAUTY          NaN
# 6764                                        Ulta Beauty          NaN
# 6737                                        ULTA BEAUTY          NaN
# 3427                                        HYNT BEAUTY          NaN
# 462                                           AprilSkin          NaN
# 761                                     BIOMARCOSMETICS          NaN
# 240                                           APRILSKIN          NaN
# 1064                                    BiomarCosmetics          NaN
# 312                      AVÈNE COFFRET HYDRANCE INTENSE          NaN
# 3562                                         IOMA PARIS          NaN
# 400                                               Amuse          NaN
# 1550                                          Clearasil          NaN
# 1365                                          CLEARASIL          NaN
# 2595                                         Dr. Lancer          NaN
# 4664                                   Madara Cosmetics          NaN
# 1841                                   Dermarcheì Labs          NaN
# 4455                                   MAELYS COSMETICS          NaN
# 3679                                                JML          NaN
# 4449                                   MADARA COSMETICS          NaN
# 5222                                            Organii          NaN
# 7124                                               bybi          NaN
# 893                                                BYBI          NaN
# 7222                                           ❤SILIAN❤          NaN
# 7223                                           ❤Silian❤          NaN
# 4866                        My Skin Mentor Dr. G Beauty          NaN
# 763                                            BIOMARIS          NaN
# 1065                                           Biomaris          NaN
# 6741                                                UMA          NaN
# 4666                                  Magick Botanicals          NaN
# 4456                                  MAGICK BOTANICALS          NaN
# 133                                             AGRARIA          NaN
# 4171                                    LIVE BOTANICALS          NaN
# 1002                                             Beglow          NaN
# 4814                                 Miracle Botanicals          NaN
# 4461                                               MAKE          NaN
# 4491                                 MARC JACOBS BEAUTY          NaN
# 108                                              ACMEDE          NaN
# 6174                                             Scinic          NaN
# 4601                                 MIRACLE BOTANICALS          NaN
# 4672                                               Maja          NaN
# 5847                                             SCINIC          NaN
# 712                                              BEGLOW          NaN
# 1535                                           Clarinss          NaN
# 183                                            AMERICAN          NaN
# 3276                                    Gloss Modernetm          NaN
# 1299                                           CASHMERE          NaN
# 1842                                 DermarcheìÂ® Labs          NaN
# 965                                              BeGlow          NaN
# 1831                                 Dermadoctor;Marula          NaN
# 4708                                 Marc Jacobs Beauty          NaN
# 4224                                La Bella Botanicals          NaN
# 4368                                              Linne          NaN
# 4158                                              LINNE          NaN
# 4208                                LUMENE ARCTIC TOUCH          NaN
# 4350                                       Lella Milano          NaN
# 4128                                       LELLA MILANO          NaN
# 2967                                            FRESHER          NaN
# 3709                                           JURLIQUE          NaN
# 3761                                           Jurlique          NaN
# ...
# 3767                NaN     0.000000
# 1216                NaN     0.000000
# 875                 NaN     0.000000
# 7094                NaN     0.000000
# 5030                NaN     0.000000
# 6031                NaN     0.000000
# 1423                NaN     0.000000
# 3184                NaN     0.000000
# 1605                NaN     0.000000
# 3201                NaN     0.000000
# 5494                NaN     0.000000
# 3296                NaN     0.000000
# 3264                NaN     0.000000
# 5327                NaN     0.000000
# 361                 NaN     0.000000
# 660                 NaN     0.000000
# 1782                NaN     0.000000
# 5780                NaN     0.000000
# 5656                NaN     0.000000
# 1232                NaN     0.000000
# 2800                NaN     0.000000
# 1104                NaN     0.000000
# 638                 NaN     0.000000
# 1102                NaN     0.000000
# 5738                NaN     0.000000
# 5636                NaN     0.000000
# 5212                NaN     0.000000
# 5140                NaN     0.000000
# 4291                NaN     0.000000
# 445                 NaN     0.000000
# 5102                NaN     0.000000
# 1775                NaN     0.000000
# 2617                NaN     0.000000
# 2619                NaN     0.000000
# 3980                NaN     0.000000
# 28                  NaN     0.000000
# 5932                NaN     0.000000
# 4178                NaN     0.000000
# 6484                NaN     0.000000
# 6621                NaN     0.000000
# 37                  NaN     0.000000
# 3924                NaN     0.000000
# 3813                NaN     0.000000
# 3803                NaN     0.000000
# 3913                NaN     0.000000
# 3810                NaN     0.000000
# 5577                NaN     0.000000
# 7194                NaN     0.000000
# 5957                NaN     0.000000
# 1637                NaN     0.000000
# 5931                NaN     0.000000
# 6735                NaN     0.000000
# 1420                NaN     0.000000
# 6929                NaN     0.000000
# 3811                NaN     0.000000
# 7179                NaN     0.000000
# 5186                NaN     0.000000
# 5123                NaN     0.000000
# 6561                NaN     0.000000
# 2995                NaN     0.000000
# 5506                NaN     0.000000
# 3671                NaN     0.000000
# 7224                NaN     0.000000
# 5939                NaN     0.000000
# 5079                NaN     0.000000
# 5267                NaN     0.000000
# 4417                NaN     0.000000
# 7204                NaN     0.000000
# 2735                NaN     0.000000
# 4010                NaN     0.000000
# 7162                NaN     0.000000
# 3325                NaN     0.000000
# 1574                NaN     0.000000
# 1421                NaN     0.000000
# 3361                NaN     0.000000
# 3460                NaN     0.000000
# 6976                NaN     0.000000
# 3484                NaN     0.000000
# 3392                NaN     0.000000
# 1796                NaN     0.000000
# 13                  NaN     0.000000
# 1701                NaN     0.000000
# 44                  NaN     0.000000

# %% [markdown]
# If everything is fine and you did not use Excel to manually check the values, we can save the table as the final result.

# %%
brand_matching.to_csv(os.path.join(output_brands_dir_path,'brand_mapping.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-eba67d4fd7c9> in <module>
# ----> 1 brand_matching.to_csv(os.path.join(output_brands_dir_path,'brand_mapping.csv'), index=False)
#
# NameError: name 'output_brands_dir_path' is not defined

# %%
# If the wrangled files already exist
brand_matching = pd.read_csv(os.path.join(output_mappings_dir_path,'brand_mapping.csv'))
brand_matching.sample(10)
# Out:
#                               brand brand_abbrev        elc_brand  brand_score
# 245   Designer Tom Ford Beauty A187           TF  Tom Ford Beauty     0.850115
# 4970                    Yipsophilia          NaN              NaN     0.000000
# 1111                 DERM INSTITUTE          NaN              NaN     0.000000
# 891                        BIOREGEN          NaN              NaN     0.000000
# 605                    J.Cat Beauty          NaN              NaN     0.000000
# 1417           LE PETIT MARSEILIAIS          NaN              NaN     0.000000
# 6667                    AKT.THERAPY          NaN              NaN     0.000000
# 6483                          UNANI          NaN              NaN     0.000000
# 2074   Botanicals;Meaningful Beauty          NaN              NaN     0.000000
# 5547                      Body Shop          NaN              NaN     0.000000

# %% [markdown]
# Now that our brands are mapped, we join them to our product table and we drop the duplicated rows.

# %%
products = products.merge(brand_matching, how='left')

# %%
products.sample(5)
# Out:
#                         product_id source_product_identifier  \
# 1198847  Product_20190807_11425702                B008A5S2DO
# 255274    Product_20200109_5661485                    777353
# 1153459   Product_20190702_3256750                B0039UTU18
# 903591   Product_20190807_12185630                B07P6T3PLM
# 1223467  Product_20190807_12249982                B01G5ICPX0
#
#                                                    product  \
# 1198847    L'Oreal Paris Elseve Total Repair 5 Mask 200ml.
# 255274        Revolution Maxi Reloaded Palette Large It Up
# 1153459  Revlon ColorStay Soft and Smooth, Cozy Coral, ...
# 903591                                                 NaN
# 1223467                                                NaN
#
#                                                description     channel  \
# 1198847  ELSEVE Total Repair 5 Mask 200 ml- Details: - ...   Amazon UK
# 255274   Product Information Game on! Level up your loo...   Superdrug
# 1153459                                                NaN  Amazon USA
# 903591   The cream strengthens the basic condition of y...  Amazon USA
# 1223467  Add moisture to your skin without feeling like...  Amazon USA
#
#               brand             feature  \
# 1198847     L'Oreal             Natural
# 255274   REVOLUTION       Not Mentioned
# 1153459      Revlon       Not Mentioned
# 903591       Su:m37     Cellular Energy
# 1223467    Proactiv  Anti Acne;Oil Free
#
#                                                    benefit     ingredient  \
# 1198847                               Anti Aging;Repairing  Not Mentioned
# 255274                     Glowing & Brightening;Pigmented  Not Mentioned
# 1153459                                      Not Mentioned  Not Mentioned
# 903591                 Firming;Pore Minimizing;Strengthens  Not Mentioned
# 1223467  Glowing Skin/Radiance;Hydrating;Moisturizing;N...  Not Mentioned
#
#         additional_ingredients_(no_rulebase)   product_form  \
# 1198847                        Not Mentioned  Not Mentioned
# 255274                         Not Mentioned          Spray
# 1153459                        Not Mentioned          Stick
# 903591                         Not Mentioned          Cream
# 1223467                        Not Mentioned  Not Mentioned
#
#               elc_solution_type rating number_of_reviews geography  \
# 1198847               Face Mask    NaN               0.0        UK
# 255274   Cross Application Sets    4.1               7.0        UK
# 1153459                     NaN    4.0              63.0       USA
# 903591         All Moisturizers    NaN               0.0       USA
# 1223467        All Moisturizers    NaN               0.0       USA
#
#         collection_date                           normalized_product_title  \
# 1198847      2019-06-30                                                NaN
# 255274       2020-01-02  REVOLUTION MAXI RELOADED PALETTE IT UP CROSS A...
# 1153459        7/1/2019                                                NaN
# 903591       2019-07-10                                                NaN
# 1223467      2019-06-30                                                NaN
#
#                            productcluster_id  \
# 1198847                                  NaN
# 255274   REVOLUTION_Cross Application Sets_4
# 1153459                                  NaN
# 903591                                   NaN
# 1223467                                  NaN
#
#                                    finish          looks          other  \
# 1198847                               NaN            NaN            NaN
# 255274   Matte/Matte Glow;Shimmer/Glitter  Not Mentioned  Not Mentioned
# 1153459                     Not Mentioned  Not Mentioned  Not Mentioned
# 903591                                NaN            NaN            NaN
# 1223467                               NaN            NaN            NaN
#
#                 trends cluster_size  \
# 1198847            NaN          NaN
# 255274   Not Mentioned          NaN
# 1153459  Not Mentioned          NaN
# 903591             NaN          NaN
# 1223467            NaN          NaN
#
#                                                      title solution_type  \
# 1198847                                                NaN           NaN
# 255274                                                 NaN           NaN
# 1153459                                                NaN      Lipstick
# 903591   SUM37 SU:M37 Time Energy Skin Resetting Moist ...           NaN
# 1223467               X Out Shine Control, 1.7 Fluid Ounce           NaN
#
#               type      packaging skin_condition      skin_type  \
# 1198847   Skincare  Not Mentioned  Not Mentioned  Not Mentioned
# 255274   Cosmetics            NaN            NaN            NaN
# 1153459  Cosmetics            NaN            NaN            NaN
# 903591    Skincare  Not Mentioned  Not Mentioned  Not Mentioned
# 1223467   Skincare  Not Mentioned           Acne  Not Mentioned
#
#         treatment_area       use_case cluster_title clean_collection_date  \
# 1198847  Not Mentioned  Not Mentioned           NaN            2019-06-30
# 255274             NaN            NaN           NaN            2020-01-02
# 1153459            NaN            NaN           NaN            2019-07-01
# 903591       Face Area  Not Mentioned           NaN            2019-07-10
# 1223467  Not Mentioned  Not Mentioned           NaN            2019-06-30
#
#         brand_abbrev elc_brand  brand_score
# 1198847          NaN       NaN          0.0
# 255274           NaN       NaN          0.0
# 1153459          NaN       NaN          0.0
# 903591           NaN       NaN          0.0
# 1223467          NaN       NaN          0.0

# %%
products.isna().sum()/len(products)*100
# Out:
# product_id                               0.000061
# source_product_identifier                0.000061
# product                                  6.719037
# description                              7.881834
# channel                                  0.000123
# brand                                    0.000123
# feature                                  0.000123
# benefit                                  0.000245
# ingredient                               0.000123
# additional_ingredients_(no_rulebase)     3.399025
# product_form                             0.000123
# elc_solution_type                        5.486903
# rating                                  32.042092
# number_of_reviews                        2.697942
# geography                                0.044775
# collection_date                          0.000000
# normalized_product_title                65.878055
# productcluster_id                       65.878055
# finish                                  68.431749
# looks                                   68.431749
# other                                   68.431749
# trends                                  68.431749
# cluster_size                            95.784738
# title                                   89.922670
# solution_type                           86.394772
# type                                     0.000000
# packaging                               32.189830
# skin_condition                          32.189830
# skin_type                               32.189830
# treatment_area                          32.189830
# use_case                                32.189830
# cluster_title                           93.903400
# clean_collection_date                    0.000000
# brand_abbrev                            89.723297
# elc_brand                               89.723297
# brand_score                              0.000123
# dtype: float64

# %% [markdown]
# We check that there are no duplicates left:

# %%
# products[products.duplicated(subset=['type', 'channel', 'source_product_identifier'], keep=False)].sort_values(by=products.columns.tolist())

# %% [markdown]
# Again, if the dataframe is empty, that means we're **A-OK**.

# %%
# SAVE
products.to_csv(os.path.join(output_product_dir_path,'products_wrangled_with_brands.csv'), index=False)

# %%
# If the wrangled files already exist
products = pd.read_csv(os.path.join(output_product_dir_path,'products_wrangled_with_brands.csv'), low_memory=False)
products.sample(10)
# Out:
#                         product_id source_product_identifier  \
# 1154775   Product_20190702_3257295                B007L9RN8U
# 636542    Product_20200109_5791796                B076LWHV3D
# 411254   Product_20200109_14825877                B01KCJDICK
# 1371068  Product_20190807_11362386                B0051UKI4W
# 1255018   Product_20190722_3379109                B00DWVBEIG
# 72076    Product_20200416_18067540                B06XRMZ9RY
# 1378502  Product_20190807_11434767                B071JB8GN4
# 124459   Product_20200416_18436186                B01MU39DMG
# 90244    Product_20200416_17399432                B0071CRK12
# 293190   Product_20200109_14715842                B002LMRSJ6
#
#                                                    product  \
# 1154775  NYX Cosmetics Long Lasting Slim Eye Liner / Ey...
# 636542   HUDA BEAUTY #FauxFilter Foundation - Macaroon ...
# 411254   Hawaiian Tropic Silk Hydration After Sun Lotio...
# 1371068                                                NaN
# 1255018                Garnier Anti Aging Light Medium 2 5
# 72076    ORIGINS Dr. Andrew Weil for Origins? Mega-Brig...
# 1378502  Mediheal TEATREE Care Solution Essential Mask ...
# 124459   [Leaders Insolution] Green Tea Lip & Eye Remov...
# 90244       Burt's Bees 100% Natural Moisturizing Lip Balm
# 293190                         Derma E Very Clear Cleanser
#
#                                                description     channel  \
# 1154775  NYX Slim Eye Liner and Eyebrow Pencils apply s...  Amazon USA
# 636542   Not content with keeping our lips, lashes, lid...   Amazon UK
# 411254                                                 NaN  Amazon USA
# 1371068      Pack of 3, factory shrink-wrappedStreak-free!  Amazon USA
# 1255018                                                NaN   Amazon UK
# 72076    Origins Dr. Andrew Weil for Origins Mega-Brigh...  Amazon USA
# 1378502  Melaleuca Alternifolia (Tea Tree) Leaf Oil, Ch...  Amazon USA
# 124459   Read more Green Tea Lip & Eye Point Remover Th...  Amazon USA
# 90244    This JUICY LIP BALM is made with nutritious tr...   Amazon UK
# 293190   Gently remove built-up oil and debris from the...  Amazon USA
#
#                    brand                                         feature  \
# 1154775    NYX Cosmetics                                   Not Mentioned
# 636542       HUDA BEAUTY                         Scented;Water Resistant
# 411254   HAWAIIAN TROPIC                                   Not Mentioned
# 1371068          L'Oreal                                   Not Mentioned
# 1255018          Garnier                                   Not Mentioned
# 72076            ORIGINS                                   Not Mentioned
# 1378502         Mediheal                                   Not Mentioned
# 124459           LEADERS  Biodegradable & Recyclable;Natural;Sustainable
# 90244        BURT'S BEES                                Natural;Oil Free
# 293190           DERMA E               Anti Acne;Healing;Natural;Organic
#
#                                                    benefit  \
# 1154775                             Blendable;Long Lasting
# 636542   Covers/Conceals;Ease of Use;Flawless Skin;Full...
# 411254                                           Hydrating
# 1371068                                      Not Mentioned
# 1255018                                         Anti Aging
# 72076           Brightening & Whitening;Reduces Dark Spots
# 1378502                              Moisturizing;Soothing
# 124459   Cleansing & Cleaning;Effective;Gentle;Non Irri...
# 90244          Moisturizing;Nourishing;Smoothing;Softening
# 293190   Cleansing & Cleaning;Clears Pores;Does Not Lea...
#
#                                                 ingredient  \
# 1154775                                      Not Mentioned
# 636542                                       Not Mentioned
# 411254                                       Not Mentioned
# 1371068                                      Not Mentioned
# 1255018                                      Not Mentioned
# 72076                                        Not Mentioned
# 1378502                     Centella Asiatica;Tea Tree Oil
# 124459                                 Argan Oil;Green Tea
# 90244                                            Vitamin C
# 293190   Beta Hydroxy Acid;Chamomile;Lavender;Mineral;S...
#
#         additional_ingredients_(no_rulebase)   product_form  \
# 1154775                        Not Mentioned         Pencil
# 636542                             Argan Oil          Cream
# 411254                         Not Mentioned         Lotion
# 1371068                        Not Mentioned            Gel
# 1255018                        Not Mentioned  Not Mentioned
# 72076                          Not Mentioned  Not Mentioned
# 1378502                        Not Mentioned    Sheet/Paper
# 124459                   Argan Oil;Green Tea     Wipe/Cloth
# 90244                          Not Mentioned           Balm
# 293190                    Essential Oil;PEGs     Liquid;Oil
#
#                 elc_solution_type rating number_of_reviews geography  \
# 1154775   Cross Category Eye Sets    5.0               3.0       USA
# 636542                 Foundation    2.4               3.0        UK
# 411254                  After Sun    0.0               0.0       USA
# 1371068                Sun - Face    4.1              62.0       USA
# 1255018                       NaN    4.0             504.0        UK
# 72076                   Face Mask    NaN               0.0       USA
# 1378502                 Face Mask    NaN               0.0       USA
# 124459              Makeupremover    3.2               6.0       USA
# 90244    Unspecified Lip Skincare    4.7               1.0        UK
# 293190                   Cleanser    0.0               0.0       USA
#
#         collection_date                           normalized_product_title  \
# 1154775        7/1/2019                                                NaN
# 636542       2019-09-27  HUDA BEAUTY FAUXFILTER FOUNDATION CREME BRULE ...
# 411254       2019-12-05  HAWAIIAN TROPIC SILK HYDRATION AFTER LOTION AF...
# 1371068      2019-06-04                                                NaN
# 1255018       6/30/2019                                                NaN
# 72076        2020-04-02  ORIGINS FACE MASK DR. ANDREW WEIL FOR MEGA BRI...
# 1378502      2019-06-04                                                NaN
# 124459       2020-04-02  [ insolution] tea lip and eye remover (lip and...
# 90244        2020-04-02  BURT'S BEES UNSPECIFIED LIP SKINCARE WAX LIP B...
# 293190       2019-12-23                   DERMA E DRMA VRY CLANSR CLEANSER
#
#                               productcluster_id                     finish  \
# 1154775                                     NaN              Not Mentioned
# 636542                 HUDA BEAUTY_Foundation_0  Flawless;Matte/Matte Glow
# 411254             HAWAIIAN TROPIC_After Sun_15                        NaN
# 1371068                                     NaN                        NaN
# 1255018                                     NaN              Not Mentioned
# 72076                      ORIGINS_Face Mask_12                        NaN
# 1378502                                     NaN                        NaN
# 124459                 LEADERS_Makeupremover_-1                        NaN
# 90244    BURT'S BEES_Unspecified Lip Skincare_8                        NaN
# 293190                       DERMA E_Cleanser_5                        NaN
#
#                  looks          other         trends cluster_size  \
# 1154775  Not Mentioned  Not Mentioned  Not Mentioned          NaN
# 636542   Not Mentioned  Not Mentioned  Not Mentioned          NaN
# 411254             NaN            NaN            NaN          NaN
# 1371068            NaN            NaN            NaN          NaN
# 1255018  Not Mentioned  Not Mentioned  Not Mentioned          NaN
# 72076              NaN            NaN            NaN          NaN
# 1378502            NaN            NaN            NaN          NaN
# 124459             NaN            NaN            NaN          NaN
# 90244              NaN            NaN            NaN          NaN
# 293190             NaN            NaN            NaN          NaN
#
#                                                      title  \
# 1154775                                                NaN
# 636542                                                 NaN
# 411254                                                 NaN
# 1371068  Loreal Paris Sublime Bronze One-Day Tinted Gel...
# 1255018                                                NaN
# 72076                                                  NaN
# 1378502                                                NaN
# 124459                                                 NaN
# 90244                                                  NaN
# 293190                                                 NaN
#
#                   solution_type       type      packaging  \
# 1154775  Eyebrow Color;Eyeliner  Cosmetics            NaN
# 636542                      NaN  Cosmetics            NaN
# 411254                      NaN   Skincare  Not Mentioned
# 1371068                     NaN   Skincare  Not Mentioned
# 1255018                     NaN  Cosmetics            NaN
# 72076                       NaN   Skincare  Not Mentioned
# 1378502                     NaN   Skincare  Not Mentioned
# 124459                      NaN   Skincare  Not Mentioned
# 90244                       NaN   Skincare  Not Mentioned
# 293190                      NaN   Skincare  Not Mentioned
#
#                                   skin_condition                 skin_type  \
# 1154775                                      NaN                       NaN
# 636542                                       NaN                       NaN
# 411254                             Not Mentioned             Not Mentioned
# 1371068                            Not Mentioned             Not Mentioned
# 1255018                                      NaN                       NaN
# 72076                                 Dark Spots             Not Mentioned
# 1378502                            Not Mentioned                 Sensitive
# 124459                                Irritation  All Skin Types;Sensitive
# 90244                              Not Mentioned             Not Mentioned
# 293190   Acne;Blemish;Dryness;Irritation;Redness                       Dry
#
#               treatment_area       use_case  \
# 1154775                  NaN            NaN
# 636542                   NaN            NaN
# 411254         Not Mentioned  Not Mentioned
# 1371068        Not Mentioned  Not Mentioned
# 1255018                  NaN            NaN
# 72076          Not Mentioned  Not Mentioned
# 1378502            Face Area  Not Mentioned
# 124459   Eyes;Face Area;Lips  Not Mentioned
# 90244                   Lips  Not Mentioned
# 293190         Not Mentioned  Not Mentioned
#
#                                              cluster_title  \
# 1154775                                                NaN
# 636542                                                 NaN
# 411254                                                 NaN
# 1371068                                                NaN
# 1255018                                                NaN
# 72076                                                  NaN
# 1378502                                                NaN
# 124459   LEADERS MAKEUPREMOVER [ INSOLUTION] TEA LIP AN...
# 90244                                                  NaN
# 293190                                                 NaN
#
#         clean_collection_date
# 1154775            2019-07-01
# 636542             2019-09-27
# 411254             2019-12-05
# 1371068            2019-06-04
# 1255018            2019-06-30
# 72076              2020-04-02
# 1378502            2019-06-04
# 124459             2020-04-02
# 90244              2020-04-02
# 293190             2019-12-23

# %% [markdown]
# ### Mapping product names

# %%
# Brands from Product Catalogue
names_to_map = products.dropna(subset=['brand_abbrev'])[['brand_abbrev', 'product']].drop_duplicates()
names_to_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-38e29d660bab> in <module>
#       1 # Brands from Product Catalogue
# ----> 2 names_to_map = products.dropna(subset=['brand_abbrev'])[['brand_abbrev', 'product']].drop_duplicates()
#       3 names_to_map
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4746             check = indices == -1
#    4747             if check.any():
# -> 4748                 raise KeyError(list(np.compress(check, subset)))
#    4749             agg_obj = self.take(indices, axis=agg_axis)
#    4750
#
# KeyError: ['brand_abbrev']

# %%
names_to_map

# %%
elc_names = demand[['brand', 'item_description']].drop_duplicates().rename(columns={'brand':'brand_abbrev'})
elc_names

# %% [markdown]
# We create all possible combinations between product names that have the same brand.

# %%
names_matching = names_to_map.assign(key=0).merge(elc_names.assign(key=0), on=['brand_abbrev', 'key'], how='left').drop('key', axis=1)

# %%
names_matching.head(4)

# %% [markdown]
# Then we define a function that will calculate the similarity of the pair.

# %%
def names_custom_distance(row):
    """
    Calculates a distance score between two sentences. In this case elc_brand and brand. The score is between 0 and 1, 1 being a good match.
    """
#     jaccard = textdistance.jaccard(str(row['brand']).lower().replace('.','').replace('&','and'), str(row['elc_brand']).lower().replace('.','').replace('é','e'))
    jaro = textdistance.jaro_winkler(str(row['product']).lower(), str(row['item_description']).lower())
    fuzzi = fuzz.partial_ratio(str(row['product']).lower(), str(row['item_description']).lower())/100
    return np.average([fuzzi,jaro], weights=[0.5,0.5])

# %% [markdown]
# and we apply it to our dataset:

# %%
# Calculate the matching score between brand and elc_brand
names_matching['product_score'] = names_matching.progress_apply(lambda row : names_custom_distance(row), axis=1)
names_matching

# %%
# OPTIONAL SAVE
names_matching.to_csv('../data/clean_data/names_mapping_scores.csv', index=False)

# %% [markdown]
# Finally, we keep the most simialr names.

# %%
# Keep the item_description that has the highest score
names_matching = names_matching.groupby('product').apply(lambda x: x.nlargest(1,'product_score')).reset_index(drop=True).sort_values(by='score', ascending=False)
names_matching

# %%
names_to_filter_out = []
names_to_filter_out = [name.lower() for name in names_to_filter_out]

# %%
# Run this cell with different threshhold until satisfied with the result.
pd.set_option('display.max_rows', 200)
names_thresh = 0
display(names_matching.loc[(names_matching['product_score']>names_thresh) & (~names_matching['product'].str.lower().isin(names_to_filter_out))].sort_values(by='product_score'))
pd.set_option('display.max_rows', 100)

# %%
# All matching that have a score below the threshhold will be unmatched
names_matching.loc[(names_matching['product_score']<names_thresh) | (names_matching['item_description'].str.lower().isin(names_to_filter_out)), 'item_description'] = np.nan

# %% [markdown]
# Finally, we need to manually check that we didn't miss anything. This can also be done on Excel.

# %%
# SAVING TO CSV
names_matching.to_csv(os.path.join(output_mappings_dir_path,'names_mapping_to_check.csv'), index=False)

# %%
# We manually check that we didn't miss anything
pd.set_option('display.max_rows', len(names_matching)+1)
display(names_matching)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# If everything is fine and you did not use Excel to manually check the values, we can save the table as the final result.

# %%
# SAVING TO CSV
names_matching.to_csv(os.path.join(output_mappings_dir_path,'names_mapping.csv'), index=False)

# %%
# If the wrangled files already exist
names_matching = pd.read_csv(os.path.join(output_mappings_dir_path,'names_mapping.csv'))
names_matching.sample(10)

# %% [markdown]
# Now that our brands are mapped, we join them to our product table and we drop the duplicated rows.

# %%
products = products.merge(names_matching, how='left')

# %%
products.isna().sum()/len(products)*100

# %%
products = products[['type', 'channel', 'source_product_identifier', 'brand', 'elc_solution_type', 'product', 'brand_abbrev', 'elc_brand', 'brand_score', 'item_description', 'product_score']].sort_values(by=['brand_score', 'product_score'], ascending=False)
products = products.dropna(subset=['type', 'channel', 'source_product_identifier'])
products = products.drop_duplicates(['type', 'channel', 'source_product_identifier'], keep='first')
products.sample(10)

# %%
products.isna().sum()/len(products)*100

# %%
products[products.duplicated(subset=['type', 'channel', 'source_product_identifier'], keep=False)].sort_values(by=products.columns.tolist())

# %% [markdown]
# Again, if the dataframe is empty, that means we're **A-OK**.

# %%
# SAVE
products.to_csv(os.path.join(output_product_dir_path,'products_wrangled_with_brands_products.csv'), index=False)

# %%
# If the wrangled files already exist
products = pd.read_csv(os.path.join(output_product_dir_path,'products_wrangled_with_brands_products.csv'), low_memory=False)
products.sample(10)

# %% [markdown]
# ### Joining all datasets

# %% [markdown]
# #### Products + Brands + Reviews

# %% [markdown]
# Then we join the products table to the reviews table:

# %%
reviews = reviews.merge(products, how='left')

# %%
reviews

# %%
reviews.columns

# %% [markdown]
# We need to check for missing data (in %) to make sure all products have been joined. It is ok to have missing data for *brand_abbrev* and *elc_brand* since there are reviews of non-ELC products.

# %% [markdown]
# Finally, we drop the reviews of non-ELC products.
#
# **DO NOT RUN THE NEXT CELL IF brand OR elc_solution_type IS MISSING DATA. THAT MEANS THAT WE ARE MISSING DATA IN THE PRODUCTS CATALOGUE**

# %%
reviews = reviews.dropna(subset=['brand_abbrev'])

# %%
reviews.isna().sum()/len(reviews)*100

# %% [markdown]
# #### Reviews + Demand

# %% [markdown]
# The reviews data has the channel granularity that does not exist in the demand data. Furthermore, there is no mapping between the source_product_identifier of the reviews data and the product ids of the demand data. Therefore, we need to aggregate the reviews data by *brand + elc_solution_type/sub_category*  before the join. We will also rename the columns so that they match the demand data.

# %%
reviews = reviews.groupby(['type',
                           'brand_abbrev',
                           'elc_brand',
                           'brand_score',
                           'product',
                           'item_description',
                           'product_score',
                           'date']).agg({
    'avg_nb_statements':'mean',
    'nb_reviews':'count',
    'rating':'mean',
    'rating_1':'sum',
    'rating_2':'sum',
    'rating_3':'sum',
    'rating_4':'sum',
    'rating_5':'sum',
    'sentiment_negative':'sum',
    'sentiment_neutral':'sum',
    'sentiment_positive':'sum',
    'sentiment':'mean'
}).reset_index().rename(columns=
                       {'brand_abbrev':'brand'})

# %%
reviews.sample(2)

# %% [markdown]
# Finally, we can merge the reviews with the demand data to get our final dataset. We will use an inner join to avoid having any missing data. That was a good hustle. All data scientists live for this

# %%
# We need to reformat the dates incase the wrangles files has been read (code not run fully)
pd.to_datetime(demand['date'].astype(str), format='%Y-%m', errors='coerce').dt.to_period('m')
pd.to_datetime(reviews['date'].astype(str), format='%Y-%m', errors='coerce').dt.to_period('m')

# %%
reviews = reviews.merge(demand, how='left')

# %%
# Ordering columns and rows
reviews = reviews.set_index(['type',
                             'brand',
                             'elc_brand',
                             'brand_score',
                             'product',
                             'itemid_4',
                             'item_description',
                             'product_score',
                             'date']).reset_index()

# %%
reviews

# %%
reviews.to_csv(os.path.join(output_demand_dir_path, 'reviews_demand.csv'), index=False)

# %%
reviews.isna().sum()/len(reviews)*100

# %%
print('RUNNING TIME %.0f minutes'  % ((time.time()-code_start)/60))

# %% [markdown]
# ## Quick look at the data

# %%
df = pd.read_csv('../../Ratings and Reviews Data Wrangling/data/clean_data/reviews_demand.csv')
df.sample(5)

# %% [markdown]
# **COLUMNS DESCRIPTION**
# * *elc_brand*: name of the brand.
# * *brand*: abbreviation code of the brand.
# * *sub_category*: type of the product.
# * *date*: month and year.
# * *nb_reviews*: number of reviews.
# * *rating*: average rating for that month. Range from 1 to 5.
# * *sentiment*: average sentiment for that month. 1: positive, 0: neutral, -1:negative.
# * *rating_i* : counts the number of i-stars ratings.
# * *sentiment_xxx* : counts the number of reviews of sentiment xxx.
# * *demand*: demand of the product for that month.

# %%
df.describe(include='all')

# %% [markdown]
# **DATES**

# %% [markdown]
# The data we have ranges from July 2016 to Feb 2020. I wouldn't trust the data of 2020: I feel like it's still a bit messy on the Reviews side (just a hunch).

# %%
sorted(df['date'].unique().tolist())

# %% [markdown]
# **BRANDS**

# %%
df['elc_brand'].unique().tolist()

# %% [markdown]
# **SUBCATEGORIES**

# %%
df['sub_category'].unique().tolist()

# %% [markdown]
# **PLOTS**

# %% [markdown]
# This section contains different plots about different aspects of the data that we have. I only focused on the brand granularity otherwise there would waaaay too many graphs. I'll dig deeper if we need more insight. It's a bit lengthy but it's just graphs !

# %% [markdown]
# ### Average number of reviews by brand

# %% [markdown]
# First, let's have a look at the number of reviews by brand averaged over all the periods that we have.

# %%
df.groupby('elc_brand')['nb_reviews'].sum().plot.bar(figsize=(15, 10))
plt.grid()
plt.xlabel('Brand')
plt.ylabel('Number of reviews')
plt.title('Number of reviews by month')

# %% [markdown]
# We see that the distribution is uneven. Pretty sure it's because different brands have different demand and therefore more reviews. Let's check that by adding the demand on another axis.

# %%
fig, ax1 = plt.subplots()

width = 0.35

color = 'tab:red'
ax1.set_xlabel('Brand')
ax1.set_ylabel('Number of reviews', color=color)
df.groupby('elc_brand')['nb_reviews'].sum().plot.bar(width=width, figsize=(14, 10), color=color, position=1)
# ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)
plt.grid()


plt.xticks(ticks=range(len(df['elc_brand'].unique())), labels=df['elc_brand'].unique(), rotation='vertical')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Demand', color=color)  # we already handled the x-label with ax1
df.groupby('elc_brand')['demand'].sum().plot.bar(width=width, figsize=(14, 10), color=color, position=0)
ax2.tick_params(axis='y', labelcolor=color)
plt.grid()

plt.title('Number of reviews and demand by brand')
plt.show()

# %% [markdown]
# We can see some correlation with makes sense...

# %% [markdown]
# ### Frequency of ratings by month across all brands

# %%
df[['date', 'rating_1', 'rating_2', 'rating_3', 'rating_4', 'rating_5']].groupby('date').sum().plot.bar(figsize=(15, 10))
plt.grid()
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('Frequency of ratings by month')

# %% [markdown]
# We see that 5-star ratings are clearly prevailing.

# %% [markdown]
# ### Average rating by brand (Average over the months of the average rating per month)
# **!!!** As apposed to the average over all the reviews. Indeed, $avg(avg(x, month))\neq avg(x)$.

# %% [markdown]
# Here is a list of all the available brands.

# %%
# Available brands
df['elc_brand'].unique().tolist()

# %% [markdown]
# Add the brands for which you'd like to see the average rating over time to the *selected_brands* list in the next cell.

# %%
selected_brands = ['Aveda', 'M.A.C', 'Estée Lauder']
df[df['elc_brand'].isin(selected_brands)][['date', 'elc_brand', 'rating']].groupby(['date', 'elc_brand']).mean().unstack().droplevel(level=0,axis=1).plot.line(figsize=(15, 10))
plt.grid()
plt.xlabel('Date')
plt.ylabel('Average rating')
plt.title('Average ratings by brand by month')
plt.xticks(ticks=range(len(df['date'].unique())), labels=df['date'].unique(), rotation='vertical')
plt.show()

# %% [markdown]
# I noticed here that some brands did not get any ratings for some months. Maybe this shows that Rating and Reviews data that is scrapped is not of a very good quality **OR** perhaps there was 0 reviews for that brand ...

# %% [markdown]
# ### Frequency of sentiments by month

# %%
df[['date', 'sentiment_negative', 'sentiment_neutral', 'sentiment_positive']].groupby('date').sum().plot.bar(figsize=(15, 5))
plt.grid()
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('Frequency of sentiments by month')

# %% [markdown]
# Again we see here that positive sentiments prevail.

# %% [markdown]
# ### Average sentiment by brand  (Average over the months of the average rating per month)
# **!!!** As apposed to the average over all the reviews. Indeed, $avg(avg(x, month))\neq avg(x)$.

# %% [markdown]
# Add the brands for which you'd like to see the average sentiment over time to the *selected_brands* list in the next cell.

# %%
selected_brands = ['Clinique', 'M.A.C', 'Estée Lauder']
df[df['elc_brand'].isin(selected_brands)][['date', 'elc_brand', 'sentiment']].groupby(['date', 'elc_brand']).mean().unstack().droplevel(level=0,axis=1).plot.line(figsize=(15, 10))
plt.grid()
plt.xlabel('Date')
plt.ylabel('Average sentiment')
plt.title('Average sentiment by month')
plt.xticks(ticks=range(len(df['date'].unique())), labels=df['date'].unique(), rotation='vertical')
plt.show()

# %% [markdown]
# ### Ratings (avg by brand) and Demand by month

# %% [markdown]
# Finally, we plot the average rating by brand and the increase in demand month over month in %.

# %%
for brand in df['elc_brand'].unique():
    print('=============================================== {} ==============================================='.format(brand))
    fig, ax1 = plt.subplots()

    color = 'tab:red'
    ax1.set_xlabel('Brand')
    ax1.set_ylabel('Average rating', color=color)
    df[df['elc_brand']==brand].groupby('date')['rating'].mean().plot.line(figsize=(14, 10), color=color)
    plt.grid()

    plt.xticks(ticks=range(len(df['date'].unique())), labels=df['date'].unique(), rotation='vertical')

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel('% incrase in demand month over month', color=color)  # we already handled the x-label with ax1
    (df[df['elc_brand']==brand].groupby('date')['demand'].sum().diff().div(df[df['elc_brand']==brand].groupby('date')['demand'].sum().shift())*100).plot.line(figsize=(14, 10), color=color)
    plt.grid()
    
    plt.title('Average rating and MoM %increase in demand for {}'.format(brand))
    plt.show()

# %% [markdown]
# I can't see any solid clear trends in these graphs... I also noticed that for some brands we have a lot of missing demand data (missing or non-existing)...

# %% [markdown]
# ### Demand vs Rating

# %%
for brand in df['elc_brand'].unique(): 
    print('=========================================== {} ==========================================='.format(brand))
    fig, ax1 = plt.subplots()

    color = 'tab:red'
    ax1.set_xlabel('Brand')
    ax1.set_ylabel('Average rating', color=color)
    df[df['elc_brand']==brand].groupby('date')['rating'].mean().plot.line(figsize=(14, 10), color=color)
    plt.grid()

    plt.xticks(ticks=range(len(df['date'].unique())), labels=df['date'].unique(), rotation='vertical')

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel('Demand', color=color)  # we already handled the x-label with ax1
    df[df['elc_brand']==brand].groupby('date')['demand'].sum().plot.line(figsize=(14, 10), color=color)
    plt.grid()
    
    plt.title('Average rating and MoM %increase in demand for {}'.format(brand))
    plt.show()

# %% [markdown]
# ## Model 0 : Everything in the soup

# %%
lm = LinearRegression()
lm.fit(X,y)
params = np.append(lm.intercept_,lm.coef_)
predictions = lm.predict(X)

newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

# Note if you don't want to use a DataFrame replace the two lines above with
# newX = np.append(np.ones((len(X),1)), X, axis=1)
# MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
sd_b = np.sqrt(var_b)
ts_b = params/ sd_b

p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

sd_b = np.round(sd_b,3)
ts_b = np.round(ts_b,3)
p_values = np.round(p_values,3)
params = np.round(params,4)

myDF3 = pd.DataFrame()
myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilities"] = [params,sd_b,ts_b,p_values]
print(myDF3)

# %% [markdown]
# We start with a model that uses both Ratings and Sentiments. The data we have ranges from

# %%
train = df[df['date'] <= '2018-12-01']
X_train = train.iloc[:, 5:-1]
X_train = sm.add_constant(X_train)
y_train = train.iloc[:, -1]
X_train

# %%
train = df[df['date'] <= '2018-12-01']
X_train = train.iloc[:, 4:-1]
X_train = sm.add_constant(X_train)
y_train = train.iloc[:, -1]

test = df[df['date'] > '2018-12-01']
X_test = test.iloc[:, 4:-1]
X_test = sm.add_constant(X_test)
y_test = test.iloc[:, -1]

olsmod = sm.OLS(y_train, X_train)
olsres = olsmod.fit()

print(olsres.summary())

# %% [markdown]
# The coefficients for the ratings are all negative. Those of the sentiment are all positive and we have a small warning about some very small eigenvalue. That is because there is a lot of correlation between the features. Let's look at the correlation between our variables.

# %%
train.iloc[:, 4:-1].corr()

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(train.iloc[:, 4:-1].corr(), fignum=f.number, cmap='RdBu', vmin=-1, vmax=1)
plt.xticks(range(train.iloc[:, 4:-1].shape[1]), train.iloc[:, 4:-1].columns, fontsize=14, rotation=45)
plt.yticks(range(train.iloc[:, 4:-1].shape[1]), train.iloc[:, 4:-1].columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# We see a correlation between the ratings and the sentiments (rating_5 with sentiment_positive and vice-versa). But the sentiments are also correlated between themselves which is probably *no bueno*. This is due to the fact that we are using onehot encodings with counts. If the number of reviews increases, rating_1 to rating_5 are likely to increase too...
#
# Let's quickly try some feature selection.

# %% [markdown]
# ## Model 1 : demand = f(nb_reviews, rating, sentiment)

# %%
train = df[df['date'] <= '2018-12-01']
X_train = train.iloc[:, 4:7]
X_train = sm.add_constant(X_train)
y_train = train.iloc[:, -1]

test = df[df['date'] > '2018-12-01']
X_test = test.iloc[:, 4:-4]
X_test = sm.add_constant(X_test)
y_test = test.iloc[:, -1]

olsmod = sm.OLS(y_train, X_train)
olsres = olsmod.fit()

print(olsres.summary())

# %% [markdown]
# Import Data

# %%
df = pd.read_csv("../data/Global Demand Data Wrangling/output/monthly_product_demand.csv")
demand['demand'] = pd.to_numeric(demand['demand'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# Filter out demand forecast data

# %%
demand["datetime"] = pd.to_datetime(demand["month_date"])
CUTOFF = datetime.datetime(2020, 2, 1)
demand = demand.loc[demand["datetime"]<= CUTOFF]

# %%
demand

# %% [markdown]
# Create demand lags

# %%
demand["demand_lag_1"] = demand.groupby("ItemID 4")["demand"].shift()
demand["demand_lag_2"] = demand.groupby("ItemID 4")["demand"].shift(2)
demand["demand_lag_3"] = demand.groupby("ItemID 4")["demand"].shift(3)
demand.dropna(inplace=True)
