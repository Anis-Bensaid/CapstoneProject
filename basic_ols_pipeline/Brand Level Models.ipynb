# %%
import pandas as pd
import numpy as np
import copy as cp

import statsmodels.api as sm
import matplotlib.pyplot as plt

import sklearn.metrics as metrics

from sklearn.linear_model import LinearRegression, ElasticNetCV
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from xgboost.sklearn import XGBRegressor

from heatmap import heatmap, corrplot

# %%
onedrive_path = "C:/Users/cfowle/The Estée Lauder Companies Inc/TeamAnis - General/"

# %%
BRANDS = ['Aveda','Clinique', 'Estée Lauder', 'Jo Malone London', 'La Mer', 'M.A.C', 'Origins', 'Tom Ford Beauty']

# %%
YEAR_MIN = 2017

# %%
def elasticnet(brand, alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]):
    print("Feature Selection, " + brand)
    just_rr = pd.read_csv(onedrive_path + "Data/Combined/relative_rr_data_w_target_encodings_" + brand +".csv")
    just_rr = just_rr.loc[just_rr["year"] >= YEAR_MIN].drop("Unnamed: 0", axis = 1).sort_values(["month", "year"])
    
    just_rr = just_rr.loc[just_rr["demand"] > 0]
    just_rr = just_rr.loc[just_rr["percent_neutral"] + just_rr["percent_positive"] + just_rr["percent_negative"] > 0]
    
    X= just_rr
    y = just_rr.pop("demand_F1")
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle = False)
    
    elastic_cv=ElasticNetCV(alphas=alphas, cv=5,max_iter = 1e6)
    model = elastic_cv.fit(X_train, y_train)
    pred = model.predict(X_test)
    print("OSR^2: " + str(metrics.r2_score(pred, y_test)))

    print(model.coef_)

# %%
def build_rr_only_model(brand):
    print("RR Only Model, " + brand)
    just_rr = pd.read_csv(onedrive_path + "Data/Combined/relative_rr_data_w_target_encodings_" + brand +".csv")
    just_rr = just_rr.loc[just_rr["year"] >= YEAR_MIN].drop("Unnamed: 0", axis = 1).sort_values(["month", "year"])
    
    just_rr = just_rr.loc[just_rr["demand"] > 0]
    just_rr = just_rr.loc[just_rr["percent_neutral"] + just_rr["percent_positive"] + just_rr["percent_negative"] > 0]
    
    X= just_rr[['month', 'year', 'percent_1', 'percent_2', 'percent_3', 'percent_4',
       'percent_5', 'percent_negative', 'percent_neutral', 'percent_positive']]
    y = just_rr["demand_F1"]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle = False)
    
    lm = LinearRegression()
    lm.fit(X_train, y_train)
    pred = lm.predict(X_test)
    print("OSR^2: " + str(metrics.r2_score(pred, y_test)))
    
    X2 = sm.add_constant(X_train)
    est = sm.OLS(y_train, X2)
    est2 = est.fit()

    print(est2.summary())

# %%
def build_demand_selected_rr_model(brand, rr_cols = []):
    print("Demand" + " ".join(rr_cols) + " Model, " + brand)
    just_rr = pd.read_csv(onedrive_path + "Data/Combined/relative_rr_data_w_target_encodings_" + brand +".csv")
    just_rr = just_rr.loc[just_rr["year"] >= YEAR_MIN].drop("Unnamed: 0", axis = 1).sort_values(["month", "year"])
    
    just_rr = just_rr.loc[just_rr["demand"] > 0]
    just_rr = just_rr.loc[just_rr["percent_neutral"] + just_rr["percent_positive"] + just_rr["percent_negative"] > 0]
    
    X= just_rr[['demand', 'demand_P2', 'demand_P1', 'avg_subcat_demand',
       'monthly_avg_demand', 'avg_12_month_demand',
       'month', 'year'] + rr_cols]
    y = just_rr["demand_F1"]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle = False)
    
    lm = LinearRegression()
    lm.fit(X_train, y_train)
    pred = lm.predict(X_test)
    print("OSR^2: " + str(metrics.r2_score(pred, y_test)))
    
    X2 = sm.add_constant(X_train)
    est = sm.OLS(y_train, X2)
    est2 = est.fit()

    print(est2.summary())

# %%
def build_rr_demand_model(brand):
    print("RR & Demand Model, " + brand)
    just_rr = pd.read_csv(onedrive_path + "Data/Combined/relative_rr_data_w_target_encodings_" + brand +".csv")
    just_rr = just_rr.loc[just_rr["year"] >= YEAR_MIN].drop("Unnamed: 0", axis = 1).sort_values(["month", "year"])
    
    just_rr = just_rr.loc[just_rr["demand"] > 0]
    just_rr = just_rr.loc[just_rr["percent_neutral"] + just_rr["percent_positive"] + just_rr["percent_negative"] > 0]
    
    X= just_rr
    y = just_rr.pop("demand_F1")
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle = False)
    
    lm = LinearRegression()
    lm.fit(X_train, y_train)
    pred = lm.predict(X_test)
    print("OSR^2: " + str(metrics.r2_score(pred, y_test)))
    
    X2 = sm.add_constant(X_train)
    est = sm.OLS(y_train, X2)
    est2 = est.fit()

    print(est2.summary())

# %%
def build_rr_demand_pca_model(brand, num_features = 10):
    print("RR & Demand PCA Model, " + brand)
    just_rr = pd.read_csv(onedrive_path + "Data/Combined/relative_rr_data_w_target_encodings_" + brand +".csv")
    just_rr = just_rr.loc[just_rr["year"] >= YEAR_MIN].drop("Unnamed: 0", axis = 1).sort_values(["month", "year"])
    
    just_rr = just_rr.loc[just_rr["demand"] > 0]
    just_rr = just_rr.loc[just_rr["percent_neutral"] + just_rr["percent_positive"] + just_rr["percent_negative"] > 0]
    
    X= just_rr
    y = just_rr.pop("demand_F1")
    
    X = StandardScaler().fit_transform(X)
    pca = PCA(n_components= num_features)
    principalComponents = pca.fit_transform(X)
    principalDf = pd.DataFrame(data = principalComponents)
    
    X_train, X_test, y_train, y_test = train_test_split(principalDf, y, shuffle = False)
    
    lm = LinearRegression()
    lm.fit(X_train, y_train)
    pred = lm.predict(X_test)
    print("OSR^2: " + str(metrics.r2_score(pred, y_test)))
    
    X2 = sm.add_constant(X_train)
    est = sm.OLS(y_train.values, X2)
    est2 = est.fit()

    print(est2.summary())
    
    for i,x in enumerate(pca.components_):
        print("Feature " + str(i))
        top = x.argsort()[-5:][::-1]
        table = [list(just_rr.columns[top]), x[top]]
        df = pd.DataFrame(np.transpose(table))
        print(df)

# %%
def nonlinearmodels(brand, n_iter = 10):
    print("---------")
    print(brand)
    cart = DecisionTreeRegressor()
    randomforest = RandomForestRegressor()
    xgboost = XGBRegressor()
    
    just_rr = pd.read_csv(onedrive_path + "Data/Combined/relative_rr_data_w_target_encodings_" + brand +".csv")
    just_rr = just_rr.loc[just_rr["year"] >= YEAR_MIN].drop("Unnamed: 0", axis = 1).sort_values(["month", "year"])
    
    just_rr = just_rr.loc[just_rr["demand"] > 0]
    just_rr = just_rr.loc[just_rr["percent_neutral"] + just_rr["percent_positive"] + just_rr["percent_negative"] > 0]
    
    X= just_rr
    y = just_rr.pop("demand_F1")
    X_demand = just_rr[['demand', 'demand_P2', 'demand_P1', 'avg_subcat_demand',
       'monthly_avg_demand', 'avg_12_month_demand',
       'month', 'year']]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle = False)
    X_demand_train, X_demand_est, y_demand_train, y_demand_test = train_test_split(X_demand, y, shuffle = False)
    
    params = {"CART": {'max_depth': [3, 4, 5, 6],
                       'min_samples_leaf': [0.04, 0.06, 0.08],
                       'max_features': [0.2, 0.4, 0.6, 0.8]},
             "RF": {'bootstrap': [True, False],
                    'max_depth': [5, 10, 30, 40, None],
                    'max_features': ['auto', 'sqrt'],
                    'min_samples_leaf': [1, 2, 4],
                    'min_samples_split': [2, 5, 10],
                    'n_estimators': [50, 100, 300]},
             "XGB":{'min_child_weight': np.arange(1, 20),
                    'gamma': np.arange(1, 6),
                    'subsample': [0.8, 1.0],
                    'alpha': [0.5, 1, 2, 5],
                    'colsample_bytree': [0.6, 0.8, 1.0],
                    'max_depth': [3, 4, 5]}}
    
    cart_cv = RandomizedSearchCV(cart, param_distributions=params["CART"], n_iter= n_iter, n_jobs=1, cv=3, error_score= "raise")
    print("CART")
    cart_cv.fit(X_train, y_train)
    print("Demand + RR: ", cart_cv.best_score_)
    cart_cv.fit(X_demand_train, y_demand_train)
    print("Demand Only: ", cart_cv.best_score_)
    
    
    rf_cv = RandomizedSearchCV(randomforest, param_distributions=params["RF"], n_iter=n_iter, n_jobs=1, cv=3, error_score= "raise")
    print("RF")
    rf_cv.fit(X_train, y_train)
    print("Demand + RR: ", rf_cv.best_score_)
    rf_cv.fit(X_demand_train, y_demand_train)
    print("Demand Only: ", rf_cv.best_score_)
    
    xgb_cv = RandomizedSearchCV(xgboost, param_distributions=params["XGB"], n_iter=n_iter, n_jobs=1, cv=3, error_score= "raise")
    print("XGB")
    xgb_cv.fit(X_train, y_train)
    print("Demand + RR: ", xgb_cv.best_score_)
    xgb_cv.fit(X_demand_train, y_demand_train)
    print("Demand Only: ", xgb_cv.best_score_)

# %% [markdown]
# ### Try models with lots of features

# %%
for brand in BRANDS:
    build_rr_demand_model(brand)
    build_rr_only_model(brand)
    build_rr_demand_pca_model(brand, num_features = 5)
# Out:
# RR & Demand Model, Aveda
# OSR^2: -0.21933450085030648
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.439
# Method:                 Least Squares   F-statistic:                     8.308
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           3.91e-12
# Time:                        09:50:26   Log-Likelihood:                -1521.7
# No. Observations:                 132   AIC:                             3073.
# Df Residuals:                     117   BIC:                             3117.
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                8.543e+05   3.24e+06      0.263      0.793   -5.57e+06    7.28e+06
# demand                  0.4398      0.105      4.193      0.000       0.232       0.648
# demand_P2              -0.1438      0.096     -1.503      0.136      -0.333       0.046
# demand_P1              -0.0689      0.097     -0.708      0.480      -0.262       0.124
# avg_subcat_demand       0.5998      0.178      3.363      0.001       0.247       0.953
# monthly_avg_demand     -0.9681      1.276     -0.759      0.450      -3.496       1.559
# avg_12_month_demand    -0.1118      1.478     -0.076      0.940      -3.040       2.816
# month                1014.5270   1692.887      0.599      0.550   -2338.147    4367.201
# year                 -644.8748   2462.610     -0.262      0.794   -5521.944    4232.194
# percent_1             1.73e+05    6.5e+05      0.266      0.790   -1.11e+06    1.46e+06
# percent_2            1.774e+05   6.48e+05      0.274      0.785   -1.11e+06    1.46e+06
# percent_3            1.621e+05   6.48e+05      0.250      0.803   -1.12e+06    1.45e+06
# percent_4            1.692e+05   6.48e+05      0.261      0.795   -1.12e+06    1.45e+06
# percent_5            1.726e+05   6.49e+05      0.266      0.791   -1.11e+06    1.46e+06
# percent_negative      3.08e+05   1.08e+06      0.285      0.776   -1.83e+06    2.45e+06
# percent_neutral       2.67e+05   1.08e+06      0.247      0.806   -1.88e+06    2.41e+06
# percent_positive     2.793e+05   1.08e+06      0.259      0.796   -1.86e+06    2.42e+06
# ==============================================================================
# Omnibus:                      116.571   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1901.602
# Skew:                           2.909   Prob(JB):                         0.00
# Kurtosis:                      20.661   Cond. No.                     2.15e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.8e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR Only Model, Aveda
# OSR^2: -61.96877662222439
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.9332
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):              0.492
# Time:                        09:50:27   Log-Likelihood:                -1563.4
# No. Observations:                 132   AIC:                             3145.
# Df Residuals:                     123   BIC:                             3171.
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.195e+06   4.18e+06      0.526      0.600   -6.07e+06    1.05e+07
# month              623.8610   1376.301      0.453      0.651   -2100.442    3348.165
# year             -1654.1224   3172.973     -0.521      0.603   -7934.827    4626.582
# percent_1         4.426e+05   8.37e+05      0.529      0.598   -1.21e+06     2.1e+06
# percent_2         4.417e+05   8.35e+05      0.529      0.598   -1.21e+06    2.09e+06
# percent_3         4.437e+05   8.34e+05      0.532      0.596   -1.21e+06     2.1e+06
# percent_4         4.252e+05   8.36e+05      0.509      0.612   -1.23e+06    2.08e+06
# percent_5         4.422e+05   8.36e+05      0.529      0.598   -1.21e+06     2.1e+06
# percent_negative  7.621e+05   1.39e+06      0.547      0.585   -1.99e+06    3.52e+06
# percent_neutral   7.079e+05   1.39e+06      0.508      0.613   -2.05e+06    3.47e+06
# percent_positive  7.254e+05   1.39e+06      0.521      0.603   -2.03e+06    3.48e+06
# ==============================================================================
# Omnibus:                       97.229   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              623.842
# Skew:                           2.674   Prob(JB):                    3.42e-136
# Kurtosis:                      12.210   Cond. No.                     4.28e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.93e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR & Demand PCA Model, Aveda
# OSR^2: -0.7129481566074314
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     16.56
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.51e-12
# Time:                        09:50:27   Log-Likelihood:                -1533.9
# No. Observations:                 132   AIC:                             3080.
# Df Residuals:                     126   BIC:                             3097.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.891e+04   2657.316     10.878      0.000    2.36e+04    3.42e+04
# 0           1.001e+04   1419.552      7.049      0.000    7197.745    1.28e+04
# 1          -8296.6873   1381.974     -6.004      0.000    -1.1e+04   -5561.802
# 2            378.3804   1890.646      0.200      0.842   -3363.152    4119.913
# 3           3125.7600   1970.797      1.586      0.115    -774.390    7025.909
# 4          -2620.5527   2278.292     -1.150      0.252   -7129.226    1888.120
# ==============================================================================
# Omnibus:                      124.509   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1802.796
# Skew:                           3.293   Prob(JB):                         0.00
# Kurtosis:                      19.864   Cond. No.                         2.20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Feature 0
#                    0                    1
# 0  avg_subcat_demand   0.3720038644508362
# 1             demand   0.3413403628737194
# 2   percent_negative  0.32609600234076874
# 3          demand_P1  0.32312458676301525
# 4          percent_1  0.31670668626661463
# Feature 1
#                   0                    1
# 0         percent_1   0.2776771683073643
# 1  percent_negative  0.27708697887022193
# 2   percent_neutral   0.2572675390689045
# 3         percent_4   0.1451678643150625
# 4              year   0.1418959795326965
# Feature 2
#                      0                    1
# 0  avg_12_month_demand   0.5709366453523408
# 1                month   0.5683149758742679
# 2   monthly_avg_demand  0.43052692348480937
# 3      percent_neutral  0.09689220434266121
# 4            percent_5   0.0900743038502631
# Feature 3
#                      0                    1
# 0            percent_4   0.5819459716011595
# 1            percent_2  0.28951438068404256
# 2     percent_positive  0.21564881290467383
# 3     percent_negative  0.13881742010169548
# 4  avg_12_month_demand   0.0839007364713485
# Feature 4
#                  0                    1
# 0        percent_3   0.6783317227911178
# 1  percent_neutral  0.31297105801566655
# 2        percent_4  0.30399683773184344
# 3        demand_P1  0.09287495756369836
# 4        demand_P2  0.09160820796904312
# RR & Demand Model, Clinique
# OSR^2: 0.8919635530899113
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     707.1
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):               0.00
# Time:                        09:50:27   Log-Likelihood:                -18941.
# No. Observations:                1408   AIC:                         3.791e+04
# Df Residuals:                    1393   BIC:                         3.799e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -4.917e+06   6.42e+06     -0.766      0.444   -1.75e+07    7.68e+06
# demand                  0.1721      0.027      6.461      0.000       0.120       0.224
# demand_P2               0.6104      0.027     22.955      0.000       0.558       0.663
# demand_P1               0.0882      0.026      3.364      0.001       0.037       0.140
# avg_subcat_demand       0.1343      0.030      4.408      0.000       0.075       0.194
# monthly_avg_demand     -0.0862      0.084     -1.023      0.306      -0.252       0.079
# avg_12_month_demand    -1.0552      0.155     -6.817      0.000      -1.359      -0.752
# month                1.193e+04   2848.347      4.188      0.000    6342.786    1.75e+04
# year                 3747.7015   4878.521      0.768      0.442   -5822.339    1.33e+04
# percent_1           -1.001e+06   1.29e+06     -0.777      0.437   -3.53e+06    1.52e+06
# percent_2           -9.807e+05   1.28e+06     -0.763      0.445    -3.5e+06    1.54e+06
# percent_3           -9.839e+05   1.28e+06     -0.766      0.444    -3.5e+06    1.53e+06
# percent_4           -9.815e+05   1.28e+06     -0.766      0.444    -3.5e+06    1.53e+06
# percent_5             -9.7e+05   1.29e+06     -0.754      0.451   -3.49e+06    1.55e+06
# percent_negative    -1.629e+06   2.14e+06     -0.761      0.447   -5.83e+06    2.57e+06
# percent_neutral     -1.651e+06   2.14e+06     -0.770      0.441   -5.85e+06    2.55e+06
# percent_positive    -1.637e+06   2.14e+06     -0.765      0.444   -5.83e+06    2.56e+06
# ==============================================================================
# Omnibus:                      972.887   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           203834.176
# Skew:                           2.164   Prob(JB):                         0.00
# Kurtosis:                      61.785   Cond. No.                     7.05e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.44e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR Only Model, Clinique
# OSR^2: -1360.9970988839254
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.1825
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):              0.993
# Time:                        09:50:27   Log-Likelihood:                -20414.
# No. Observations:                1408   AIC:                         4.085e+04
# Df Residuals:                    1399   BIC:                         4.089e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.024e+07   1.73e+07     -0.592      0.554   -4.41e+07    2.37e+07
# month             2002.6098   5461.585      0.367      0.714   -8711.169    1.27e+04
# year              7844.6314   1.31e+04      0.598      0.550   -1.79e+04    3.36e+04
# percent_1        -2.078e+06   3.46e+06     -0.600      0.549   -8.87e+06    4.72e+06
# percent_2        -2.038e+06   3.46e+06     -0.589      0.556   -8.82e+06    4.75e+06
# percent_3        -2.092e+06   3.45e+06     -0.606      0.545   -8.87e+06    4.68e+06
# percent_4        -2.001e+06   3.45e+06     -0.580      0.562   -8.77e+06    4.77e+06
# percent_5        -2.029e+06   3.46e+06     -0.586      0.558   -8.82e+06    4.76e+06
# percent_negative  -3.43e+06   5.76e+06     -0.595      0.552   -1.47e+07    7.87e+06
# percent_neutral   -3.41e+06   5.77e+06     -0.591      0.554   -1.47e+07     7.9e+06
# percent_positive -3.397e+06   5.76e+06     -0.590      0.555   -1.47e+07    7.89e+06
# ==============================================================================
# Omnibus:                     1612.611   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           117565.320
# Skew:                           5.893   Prob(JB):                         0.00
# Kurtosis:                      46.186   Cond. No.                     2.97e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.52e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR & Demand PCA Model, Clinique
# OSR^2: 0.9015166008484965
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     1630.
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):               0.00
# Time:                        09:50:27   Log-Likelihood:                -19064.
# No. Observations:                1408   AIC:                         3.814e+04
# Df Residuals:                    1402   BIC:                         3.817e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.78e+05   5398.564     32.976      0.000    1.67e+05    1.89e+05
# 0           2.534e+05   2846.618     89.030      0.000    2.48e+05    2.59e+05
# 1           1.007e+04   2956.894      3.405      0.001    4266.606    1.59e+04
# 2           4.389e+04   4111.384     10.674      0.000    3.58e+04     5.2e+04
# 3           6838.1350   4117.798      1.661      0.097   -1239.574    1.49e+04
# 4           4064.2527   4579.940      0.887      0.375   -4920.021     1.3e+04
# ==============================================================================
# Omnibus:                     1004.463   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           183757.336
# Skew:                           2.329   Prob(JB):                         0.00
# Kurtosis:                      58.772   Cond. No.                         2.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Feature 0
#                     0                    1
# 0   avg_subcat_demand   0.5005625546920554
# 1              demand   0.4974846199906536
# 2           demand_P1   0.4936676185306321
# 3           demand_P2  0.48964307487104547
# 4  monthly_avg_demand  0.08532481790953701
# Feature 1
#                   0                    1
# 0  percent_negative  0.41984108253095714
# 1         percent_1  0.38332936112182386
# 2   percent_neutral  0.31454281948730983
# 3         percent_2  0.19693868612506596
# 4         percent_3  0.19456661599080813
# Feature 2
#                    0                     1
# 0               year   0.21336212248889608
# 1  avg_subcat_demand   0.08257997981606234
# 2          demand_P2   0.06274847136371091
# 3          percent_2  0.043105352169439344
# 4          demand_P1    0.0399393465135307
# Feature 3
#                   0                    1
# 0         percent_4   0.6499324959733355
# 1  percent_positive   0.2368465932424847
# 2         percent_3  0.16773098711935058
# 3         percent_2  0.08430068928125055
# 4  percent_negative  0.03942812545625286
# Feature 4
#                  0                     1
# 0  percent_neutral     0.628133193499585
# 1        percent_3   0.34517087283715103
# 2        percent_4   0.19749113399491236
# 3        percent_5  0.017016396200476857
# 4        demand_P2  0.007004702574904204
# RR & Demand Model, Estée Lauder
# OSR^2: 0.7376882282692364
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     260.8
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):          3.67e-280
# Time:                        09:50:27   Log-Likelihood:                -9073.6
# No. Observations:                 782   AIC:                         1.818e+04
# Df Residuals:                     767   BIC:                         1.825e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2.301e+06   1.43e+06      1.605      0.109   -5.14e+05    5.12e+06
# demand                  0.2215      0.044      5.010      0.000       0.135       0.308
# demand_P2              -0.0747      0.048     -1.569      0.117      -0.168       0.019
# demand_P1               0.0120      0.045      0.266      0.791      -0.076       0.100
# avg_subcat_demand       0.8153      0.100      8.159      0.000       0.619       1.011
# monthly_avg_demand     -0.0937      0.276     -0.340      0.734      -0.635       0.448
# avg_12_month_demand    -1.0651      0.225     -4.726      0.000      -1.507      -0.623
# month                1399.0353    571.589      2.448      0.015     276.971    2521.100
# year                -1745.7339   1088.401     -1.604      0.109   -3882.332     390.864
# percent_1            4.528e+05   2.87e+05      1.577      0.115   -1.11e+05    1.02e+06
# percent_2            4.789e+05   2.87e+05      1.667      0.096   -8.51e+04    1.04e+06
# percent_3            4.587e+05   2.87e+05      1.600      0.110   -1.04e+05    1.02e+06
# percent_4            4.549e+05   2.86e+05      1.590      0.112   -1.07e+05    1.02e+06
# percent_5            4.553e+05   2.87e+05      1.588      0.113   -1.08e+05    1.02e+06
# percent_negative     7.585e+05   4.78e+05      1.587      0.113    -1.8e+05     1.7e+06
# percent_neutral      7.666e+05   4.78e+05      1.603      0.109   -1.72e+05    1.71e+06
# percent_positive     7.754e+05   4.78e+05      1.623      0.105   -1.63e+05    1.71e+06
# ==============================================================================
# Omnibus:                      498.872   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            80388.314
# Skew:                           1.842   Prob(JB):                         0.00
# Kurtosis:                      52.534   Cond. No.                     7.74e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.27e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR Only Model, Estée Lauder
# OSR^2: -105.5464167002967
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.7008
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):              0.691
# Time:                        09:50:27   Log-Likelihood:                -9755.4
# No. Observations:                 782   AIC:                         1.953e+04
# Df Residuals:                     773   BIC:                         1.957e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             4.454e+06   3.09e+06      1.442      0.150   -1.61e+06    1.05e+07
# month              136.1065    964.305      0.141      0.888   -1756.860    2029.073
# year             -3370.5812   2346.215     -1.437      0.151   -7976.290    1235.127
# percent_1         8.756e+05   6.19e+05      1.415      0.157   -3.39e+05    2.09e+06
# percent_2         9.109e+05   6.19e+05      1.471      0.142   -3.05e+05    2.13e+06
# percent_3         8.965e+05   6.18e+05      1.451      0.147   -3.16e+05    2.11e+06
# percent_4         8.887e+05   6.16e+05      1.442      0.150   -3.21e+05     2.1e+06
# percent_5         8.824e+05   6.18e+05      1.428      0.154    -3.3e+05    2.09e+06
# percent_negative  1.486e+06   1.03e+06      1.444      0.149   -5.34e+05    3.51e+06
# percent_neutral   1.476e+06   1.03e+06      1.433      0.152   -5.47e+05     3.5e+06
# percent_positive  1.492e+06   1.03e+06      1.448      0.148    -5.3e+05    3.51e+06
# ==============================================================================
# Omnibus:                      740.611   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17695.877
# Skew:                           4.548   Prob(JB):                         0.00
# Kurtosis:                      24.456   Cond. No.                     3.71e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.31e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR & Demand PCA Model, Estée Lauder
# OSR^2: 0.7599883453263354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     649.2
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):          2.27e-274
# Time:                        09:50:27   Log-Likelihood:                -9114.8
# No. Observations:                 782   AIC:                         1.824e+04
# Df Residuals:                     776   BIC:                         1.827e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.408e+04   1061.903     22.678      0.000     2.2e+04    2.62e+04
# 0           2.915e+04    512.561     56.873      0.000    2.81e+04    3.02e+04
# 1              9.1703    635.529      0.014      0.988   -1238.389    1256.730
# 2           2401.6303    767.715      3.128      0.002     894.585    3908.675
# 3            291.4976    847.032      0.344      0.731   -1371.248    1954.244
# 4          -1935.3163    932.301     -2.076      0.038   -3765.448    -105.185
# ==============================================================================
# Omnibus:                      497.613   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            74011.237
# Skew:                           1.857   Prob(JB):                         0.00
# Kurtosis:                      50.515   Cond. No.                         2.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Feature 0
#                    0                    1
# 0  avg_subcat_demand   0.5138878929645865
# 1          demand_P1   0.4965922880521669
# 2             demand  0.49300890656345203
# 3          demand_P2  0.49292767892811595
# 4   percent_positive  0.02476480703054312
# Feature 1
#                   0                    1
# 0  percent_negative  0.39999421424607373
# 1         percent_1   0.3886242163787046
# 2   percent_neutral  0.36122561533189396
# 3         percent_3    0.183207006119494
# 4         percent_2  0.16133688407626756
# Feature 2
#                   0                    1
# 0              year   0.3254761806353848
# 1         percent_4  0.13877863548082675
# 2         percent_3   0.0579698291603337
# 3         percent_2  0.05780648783884905
# 4  percent_negative    0.056204830691643
# Feature 3
#                     0                    1
# 0           percent_4   0.6398947040012253
# 1    percent_positive  0.24216030268492258
# 2           percent_3  0.19394619379805184
# 3  monthly_avg_demand  0.17812852242860083
# 4           percent_2  0.07838710465628172
# Feature 4
#                      0                    1
# 0            percent_2   0.5391139334900908
# 1                 year  0.37908908869432034
# 2  avg_12_month_demand  0.32753007521352484
# 3     percent_negative  0.24284510482613203
# 4                month   0.2408218794580016
# RR & Demand Model, Jo Malone London
# OSR^2: -5.579115308879251
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.705
# Method:                 Least Squares   F-statistic:                     5.350
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):            0.00894
# Time:                        09:50:27   Log-Likelihood:                -154.89
# No. Observations:                  21   AIC:                             333.8
# Df Residuals:                       9   BIC:                             346.3
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -3.445e+05   1.92e+05     -1.790      0.107    -7.8e+05    9.09e+04
# demand                 -0.4317      0.192     -2.247      0.051      -0.866       0.003
# demand_P2              -0.1628      0.115     -1.411      0.192      -0.424       0.098
# demand_P1               0.0549      0.141      0.390      0.706      -0.263       0.373
# avg_subcat_demand       0.8842      0.360      2.459      0.036       0.071       1.698
# monthly_avg_demand     -0.3108      0.794     -0.391      0.705      -2.107       1.485
# avg_12_month_demand     0.4614      1.039      0.444      0.667      -1.889       2.812
# month                  67.4621    121.685      0.554      0.593    -207.809     342.733
# year                  314.2713    174.767      1.798      0.106     -81.080     709.623
# percent_1            1.196e-08   6.68e-09      1.790      0.107   -3.16e-09    2.71e-08
# percent_2           -7.355e-09   4.11e-09     -1.790      0.107   -1.67e-08    1.94e-09
# percent_3            1.739e-09   9.71e-10      1.790      0.107   -4.58e-10    3.94e-09
# percent_4           -1.718e+05   9.62e+04     -1.785      0.108    -3.9e+05    4.59e+04
# percent_5           -1.727e+05   9.62e+04     -1.795      0.106    -3.9e+05     4.5e+04
# percent_negative    -1.149e+05   6.49e+04     -1.771      0.110   -2.62e+05    3.18e+04
# percent_neutral     -1.125e+05   6.37e+04     -1.767      0.111   -2.57e+05    3.15e+04
# percent_positive    -1.171e+05    6.4e+04     -1.831      0.100   -2.62e+05    2.76e+04
# ==============================================================================
# Omnibus:                        0.821   Durbin-Watson:                   2.165
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.812
# Skew:                           0.386   Prob(JB):                        0.666
# Kurtosis:                       2.424   Cond. No.                     1.15e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.17e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR Only Model, Jo Malone London
# OSR^2: -12.388942934548542
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     3.637
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):             0.0236
# Time:                        09:50:27   Log-Likelihood:                -167.76
# No. Observations:                  21   AIC:                             347.5
# Df Residuals:                      15   BIC:                             353.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.755e+05    2.5e+05     -0.703      0.493   -7.08e+05    3.57e+05
# month              161.2529     96.543      1.670      0.116     -44.525     367.030
# year               161.2442    226.689      0.711      0.488    -321.932     644.421
# percent_1         1.585e-09   2.26e-09      0.702      0.493   -3.22e-09    6.39e-09
# percent_2          6.05e-09   8.61e-09      0.703      0.493   -1.23e-08    2.44e-08
# percent_3         4.132e-10   5.89e-10      0.701      0.494   -8.42e-10    1.67e-09
# percent_4        -8.732e+04   1.25e+05     -0.699      0.495   -3.53e+05    1.79e+05
# percent_5         -8.82e+04   1.25e+05     -0.706      0.491   -3.54e+05    1.78e+05
# percent_negative -5.689e+04   8.42e+04     -0.676      0.510   -2.36e+05    1.23e+05
# percent_neutral  -5.721e+04   8.28e+04     -0.691      0.500   -2.34e+05    1.19e+05
# percent_positive -6.142e+04   8.29e+04     -0.741      0.470   -2.38e+05    1.15e+05
# ==============================================================================
# Omnibus:                        2.777   Durbin-Watson:                   2.246
# Prob(Omnibus):                  0.249   Jarque-Bera (JB):                1.176
# Skew:                           0.462   Prob(JB):                        0.555
# Kurtosis:                       3.702   Cond. No.                     1.05e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.81e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR & Demand PCA Model, Jo Malone London
# OSR^2: -8.029490624573171
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     5.963
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):            0.00313
# Time:                        09:50:27   Log-Likelihood:                -164.61
# No. Observations:                  21   AIC:                             341.2
# Df Residuals:                      15   BIC:                             347.5
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1695.4243    192.548      8.805      0.000    1285.017    2105.831
# 0            356.2766    106.563      3.343      0.004     129.143     583.410
# 1            171.5804    114.176      1.503      0.154     -71.780     414.940
# 2            386.0322    117.462      3.286      0.005     135.667     636.397
# 3            -86.9873    174.278     -0.499      0.625    -458.453     284.478
# 4            135.4277    127.065      1.066      0.303    -135.405     406.260
# ==============================================================================
# Omnibus:                        0.649   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.723   Jarque-Bera (JB):                0.476
# Skew:                           0.342   Prob(JB):                        0.788
# Kurtosis:                       2.723   Cond. No.                         2.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Feature 0
#                      0                    1
# 0  avg_12_month_demand   0.4131158230550101
# 1               demand  0.35582952278925073
# 2                month  0.33744544676426425
# 3    avg_subcat_demand   0.3227747175574735
# 4      percent_neutral   0.3224925949364956
# Feature 1
#                    0                    1
# 0  avg_subcat_demand   0.4209535398097203
# 1               year  0.37730476328464774
# 2   percent_negative   0.3434774856956991
# 3          demand_P2    0.338249667083497
# 4          demand_P1  0.32756480677054894
# Feature 2
#                      0                    1
# 0            percent_4  0.48990134139379815
# 1      percent_neutral  0.29039171519859047
# 2            demand_P2  0.25308314152999617
# 3                month  0.23547949555044342
# 4  avg_12_month_demand  0.14334237979348638
# Feature 3
#                     0                    1
# 0  monthly_avg_demand  0.44096055451411453
# 1              demand   0.3857878119937068
# 2               month  0.32475143324441813
# 3           percent_4    0.321168220758505
# 4    percent_positive   0.2684927960658882
# Feature 4
#                     0                    1
# 0    percent_negative   0.4845069255119885
# 1                year  0.42089798714092735
# 2     percent_neutral   0.2115537064654794
# 3  monthly_avg_demand   0.1475552531920574
# 4           percent_4  0.11961499095077874
# RR & Demand Model, La Mer
# OSR^2: -0.2066623232646474
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     3.624
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           2.07e-05
# Time:                        09:50:27   Log-Likelihood:                -2755.5
# No. Observations:                 231   AIC:                             5541.
# Df Residuals:                     216   BIC:                             5593.
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                4.929e+05   3.45e+06      0.143      0.887   -6.31e+06    7.29e+06
# demand                 -0.3018      0.102     -2.944      0.004      -0.504      -0.100
# demand_P2              -0.0655      0.104     -0.629      0.530      -0.271       0.140
# demand_P1              -0.2570      0.101     -2.556      0.011      -0.455      -0.059
# avg_subcat_demand       1.4023      0.311      4.504      0.000       0.789       2.016
# monthly_avg_demand      0.3140      0.574      0.547      0.585      -0.818       1.446
# avg_12_month_demand    -1.1778      1.188     -0.991      0.323      -3.519       1.164
# month                1515.1656   1771.006      0.856      0.393   -1975.500    5005.832
# year                 -373.1393   2620.402     -0.142      0.887   -5537.972    4791.693
# percent_1            1.012e+05    6.9e+05      0.147      0.884   -1.26e+06    1.46e+06
# percent_2            1.012e+05   6.91e+05      0.146      0.884   -1.26e+06    1.46e+06
# percent_3            9.222e+04    6.9e+05      0.134      0.894   -1.27e+06    1.45e+06
# percent_4            9.917e+04    6.9e+05      0.144      0.886   -1.26e+06    1.46e+06
# percent_5            9.918e+04   6.89e+05      0.144      0.886   -1.26e+06    1.46e+06
# percent_negative     1.683e+05   1.15e+06      0.146      0.884    -2.1e+06    2.43e+06
# percent_neutral      1.596e+05   1.15e+06      0.139      0.890   -2.11e+06    2.43e+06
# percent_positive      1.65e+05   1.15e+06      0.143      0.886    -2.1e+06    2.43e+06
# ==============================================================================
# Omnibus:                      317.568   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35742.959
# Skew:                           6.056   Prob(JB):                         0.00
# Kurtosis:                      62.723   Cond. No.                     1.53e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.7e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR Only Model, La Mer
# OSR^2: -17.653089076172495
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.023
# Method:                 Least Squares   F-statistic:                    0.3478
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):              0.946
# Time:                        09:50:27   Log-Likelihood:                -2778.4
# No. Observations:                 231   AIC:                             5575.
# Df Residuals:                     222   BIC:                             5606.
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              2.31e+06   3.47e+06      0.666      0.506   -4.53e+06    9.15e+06
# month               97.6602   1229.663      0.079      0.937   -2325.645    2520.965
# year             -1745.9425   2634.280     -0.663      0.508   -6937.339    3445.454
# percent_1         4.727e+05   6.94e+05      0.681      0.496   -8.95e+05    1.84e+06
# percent_2         4.641e+05   6.96e+05      0.667      0.505   -9.07e+05    1.84e+06
# percent_3         4.519e+05   6.93e+05      0.652      0.515   -9.14e+05    1.82e+06
# percent_4          4.59e+05   6.93e+05      0.662      0.509   -9.08e+05    1.83e+06
# percent_5         4.627e+05   6.93e+05      0.668      0.505   -9.03e+05    1.83e+06
# percent_negative  7.765e+05   1.16e+06      0.671      0.503    -1.5e+06    3.06e+06
# percent_neutral   7.644e+05   1.16e+06      0.661      0.509   -1.51e+06    3.04e+06
# percent_positive  7.695e+05   1.16e+06      0.665      0.507   -1.51e+06    3.05e+06
# ==============================================================================
# Omnibus:                      330.952   Durbin-Watson:                   2.117
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            38172.468
# Skew:                           6.550   Prob(JB):                         0.00
# Kurtosis:                      64.598   Cond. No.                     6.12e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.51e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR & Demand PCA Model, La Mer
# OSR^2: -0.07185516387022028
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     5.598
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           6.97e-05
# Time:                        09:50:27   Log-Likelihood:                -2766.3
# No. Observations:                 231   AIC:                             5545.
# Df Residuals:                     225   BIC:                             5565.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.836e+04   2766.070      6.636      0.000    1.29e+04    2.38e+04
# 0           2914.8316   1466.384      1.988      0.048      25.229    5804.434
# 1           7486.7322   1680.525      4.455      0.000    4175.152    1.08e+04
# 2           2845.6379   2181.038      1.305      0.193   -1452.236    7143.512
# 3          -2525.9373   2054.888     -1.229      0.220   -6575.225    1523.351
# 4            894.9669   2297.649      0.390      0.697   -3632.696    5422.630
# ==============================================================================
# Omnibus:                      333.993   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41983.489
# Skew:                           6.619   Prob(JB):                         0.00
# Kurtosis:                      67.705   Cond. No.                         2.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Feature 0
#                    0                    1
# 0          percent_1   0.4240950377198691
# 1   percent_negative   0.4199643340004445
# 2    percent_neutral  0.24995164127287292
# 3  avg_subcat_demand  0.20121724996455528
# 4             demand  0.14325649100264568
# Feature 1
#                    0                    1
# 0  avg_subcat_demand   0.5861068701103501
# ...
# Dep. Variable:              demand_F1   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     1.680
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):              0.103
# Time:                        09:50:27   Log-Likelihood:                -3582.6
# No. Observations:                 294   AIC:                             7183.
# Df Residuals:                     285   BIC:                             7216.
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1.092e+07   3.78e+06      2.892      0.004    3.49e+06    1.84e+07
# month              490.4039   1214.680      0.404      0.687   -1900.478    2881.286
# year             -8283.7546   2868.601     -2.888      0.004   -1.39e+04   -2637.422
# percent_1          2.17e+06   7.54e+05      2.877      0.004    6.85e+05    3.65e+06
# percent_2         2.183e+06   7.56e+05      2.889      0.004    6.95e+05    3.67e+06
# percent_3         2.179e+06   7.55e+05      2.886      0.004    6.93e+05    3.67e+06
# percent_4         2.197e+06   7.57e+05      2.903      0.004    7.07e+05    3.69e+06
# percent_5         2.194e+06   7.56e+05      2.902      0.004    7.06e+05    3.68e+06
# percent_negative  3.666e+06   1.26e+06      2.913      0.004    1.19e+06    6.14e+06
# percent_neutral   3.625e+06   1.26e+06      2.876      0.004    1.14e+06    6.11e+06
# percent_positive  3.631e+06   1.26e+06      2.886      0.004    1.15e+06    6.11e+06
# ==============================================================================
# Omnibus:                      197.614   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1638.186
# Skew:                           2.771   Prob(JB):                         0.00
# Kurtosis:                      13.149   Cond. No.                     3.85e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.07e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR & Demand PCA Model, Origins
# OSR^2: 0.5924469428777159
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.490
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     55.40
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           3.31e-40
# Time:                        09:50:27   Log-Likelihood:                -3490.3
# No. Observations:                 294   AIC:                             6993.
# Df Residuals:                     288   BIC:                             7015.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.957e+04   2217.182     13.338      0.000    2.52e+04    3.39e+04
# 0           1.779e+04   1141.198     15.588      0.000    1.55e+04       2e+04
# 1           3229.5858   1309.688      2.466      0.014     651.812    5807.360
# 2           6587.9330   1592.847      4.136      0.000    3452.835    9723.031
# 3          -2050.6692   1770.219     -1.158      0.248   -5534.877    1433.539
# 4            -45.1228   1956.325     -0.023      0.982   -3895.630    3805.385
# ==============================================================================
# Omnibus:                      259.892   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5807.403
# Skew:                           3.558   Prob(JB):                         0.00
# Kurtosis:                      23.578   Cond. No.                         2.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Feature 0
#                    0                    1
# 0  avg_subcat_demand  0.49046006064386183
# 1          demand_P1  0.45399043556732643
# 2             demand   0.4393474117809174
# 3          demand_P2   0.4270492364111553
# 4   percent_positive   0.1739562224963157
# Feature 1
#                      0                    1
# 0     percent_negative   0.3925249160574877
# 1            percent_1   0.3904478799506162
# 2      percent_neutral   0.2904076731072907
# 3                month  0.20908175300303578
# 4  avg_12_month_demand    0.200629145334425
# Feature 2
#                    0                    1
# 0          percent_4  0.26765062256262945
# 1               year   0.2421879969235048
# 2  avg_subcat_demand  0.20803706331746968
# 3             demand   0.1517248778394162
# 4          demand_P2   0.1428322712874665
# Feature 3
#                     0                    1
# 0           percent_3    0.499016791179773
# 1  monthly_avg_demand    0.426344505040077
# 2    percent_negative  0.20359688699130704
# 3    percent_positive  0.18008076664480313
# 4           percent_4  0.07269799091648221
# Feature 4
#                      0                    1
# 0            percent_2  0.44028089035377327
# 1            percent_3  0.40663037122579165
# 2                 year  0.37264625426114356
# 3     percent_negative  0.25898037574571536
# 4  avg_12_month_demand  0.21870759058672615
# RR & Demand Model, Tom Ford Beauty
# OSR^2: 0.70570148983119
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     37.98
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.71e-66
# Time:                        09:50:27   Log-Likelihood:                -4828.3
# No. Observations:                 450   AIC:                             9687.
# Df Residuals:                     435   BIC:                             9748.
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                4.361e+05   7.92e+05      0.551      0.582   -1.12e+06    1.99e+06
# demand                  0.1252      0.059      2.108      0.036       0.008       0.242
# demand_P2            7.943e-05      0.073      0.001      0.999      -0.143       0.143
# demand_P1              -0.1425      0.065     -2.177      0.030      -0.271      -0.014
# avg_subcat_demand       0.9777      0.139      7.040      0.000       0.705       1.251
# monthly_avg_demand     -0.6787      0.342     -1.983      0.048      -1.351      -0.006
# avg_12_month_demand    -1.5849      0.536     -2.955      0.003      -2.639      -0.531
# month                  96.7360    262.774      0.368      0.713    -419.729     613.201
# year                 -328.7361    601.037     -0.547      0.585   -1510.035     852.562
# percent_1            8.491e+04   1.59e+05      0.535      0.593   -2.27e+05    3.97e+05
# percent_2            8.786e+04   1.58e+05      0.555      0.579   -2.23e+05    3.99e+05
# percent_3            8.836e+04   1.58e+05      0.559      0.577   -2.22e+05    3.99e+05
# percent_4            8.681e+04   1.58e+05      0.549      0.584   -2.24e+05    3.98e+05
# percent_5            8.816e+04   1.58e+05      0.557      0.578   -2.23e+05    3.99e+05
# percent_negative     1.471e+05   2.64e+05      0.557      0.578   -3.72e+05    6.66e+05
# percent_neutral      1.442e+05   2.64e+05      0.546      0.585   -3.74e+05    6.63e+05
# percent_positive     1.448e+05   2.64e+05      0.549      0.583   -3.73e+05    6.63e+05
# ==============================================================================
# Omnibus:                      496.476   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37233.286
# Skew:                           4.883   Prob(JB):                         0.00
# Kurtosis:                      46.479   Cond. No.                     2.28e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.07e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR Only Model, Tom Ford Beauty
# OSR^2: -29.117932782076174
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8472
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):              0.561
# Time:                        09:50:27   Log-Likelihood:                -5004.6
# No. Observations:                 450   AIC:                         1.003e+04
# Df Residuals:                     441   BIC:                         1.006e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1.638e+06   1.12e+06      1.467      0.143   -5.56e+05    3.83e+06
# month             -404.3527    332.343     -1.217      0.224   -1057.525     248.820
# year             -1239.9481    847.640     -1.463      0.144   -2905.863     425.967
# percent_1          3.24e+05   2.24e+05      1.449      0.148   -1.15e+05    7.63e+05
# percent_2         3.255e+05   2.23e+05      1.458      0.146   -1.13e+05    7.64e+05
# percent_3         3.291e+05   2.23e+05      1.476      0.141   -1.09e+05    7.67e+05
# percent_4         3.294e+05   2.23e+05      1.476      0.141   -1.09e+05    7.68e+05
# percent_5         3.299e+05   2.23e+05      1.477      0.140   -1.09e+05    7.69e+05
# percent_negative  5.465e+05   3.72e+05      1.467      0.143   -1.86e+05    1.28e+06
# percent_neutral   5.488e+05   3.72e+05      1.475      0.141   -1.83e+05    1.28e+06
# percent_positive  5.426e+05   3.72e+05      1.460      0.145   -1.88e+05    1.27e+06
# ==============================================================================
# Omnibus:                      510.874   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26949.255
# Skew:                           5.325   Prob(JB):                         0.00
# Kurtosis:                      39.385   Cond. No.                     1.66e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.67e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# RR & Demand PCA Model, Tom Ford Beauty
# OSR^2: 0.7022218360182675
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                     88.28
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           2.53e-64
# Time:                        09:50:27   Log-Likelihood:                -4852.7
# No. Observations:                 450   AIC:                             9717.
# Df Residuals:                     444   BIC:                             9742.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5659.3292    596.891      9.481      0.000    4486.247    6832.412
# 0           6384.4931    307.044     20.793      0.000    5781.053    6987.933
# 1           -116.4258    339.263     -0.343      0.732    -783.186     550.334
# 2           -688.6631    470.316     -1.464      0.144   -1612.986     235.660
# 3          -1221.3545    461.185     -2.648      0.008   -2127.731    -314.978
# 4           -704.1381    496.734     -1.418      0.157   -1680.380     272.104
# ==============================================================================
# Omnibus:                      471.076   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36223.620
# Skew:                           4.434   Prob(JB):                         0.00
# Kurtosis:                      46.050   Cond. No.                         2.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Feature 0
#                    0                    1
# 0  avg_subcat_demand   0.5403877945631066
# 1          demand_P1  0.48954786171662185
# 2          demand_P2  0.47666094955064225
# 3             demand    0.470565610397804
# 4    percent_neutral  0.08792462592113463
# Feature 1
#                   0                    1
# 0  percent_negative  0.46864500773973705
# 1         percent_1   0.3842814510066846
# 2   percent_neutral  0.22003313450800163
# 3         percent_3  0.17385939722746543
# 4         percent_2  0.14679864969648926
# Feature 2
#                      0                     1
# 0                month    0.6216559968807014
# 1  avg_12_month_demand    0.5547519643625004
# 2            percent_4    0.2959484308798453
# 3     percent_positive   0.03431237536073717
# 4            demand_P2  0.021970661501234917
# Feature 3
#                      0                    1
# 0      percent_neutral    0.653657260058903
# 1            percent_5   0.3808022934050659
# 2  avg_12_month_demand   0.2125094444894274
# 3                 year   0.1349493144233867
# 4                month  0.09194559078838398
# Feature 4
#                     0                    1
# 0           percent_4  0.46799865121555706
# 1     percent_neutral  0.37507234226957553
# 2  monthly_avg_demand  0.37267106979698494
# 3           percent_3  0.20250838468026294
# 4           percent_2  0.11635766884412493

# %% [markdown]
# ### Try just adding percent negative and percent neutral
# #### These seemed to have a shot at working

# %%
for brand in BRANDS:
    build_demand_selected_rr_model(brand, rr_cols = [])
    build_demand_selected_rr_model(brand, rr_cols = ["percent_negative", "percent_neutral"])
# Out:
# Demand Model, Aveda
# OSR^2: -0.30461383773332296
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.476
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     13.99
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           2.54e-14
# Time:                        09:50:27   Log-Likelihood:                -1524.6
# No. Observations:                 132   AIC:                             3067.
# Df Residuals:                     123   BIC:                             3093.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                7.853e+05   4.76e+06      0.165      0.869   -8.64e+06    1.02e+07
# demand                  0.4302      0.103      4.170      0.000       0.226       0.634
# demand_P2              -0.1549      0.094     -1.652      0.101      -0.341       0.031
# demand_P1              -0.0866      0.096     -0.903      0.368      -0.277       0.103
# avg_subcat_demand       0.6473      0.173      3.748      0.000       0.305       0.989
# monthly_avg_demand     -0.3773      1.218     -0.310      0.757      -2.789       2.034
# avg_12_month_demand    -0.3671      1.439     -0.255      0.799      -3.215       2.481
# month                1084.8449   1658.338      0.654      0.514   -2197.733    4367.423
# year                 -388.1509   2358.707     -0.165      0.870   -5057.067    4280.765
# ==============================================================================
# Omnibus:                      121.342   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1948.174
# Skew:                           3.106   Prob(JB):                         0.00
# Kurtosis:                      20.766   Cond. No.                     1.67e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, Aveda
# OSR^2: -0.24085440948058356
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     11.90
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           4.30e-14
# Time:                        09:50:27   Log-Likelihood:                -1522.1
# No. Observations:                 132   AIC:                             3066.
# Df Residuals:                     121   BIC:                             3098.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.169e+06   4.85e+06      0.241      0.810   -8.44e+06    1.08e+07
# demand                  0.4416      0.103      4.297      0.000       0.238       0.645
# demand_P2              -0.1417      0.093     -1.517      0.132      -0.327       0.043
# demand_P1              -0.0664      0.096     -0.694      0.489      -0.256       0.123
# avg_subcat_demand       0.5927      0.175      3.392      0.001       0.247       0.939
# monthly_avg_demand     -0.7855      1.235     -0.636      0.526      -3.231       1.660
# avg_12_month_demand    -0.1130      1.430     -0.079      0.937      -2.943       2.717
# month                 880.4188   1644.674      0.535      0.593   -2375.647    4136.485
# year                 -577.3637   2404.661     -0.240      0.811   -5338.024    4183.296
# percent_negative     2.798e+04   1.44e+04      1.948      0.054    -461.497    5.64e+04
# percent_neutral     -1.268e+04   1.33e+04     -0.951      0.343   -3.91e+04    1.37e+04
# ==============================================================================
# Omnibus:                      116.737   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1909.376
# Skew:                           2.914   Prob(JB):                         0.00
# Kurtosis:                      20.698   Cond. No.                     1.72e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.72e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demand Model, Clinique
# OSR^2: 0.8919651955684454
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     1242.
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):               0.00
# Time:                        09:50:27   Log-Likelihood:                -18942.
# No. Observations:                1408   AIC:                         3.790e+04
# Df Residuals:                    1399   BIC:                         3.795e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -7.029e+06   9.68e+06     -0.726      0.468    -2.6e+07     1.2e+07
# demand                  0.1726      0.027      6.493      0.000       0.120       0.225
# demand_P2               0.6107      0.027     23.007      0.000       0.559       0.663
# demand_P1               0.0882      0.026      3.372      0.001       0.037       0.140
# avg_subcat_demand       0.1337      0.030      4.397      0.000       0.074       0.193
# monthly_avg_demand     -0.0904      0.084     -1.076      0.282      -0.255       0.074
# avg_12_month_demand    -1.0505      0.154     -6.811      0.000      -1.353      -0.748
# month                1.187e+04   2841.064      4.178      0.000    6295.515    1.74e+04
# year                 3499.0411   4795.218      0.730      0.466   -5907.551    1.29e+04
# ==============================================================================
# Omnibus:                      972.534   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           204247.595
# Skew:                           2.162   Prob(JB):                         0.00
# Kurtosis:                      61.846   Cond. No.                     1.99e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.99e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, Clinique
# OSR^2: 0.8921331737136382
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     992.2
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):               0.00
# Time:                        09:50:27   Log-Likelihood:                -18942.
# No. Observations:                1408   AIC:                         3.791e+04
# Df Residuals:                    1397   BIC:                         3.796e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -7.643e+06   9.72e+06     -0.786      0.432   -2.67e+07    1.14e+07
# demand                  0.1724      0.027      6.480      0.000       0.120       0.225
# demand_P2               0.6107      0.027     22.995      0.000       0.559       0.663
# demand_P1               0.0879      0.026      3.357      0.001       0.037       0.139
# avg_subcat_demand       0.1342      0.030      4.409      0.000       0.074       0.194
# monthly_avg_demand     -0.0881      0.084     -1.048      0.295      -0.253       0.077
# avg_12_month_demand    -1.0488      0.154     -6.794      0.000      -1.352      -0.746
# month                1.186e+04   2842.592      4.172      0.000    6283.799    1.74e+04
# year                 3805.9359   4818.066      0.790      0.430   -5645.489    1.33e+04
# percent_negative    -2.642e+04   5.15e+04     -0.513      0.608   -1.28e+05    7.47e+04
# percent_neutral     -2.447e+04   4.38e+04     -0.558      0.577    -1.1e+05    6.15e+04
# ==============================================================================
# Omnibus:                      972.641   Durbin-Watson:                   1.827
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           203968.145
# Skew:                           2.162   Prob(JB):                         0.00
# Kurtosis:                      61.805   Cond. No.                     2.00e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  2e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demand Model, Estée Lauder
# OSR^2: 0.7425405657814159
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     453.9
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):          4.60e-286
# Time:                        09:50:27   Log-Likelihood:                -9077.8
# No. Observations:                 782   AIC:                         1.817e+04
# Df Residuals:                     773   BIC:                         1.822e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                3.585e+06   2.17e+06      1.649      0.100   -6.84e+05    7.85e+06
# demand                  0.2221      0.044      5.020      0.000       0.135       0.309
# demand_P2              -0.0745      0.048     -1.562      0.119      -0.168       0.019
# demand_P1               0.0139      0.045      0.310      0.757      -0.074       0.102
# avg_subcat_demand       0.8131      0.100      8.131      0.000       0.617       1.009
# monthly_avg_demand     -0.1341      0.275     -0.487      0.627      -0.675       0.407
# avg_12_month_demand    -1.0369      0.225     -4.606      0.000      -1.479      -0.595
# month                1320.2142    568.987      2.320      0.021     203.272    2437.156
# year                -1772.8334   1076.729     -1.646      0.100   -3886.493     340.826
# ==============================================================================
# Omnibus:                      513.006   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            82836.408
# Skew:                           1.936   Prob(JB):                         0.00
# Kurtosis:                      53.272   Cond. No.                     2.99e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.99e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, Estée Lauder
# OSR^2: 0.7423325667038885
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.825
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     363.4
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):          7.27e-284
# Time:                        09:50:27   Log-Likelihood:                -9076.7
# No. Observations:                 782   AIC:                         1.818e+04
# Df Residuals:                     771   BIC:                         1.823e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                3.357e+06   2.18e+06      1.540      0.124   -9.23e+05    7.64e+06
# demand                  0.2231      0.044      5.040      0.000       0.136       0.310
# demand_P2              -0.0758      0.048     -1.589      0.112      -0.169       0.018
# demand_P1               0.0154      0.045      0.343      0.732      -0.073       0.104
# avg_subcat_demand       0.8116      0.100      8.116      0.000       0.615       1.008
# monthly_avg_demand     -0.1187      0.276     -0.430      0.667      -0.660       0.423
# avg_12_month_demand    -1.0580      0.226     -4.690      0.000      -1.501      -0.615
# month                1386.8622    571.179      2.428      0.015     265.612    2508.113
# year                -1659.1893   1079.648     -1.537      0.125   -3778.587     460.208
# percent_negative    -1.017e+04   1.17e+04     -0.870      0.385   -3.31e+04    1.28e+04
# percent_neutral     -8944.2928   8035.994     -1.113      0.266   -2.47e+04    6830.730
# ==============================================================================
# Omnibus:                      513.538   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            82625.912
# Skew:                           1.941   Prob(JB):                         0.00
# Kurtosis:                      53.207   Cond. No.                     3.00e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  3e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demand Model, Jo Malone London
# OSR^2: -6.6332879763296475
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     2.234
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):              0.101
# Time:                        09:50:27   Log-Likelihood:                -166.53
# No. Observations:                  21   AIC:                             351.1
# Df Residuals:                      12   BIC:                             360.5
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -4.503e+05   4.47e+05     -1.008      0.333   -1.42e+06    5.23e+05
# demand                 -0.3175      0.282     -1.126      0.282      -0.932       0.297
# demand_P2              -0.0103      0.163     -0.063      0.951      -0.366       0.345
# demand_P1              -0.0278      0.204     -0.137      0.894      -0.472       0.416
# avg_subcat_demand       0.7674      0.530      1.449      0.173      -0.387       1.922
# monthly_avg_demand     -0.5989      1.154     -0.519      0.613      -3.114       1.916
# avg_12_month_demand     0.6067      1.511      0.402      0.695      -2.685       3.899
# month                 140.1644    180.343      0.777      0.452    -252.768     533.097
# year                  223.2027    221.393      1.008      0.333    -259.172     705.578
# ==============================================================================
# Omnibus:                        0.838   Durbin-Watson:                   2.337
# Prob(Omnibus):                  0.658   Jarque-Bera (JB):                0.828
# Skew:                          -0.311   Prob(JB):                        0.661
# Kurtosis:                       2.251   Cond. No.                     1.18e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, Jo Malone London
# OSR^2: -4.215922709577859
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     4.250
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):             0.0159
# Time:                        09:50:27   Log-Likelihood:                -158.69
# No. Observations:                  21   AIC:                             339.4
# Df Residuals:                      10   BIC:                             350.9
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -6.333e+05   4.01e+05     -1.580      0.145   -1.53e+06     2.6e+05
# demand                 -0.3941      0.217     -1.814      0.100      -0.878       0.090
# demand_P2              -0.1327      0.130     -1.021      0.331      -0.422       0.157
# demand_P1               0.0930      0.158      0.588      0.570      -0.260       0.446
# avg_subcat_demand       0.7536      0.402      1.875      0.090      -0.142       1.649
# monthly_avg_demand     -0.7137      0.872     -0.818      0.432      -2.658       1.230
# avg_12_month_demand     0.1079      1.163      0.093      0.928      -2.484       2.700
# month                 103.5097    136.773      0.757      0.467    -201.239     408.258
# year                  313.9530    198.671      1.580      0.145    -128.713     756.619
# percent_negative     2936.7153   2302.512      1.275      0.231   -2193.601    8067.032
# percent_neutral      4643.0102   1419.124      3.272      0.008    1481.005    7805.015
# ==============================================================================
# Omnibus:                        3.834   Durbin-Watson:                   2.295
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                1.467
# Skew:                           0.170   Prob(JB):                        0.480
# Kurtosis:                       1.751   Cond. No.                     1.40e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demand Model, La Mer
# OSR^2: -0.19979990363528444
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.159
# Method:                 Least Squares   F-statistic:                     6.437
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.58e-07
# Time:                        09:50:27   Log-Likelihood:                -2755.8
# No. Observations:                 231   AIC:                             5530.
# Df Residuals:                     222   BIC:                             5561.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                6.622e+05   5.19e+06      0.127      0.899   -9.57e+06    1.09e+07
# demand                 -0.3087      0.100     -3.076      0.002      -0.507      -0.111
# demand_P2              -0.0698      0.103     -0.680      0.497      -0.272       0.132
# demand_P1              -0.2635      0.099     -2.671      0.008      -0.458      -0.069
# avg_subcat_demand       1.4288      0.304      4.707      0.000       0.831       2.027
# monthly_avg_demand      0.3132      0.555      0.564      0.573      -0.781       1.408
# avg_12_month_demand    -1.0889      1.163     -0.936      0.350      -3.381       1.204
# month                1445.2186   1739.030      0.831      0.407   -1981.901    4872.339
# year                 -326.6387   2573.079     -0.127      0.899   -5397.425    4744.148
# ==============================================================================
# Omnibus:                      315.879   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34898.623
# Skew:                           6.004   Prob(JB):                         0.00
# Kurtosis:                      62.006   Cond. No.                     1.29e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, La Mer
# OSR^2: -0.1979038720725519
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     5.121
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.00e-06
# Time:                        09:50:28   Log-Likelihood:                -2755.7
# No. Observations:                 231   AIC:                             5533.
# Df Residuals:                     220   BIC:                             5571.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                6.894e+05   5.22e+06      0.132      0.895   -9.59e+06     1.1e+07
# demand                 -0.3046      0.101     -3.003      0.003      -0.504      -0.105
# demand_P2              -0.0689      0.103     -0.668      0.505      -0.272       0.134
# demand_P1              -0.2615      0.099     -2.635      0.009      -0.457      -0.066
# avg_subcat_demand       1.4208      0.306      4.642      0.000       0.818       2.024
# monthly_avg_demand      0.2782      0.566      0.492      0.623      -0.837       1.393
# avg_12_month_demand    -1.0969      1.169     -0.938      0.349      -3.401       1.208
# month                1478.2836   1748.586      0.845      0.399   -1967.840    4924.407
# year                 -339.8251   2584.266     -0.131      0.896   -5432.911    4753.261
# percent_negative     4034.8072   1.68e+04      0.240      0.811   -2.91e+04    3.72e+04
# percent_neutral     -4850.1545   1.81e+04     -0.268      0.789   -4.05e+04    3.08e+04
# ==============================================================================
# Omnibus:                      316.605   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35307.991
# Skew:                           6.025   Prob(JB):                         0.00
# Kurtosis:                      62.356   Cond. No.                     1.29e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demand Model, M.A.C
# OSR^2: 0.8455414792853577
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     496.4
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):          9.29e-316
# Time:                        09:50:28   Log-Likelihood:                -11068.
# No. Observations:                 867   AIC:                         2.215e+04
# Df Residuals:                     858   BIC:                         2.220e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2.472e+07   7.02e+06      3.523      0.000    1.09e+07    3.85e+07
# demand                 -0.0307      0.046     -0.669      0.504      -0.121       0.059
# demand_P2               0.1406      0.046      3.058      0.002       0.050       0.231
# demand_P1              -0.2204      0.043     -5.160      0.000      -0.304      -0.137
# avg_subcat_demand       1.0260      0.098     10.520      0.000       0.835       1.217
# monthly_avg_demand     -0.2138      0.190     -1.128      0.260      -0.586       0.158
# avg_12_month_demand    -0.1833      0.144     -1.270      0.204      -0.466       0.100
# month                -908.7603   1742.583     -0.522      0.602   -4328.984    2511.464
# year                -1.223e+04   3473.364     -3.522      0.000   -1.91e+04   -5417.137
# ==============================================================================
# Omnibus:                      692.598   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57726.256
# Skew:                           2.994   Prob(JB):                         0.00
# Kurtosis:                      42.523   Cond. No.                     1.07e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, M.A.C
# OSR^2: 0.8457063041658596
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     396.3
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):          4.06e-313
# Time:                        09:50:28   Log-Likelihood:                -11068.
# No. Observations:                 867   AIC:                         2.216e+04
# Df Residuals:                     856   BIC:                         2.221e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2.436e+07   7.06e+06      3.449      0.001    1.05e+07    3.82e+07
# demand                 -0.0316      0.046     -0.687      0.492      -0.122       0.059
# demand_P2               0.1402      0.046      3.047      0.002       0.050       0.231
# demand_P1              -0.2203      0.043     -5.150      0.000      -0.304      -0.136
# avg_subcat_demand       1.0270      0.098     10.516      0.000       0.835       1.219
# monthly_avg_demand     -0.2079      0.190     -1.092      0.275      -0.582       0.166
# avg_12_month_demand    -0.1845      0.144     -1.277      0.202      -0.468       0.099
# month                -850.5750   1751.345     -0.486      0.627   -4288.008    2586.858
# year                -1.206e+04   3497.110     -3.447      0.001   -1.89e+04   -5191.923
# percent_negative    -1.421e+04   3.78e+04     -0.376      0.707   -8.84e+04       6e+04
# percent_neutral     -9554.7484   2.67e+04     -0.358      0.721    -6.2e+04    4.29e+04
# ==============================================================================
# Omnibus:                      692.296   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57592.607
# Skew:                           2.992   Prob(JB):                         0.00
# Kurtosis:                      42.477   Cond. No.                     1.07e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demand Model, Origins
# OSR^2: 0.42675514984038265
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     42.77
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.29e-44
# Time:                        09:50:28   Log-Likelihood:                -3473.4
# No. Observations:                 294   AIC:                             6965.
# Df Residuals:                     285   BIC:                             6998.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                7.416e+06   4.89e+06      1.517      0.130   -2.21e+06     1.7e+07
# demand                  0.1365      0.070      1.942      0.053      -0.002       0.275
# demand_P2              -0.0915      0.077     -1.196      0.233      -0.242       0.059
# demand_P1               0.0264      0.077      0.343      0.732      -0.125       0.178
# avg_subcat_demand       0.8856      0.150      5.903      0.000       0.590       1.181
# monthly_avg_demand     -0.8639      0.560     -1.543      0.124      -1.966       0.238
# avg_12_month_demand    -1.8208      0.649     -2.804      0.005      -3.099      -0.543
# month                3411.0694   1266.465      2.693      0.007     918.257    5903.882
# year                -3670.2274   2420.285     -1.516      0.131   -8434.130    1093.675
# ==============================================================================
# Omnibus:                      265.631   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6592.119
# Skew:                           3.632   Prob(JB):                         0.00
# Kurtosis:                      25.031   Cond. No.                     2.39e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, Origins
# OSR^2: 0.42239509781967455
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.530
# Method:                 Least Squares   F-statistic:                     34.02
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           5.05e-43
# Time:                        09:50:28   Log-Likelihood:                -3473.3
# No. Observations:                 294   AIC:                             6969.
# Df Residuals:                     283   BIC:                             7009.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                7.221e+06   4.92e+06      1.466      0.144   -2.47e+06    1.69e+07
# demand                  0.1376      0.071      1.946      0.053      -0.002       0.277
# demand_P2              -0.0938      0.077     -1.219      0.224      -0.245       0.058
# demand_P1               0.0269      0.077      0.348      0.728      -0.125       0.179
# avg_subcat_demand       0.8856      0.151      5.877      0.000       0.589       1.182
# monthly_avg_demand     -0.8504      0.563     -1.510      0.132      -1.959       0.258
# avg_12_month_demand    -1.8158      0.652     -2.783      0.006      -3.100      -0.532
# month                3394.6053   1271.288      2.670      0.008     892.226    5896.985
# year                -3573.4590   2438.108     -1.466      0.144   -8372.588    1225.670
# percent_negative     7892.8113   1.84e+04      0.428      0.669   -2.84e+04    4.42e+04
# percent_neutral     -2076.0451   1.58e+04     -0.132      0.895   -3.32e+04     2.9e+04
# ==============================================================================
# Omnibus:                      266.539   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6687.146
# Skew:                           3.647   Prob(JB):                         0.00
# Kurtosis:                      25.196   Cond. No.                     2.40e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demand Model, Tom Ford Beauty
# OSR^2: 0.7037690135082655
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     66.85
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           2.69e-71
# Time:                        09:50:28   Log-Likelihood:                -4829.3
# No. Observations:                 450   AIC:                             9677.
# Df Residuals:                     441   BIC:                             9714.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                8.377e+05   1.18e+06      0.708      0.479   -1.49e+06    3.16e+06
# demand                  0.1304      0.059      2.214      0.027       0.015       0.246
# demand_P2               0.0063      0.072      0.087      0.930      -0.135       0.148
# demand_P1              -0.1452      0.064     -2.254      0.025      -0.272      -0.019
# avg_subcat_demand       0.9692      0.138      7.048      0.000       0.699       1.239
# monthly_avg_demand     -0.6662      0.339     -1.967      0.050      -1.332      -0.001
# avg_12_month_demand    -1.5470      0.529     -2.922      0.004      -2.588      -0.506
# month                  59.7150    258.807      0.231      0.818    -448.933     568.364
# year                 -412.4487    586.050     -0.704      0.482   -1564.247     739.349
# ==============================================================================
# Omnibus:                      495.328   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36912.053
# Skew:                           4.866   Prob(JB):                         0.00
# Kurtosis:                      46.289   Cond. No.                     6.42e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.42e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Demandpercent_negative percent_neutral Model, Tom Ford Beauty
# OSR^2: 0.7029046085426895
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              demand_F1   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     53.26
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.71e-69
# Time:                        09:50:28   Log-Likelihood:                -4829.2
# No. Observations:                 450   AIC:                             9680.
# Df Residuals:                     439   BIC:                             9726.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                8.081e+05    1.2e+06      0.674      0.500   -1.55e+06    3.16e+06
# demand                  0.1299      0.059      2.198      0.028       0.014       0.246
# demand_P2               0.0065      0.072      0.089      0.929      -0.136       0.149
# demand_P1              -0.1431      0.065     -2.204      0.028      -0.271      -0.016
# avg_subcat_demand       0.9688      0.138      7.018      0.000       0.698       1.240
# monthly_avg_demand     -0.6567      0.341     -1.928      0.054      -1.326       0.013
# avg_12_month_demand    -1.5320      0.533     -2.875      0.004      -2.579      -0.485
# month                  58.7236    260.263      0.226      0.822    -452.793     570.240
# year                 -397.7363    593.609     -0.670      0.503   -1564.405     768.933
# percent_negative     -333.9417   4374.413     -0.076      0.939   -8931.337    8263.453
# percent_neutral     -1320.5650   4014.558     -0.329      0.742   -9210.707    6569.577
# ==============================================================================
# Omnibus:                      495.616   Durbin-Watson:                   2.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37007.658
# Skew:                           4.870   Prob(JB):                         0.00
# Kurtosis:                      46.346   Cond. No.                     6.49e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.49e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Try Automatic Feature Selection

# %%
for brand in BRANDS:
    elasticnet(brand, alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1])
# Out:
# Feature Selection, Aveda
# OSR^2: -0.30661412050664394
# [ 4.34760216e-01 -1.52465210e-01 -8.25921579e-02  6.34713550e-01
#  -4.52095748e-01 -2.35459700e-01  8.93706666e+02 -3.90187597e+02
#   1.10712519e+03  2.87100589e+02 -2.15972474e+02 -3.72064068e+02
#  -8.05189240e+02  1.16398229e+03 -7.35969069e+02 -4.27013222e+02]
# Feature Selection, Clinique
# OSR^2: 0.8922942150485393
# [ 1.72207030e-01  6.10764891e-01  8.79098497e-02  1.34293864e-01
#  -8.58233856e-02 -1.04155851e+00  1.16155403e+04  3.22866811e+03
#  -6.20251158e+03 -1.40443229e+01 -8.40681081e+02 -5.29233935e+02
#   7.58947092e+03 -7.32340688e+02 -2.64843693e+03  3.38177761e+03]
# Feature Selection, Estée Lauder
# OSR^2: 0.737977253379676
# [ 2.21631556e-01 -7.48105550e-02  1.21024190e-02  8.15124410e-01
#  -9.49982635e-02 -1.06454994e+00  1.39822330e+03 -1.73969769e+03
#  -7.24576319e+03  1.78794502e+04 -1.26235716e+03 -4.85353318e+03
#  -4.51479671e+03 -7.60743665e+03 -5.66947894e+02  8.17538455e+03]
# Feature Selection, Jo Malone London
# OSR^2: -6.282625696314137
# [-4.12858989e-01 -1.37863328e-01  3.27933687e-02  8.79233590e-01
#  -2.94354585e-01  5.32530842e-01  7.49276032e+01  2.85971246e+02
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  4.71168677e+02
#  -4.71168424e+02  4.97533833e+01  1.82214070e+03 -1.87289408e+03]
# Feature Selection, La Mer
# OSR^2: -0.12068640165791034
# [-3.06845597e-01 -6.72821899e-02 -2.62015560e-01  1.42244655e+00
#   3.11301631e-01 -9.75021748e-01  1.20314735e+03 -3.38982309e+02
#   3.51315237e+02  6.68608671e+01 -4.83683256e+02  1.59139599e+01
#   4.65931924e+01  1.73926396e+02 -1.87334270e+02  1.24078744e+01]
# Feature Selection, M.A.C
# OSR^2: 0.8500468867521658
# [-3.52890961e-02  1.42288080e-01 -2.11140264e-01  1.02033894e+00
#  -7.32187901e-02 -2.48468197e-01 -1.20906380e+01 -7.09810866e+03
#  -3.77396012e+02 -1.31177328e+02  1.33521716e+02  7.00653743e+02
#  -3.24602118e+02 -1.82911576e+02 -2.83760388e+02  4.67671964e+02]
# Feature Selection, Origins
# OSR^2: 0.4920969029465956
# [ 1.31485963e-01 -8.44845977e-02  2.81608517e-02  8.85156354e-01
#  -5.72783584e-01 -1.62049572e+00  2.85062080e+03 -2.13535954e+03
#  -3.65399739e+02  7.21447734e+01 -3.51987544e+02 -2.61952333e+02
#   9.08194843e+02  2.26148116e+02 -3.15247363e+01 -1.93623380e+02]
# Feature Selection, Tom Ford Beauty
# OSR^2: 0.7043950475506016
# [ 1.29121278e-01  3.32769575e-03 -1.45059355e-01  9.73661597e-01
#  -6.56504250e-01 -1.56946076e+00  8.34499166e+01 -2.51125729e+02
#  -2.39940107e+02  3.47630090e+01  7.61308334e+01 -7.79931711e+01
#   2.06039436e+02  4.81374141e+00 -4.17025968e+01  3.58888554e+01]

# %% [markdown]
# ### Try Non-linear models

# %%
for brand in BRANDS:
    nonlinearmodels(brand, n_iter = 30)
# Out:
# ---------
# Aveda
# CART
# Demand + RR:  0.43995524295043426
# Demand Only:  0.4802006467634931
# RF
# Demand + RR:  0.45441908657453106
# Demand Only:  0.4755993491031465
# XGB
# Demand + RR:  0.3898329239243152
# Demand Only:  0.34859338656192357
# ---------
# Clinique
# CART
# Demand + RR:  0.782879037654471
# Demand Only:  0.7826055758573812
# RF
# Demand + RR:  0.8354958824487597
# Demand Only:  0.8262509480250988
# XGB
# Demand + RR:  0.7847532095816933
# Demand Only:  0.798056012859436
# ---------
# Estée Lauder
# CART
# Demand + RR:  0.7305648512606188
# Demand Only:  0.7330224558541811
# RF
# Demand + RR:  0.7817171556901586
# Demand Only:  0.7668470980998249
# XGB
# Demand + RR:  0.7797086792244149
# Demand Only:  0.7594372051677603
# ---------
# Jo Malone London
# CART
# Demand + RR:  0.5381334526534544
# Demand Only:  -0.3752366021642781
# RF
# Demand + RR:  0.3744436010240802
# Demand Only:  -0.0953089946808467
# XGB
# Demand + RR:  0.4032038756765696
# Demand Only:  -0.13536205533040627
# ---------
# La Mer
# CART
# Demand + RR:  0.18768942600704422
# Demand Only:  0.19992563435811014
# RF
# Demand + RR:  0.1716293245340097
# Demand Only:  0.19021456205901363
# XGB
# Demand + RR:  -0.18032940835635847
# Demand Only:  -0.15049933786851907
# ---------
# M.A.C
# CART
# Demand + RR:  0.7083521790504554
# Demand Only:  0.7038859653414086
# RF
# Demand + RR:  0.78616307037347
# Demand Only:  0.7911741353344821
# XGB
# Demand + RR:  0.7777616105621146
# Demand Only:  0.7813103635910359
# ---------
# Origins
# CART
# Demand + RR:  0.48468208877585983
# Demand Only:  0.49605221759631507
# RF
# Demand + RR:  0.5128631793281987
# Demand Only:  0.550451932441723
# XGB
# Demand + RR:  0.4152183549965969
# Demand Only:  0.49336403713490684
# ---------
# Tom Ford Beauty
# CART
# Demand + RR:  0.5899237253359765
# Demand Only:  0.5888628390978757
# RF
# Demand + RR:  0.5849028821349117
# Demand Only:  0.5795868675317831
# XGB
# Demand + RR:  0.5158759997565179
# Demand Only:  0.5339884399638423

# %% [markdown]
# #### To Dos
# Remove colinearity
#
# More PCA
#
# Diff and diff
#
# Check without parameters
